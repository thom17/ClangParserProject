# %%
import clang.cindex
import os
#파일 설정은 한번만 해야하는듯
clang.cindex.Config.set_library_file(r"C:\Program Files\LLVM\bin\libclang.dll")

# %%
#파싱
def parsing(file_path: str):
    index = clang.cindex.Index.create()
    return index.parse(file_path, args=['-std=c++14'])

# %%
def parse_project(directory):
    index = clang.cindex.Index.create()

    # 프로젝트 디렉토리 내의 모든 C++ 파일을 찾음
    files = list(find_cpp_files(directory))

    # 각 파일을 파싱
    translation_units = []
    for file in files:
        print(f"parse {file}")
        tu = index.parse(file, args=[
            '-x', 'c++', '-std=c++14',
            '-I', 'path/to/include',  # 추가 인클루드 경로
            '-D__CODE_GENERATOR__'   # 필요한 경우 매크로 정의
        ])
        translation_units.append(tu)

    return translation_units

def find_cpp_files(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(('.cpp', '.h')):
                yield os.path.join(root, file)

# %%
import time


folder_path = r"D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation"
# folder_path = r"D:\dev\AutoPlanning\trunk\AP_trunk_pure"
# Use the selected folder path for further processing
print("Selected folder:", folder_path)

start_time = time.time()
tus = parse_project(folder_path)

# 결과 처리 및 출력
for tu in tus:
    print(tu.spelling, "contains", len(list(tu.cursor.get_children())), "elements")

# Record the end time
end_time = time.time()

# Calculate the elapsed time
elapsed_time = end_time - start_time
print("Elapsed time:", elapsed_time, "seconds")
# Out:
# Selected folder: D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorAxialFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorAxialFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCrownDesign.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCrownDesign.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCSFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCSFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorImplantPreview.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorImplantPreview.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorMPRFixrueBase.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorMPRFixrueBase.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture - 복사본.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture-UpperLower분리.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorTgtFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorTgtFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\APImplantSimulationMain.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\APImplantSimulationMain.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoAiProcess.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoAiProcess.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoCrownImplement.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoCrownImplement.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CCrownLibTransformSaver.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CCrownLibTransformSaver.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CollisionImplant.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CollisionImplant.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandContact.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandContact.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCopy.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCopy.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCrownDesign.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCrownDesign.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureDental.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureDental.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureMeasure.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureMeasure.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandLocateCrown.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandLocateCrown.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandMorph.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandMorph.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandSmoothing.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandSmoothing.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandWaxKnife.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandWaxKnife.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CrownMorphProcessor.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CrownMorphProcessor.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DlgImplantPreview.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DlgImplantPreview.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\dllmain.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIBoneDensityTable.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIBoneDensityTable.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonClipPlane.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonClipPlane.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureManual.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureManual.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureMeasure.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureMeasure.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureView.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureView.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIFixture2D.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIFixture2D.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer-UpperLower 분리.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIPlaneFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIPlaneFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIShowOrgScan.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIShowOrgScan.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\InitLog.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\InitLog.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\interface_module.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\interface_module.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MakeSafety.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MakeSafety.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesign.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesign.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignBase.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignBase.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignMulti.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignMulti.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCS.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCS.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCSPlane.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCSPlane.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybrid.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybrid.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybridMulti.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybridMulti.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGT.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGT.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGTPlane.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGTPlane.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorListIS.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorListIS.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MeasureImplant.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MeasureImplant.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ModuleDocAPImplantSimulation.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ModuleDocAPImplantSimulation.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\mod_APImplantSimulation.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\Resource.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\stdafx.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\stdafx.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\targetver.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarCrownDesign.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarCrownDesign.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulator.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulator.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulatorSetting.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulatorSetting.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgCrownLibrary.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgCrownLibrary.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureGroup.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureGroup.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureSafetySet.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureSafetySet.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgImplantLib.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgImplantLib.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UndoRedoFixture.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UndoRedoFixture.h
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\XMLDocImplantSimulation.cpp
# parse D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\XMLDocImplantSimulation.h
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorAxialFixture.cpp contains 9643 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorAxialFixture.h contains 2820 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCrownDesign.cpp contains 9768 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCrownDesign.h contains 2869 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCSFixture.cpp contains 9601 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCSFixture.h contains 2822 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp contains 9779 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.h contains 2860 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorImplantPreview.cpp contains 9557 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorImplantPreview.h contains 2854 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorMPRFixrueBase.cpp contains 9608 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorMPRFixrueBase.h contains 2819 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture - 복사본.cpp contains 9601 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture-UpperLower분리.cpp contains 9601 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.cpp contains 9601 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.h contains 2910 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorTgtFixture.cpp contains 9598 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorTgtFixture.h contains 2821 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\APImplantSimulationMain.cpp contains 9781 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\APImplantSimulationMain.h contains 2906 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoAiProcess.cpp contains 9601 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoAiProcess.h contains 2657 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoCrownImplement.cpp contains 9607 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoCrownImplement.h contains 412 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CCrownLibTransformSaver.cpp contains 9525 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CCrownLibTransformSaver.h contains 378 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CollisionImplant.cpp contains 9612 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CollisionImplant.h contains 387 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandContact.cpp contains 9627 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandContact.h contains 3168 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCopy.cpp contains 9715 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCopy.h contains 3201 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCrownDesign.cpp contains 9597 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCrownDesign.h contains 3167 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureDental.cpp contains 9584 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureDental.h contains 2877 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureMeasure.cpp contains 9616 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureMeasure.h contains 2880 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandLocateCrown.cpp contains 9731 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandLocateCrown.h contains 3170 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandMorph.cpp contains 9635 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandMorph.h contains 3205 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandSmoothing.cpp contains 9617 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandSmoothing.h contains 3172 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandWaxKnife.cpp contains 9619 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandWaxKnife.h contains 3173 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CrownMorphProcessor.cpp contains 9580 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CrownMorphProcessor.h contains 410 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DlgImplantPreview.cpp contains 9570 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DlgImplantPreview.h contains 121 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\dllmain.cpp contains 9531 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIBoneDensityTable.cpp contains 9536 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIBoneDensityTable.h contains 1813 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonClipPlane.cpp contains 9533 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonClipPlane.h contains 134 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureManual.cpp contains 9541 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureManual.h contains 135 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureMeasure.cpp contains 9541 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureMeasure.h contains 1818 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureView.cpp contains 9533 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureView.h contains 134 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIFixture2D.cpp contains 9573 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIFixture2D.h contains 1821 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer-UpperLower 분리.cpp contains 9602 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer.cpp contains 9603 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer.h contains 2958 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIPlaneFixture.cpp contains 9530 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIPlaneFixture.h contains 1814 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIShowOrgScan.cpp contains 9537 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIShowOrgScan.h contains 1815 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\InitLog.cpp contains 9533 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\InitLog.h contains 1 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\interface_module.cpp contains 9559 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\interface_module.h contains 3032 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MakeSafety.cpp contains 9588 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MakeSafety.h contains 6 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesign.cpp contains 9597 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesign.h contains 134 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignBase.cpp contains 9571 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignBase.h contains 124 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignMulti.cpp contains 9607 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignMulti.h contains 125 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCS.cpp contains 9642 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCS.h contains 126 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCSPlane.cpp contains 9571 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCSPlane.h contains 125 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybrid.cpp contains 9622 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybrid.h contains 124 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybridMulti.cpp contains 9617 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybridMulti.h contains 124 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGT.cpp contains 9634 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGT.h contains 126 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGTPlane.cpp contains 9570 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGTPlane.h contains 125 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorListIS.cpp contains 9585 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorListIS.h contains 123 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MeasureImplant.cpp contains 9601 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MeasureImplant.h contains 392 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ModuleDocAPImplantSimulation.cpp contains 9588 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ModuleDocAPImplantSimulation.h contains 15 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\mod_APImplantSimulation.cpp contains 9524 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\Resource.h contains 0 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\stdafx.cpp contains 9524 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\stdafx.h contains 9524 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\targetver.h contains 0 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarCrownDesign.cpp contains 9808 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarCrownDesign.h contains 7116 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarFixture.cpp contains 9838 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarFixture.h contains 7674 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulator.cpp contains 9625 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulator.h contains 2050 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulatorSetting.cpp contains 9635 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulatorSetting.h contains 6715 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgCrownLibrary.cpp contains 9611 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgCrownLibrary.h contains 2054 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureGroup.cpp contains 9700 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureGroup.h contains 2066 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureSafetySet.cpp contains 9677 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureSafetySet.h contains 2049 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgImplantLib.cpp contains 9750 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgImplantLib.h contains 6720 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UndoRedoFixture.cpp contains 9536 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UndoRedoFixture.h contains 122 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\XMLDocImplantSimulation.cpp contains 9550 elements
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\XMLDocImplantSimulation.h contains 79 elements
# Elapsed time: 285.4674708843231 seconds

# %%
def read_specific_column(filename, line_number, column_index):
    try:
        with open(filename, 'r') as file:
            for current_line_number, line in enumerate(file, start=1):
                if current_line_number == line_number:
                    if column_index <= len(line):
                        return line[:column_index-1] + "->" + line[column_index-1:]
                    else:
                        return "Error: The line does not have enough columns."
            return "Error: Line number out of range."
    except FileNotFoundError:
        return "Error: File not found."
    except Exception as e:
        return f"Error: {str(e)}"

def visit_node(node, depth=0):
    indent = ' ' * depth
    # print(f"{indent}{node.kind}: spelling='{node.spelling}', displayname='{node.displayname}', location={node.location.file.name}:{node.location.line}:{node.location.column}")
    print(f"{indent}{node.kind}: spelling='{node.spelling}', displayname='{node.displayname}',{node.location.line}:{node.location.column}")

    for child in node.get_children():
        visit_node(child, depth + 2)

def getSimpleFileName(input_path):
    # 경로를 표준화합니다.
    normalized_path = os.path.normpath(input_path)
    
    # 경로를 구성하는 파트들을 리스트로 분리합니다.
    parts = normalized_path.split(os.sep)
    
    # 마지막 파일 이름과 그 바로 상위 디렉토리만 포함하도록 조정합니다.
    if len(parts) > 1:
        result_path = os.path.join(parts[-2], parts[-1])
    else:
        result_path = parts[-1]  # 파일 또는 폴더만 있는 경우
    
    return result_path

# %%
class SimpleVisitor:
    def __init__(self, node, base_path: str):
        self.node: clang.cindex.Cursor = node
        self.base_path: str = base_path
        self.base_path_cpp: str = base_path.replace(".cpp", ".h")
        self.base_path_h: str = base_path.replace(".h", ".cpp")
        self.location: clang.cindex.SourceLocation = self.node.location
        self.child_node = self.node.get_children()

    def get_source_code(self):
        file = self.location.file
        if file:
            file_path: str = file.name
        else:
            file_path = self.base_path
        with open(file_path, 'r') as file:
            return file.read()
            
    def make_comment_code(self, code: str = None):
        if code is None:
            code = self.get_source_code()

        code2list = code.splitlines()
        line = self.location.line
        # 현재 노드에 대한 주석 추가
        try:
            code2list[line - 1] += f" // {self.node.kind.name}({self.node.spelling})"
        except:
            print(f"line={line} size = {code2list.__len__()}")
            return code
        code = '\n'.join(code2list)

        # 모든 자식 노드에 대해 재귀적으로 처리
        for child in self.node.get_children():
            child_visitor = SimpleVisitor(child, self.base_path)
            code = child_visitor.make_comment_code(code)

        return code




    def is_base_file(self):
        """
        재귀에서 node와 str을 입력 받음
        node 자체는 경로가 원래 상위의 경로가 아니니까
        :return:
        """
        location: clang.cindex.SourceLocation = self.node.location
        file: clang.cindex.File = location.file

        parsing_file_path: str = file.__str__()
        return parsing_file_path.__contains__(self.base_path) and parsing_file_path


    def visit(self):
        spelling = self.node.spelling
        location: clang.cindex.SourceLocation = self.node.location
        file: clang.cindex.File = location.file

        # print(f"node.base_path = {self.base_path}")

        parsing_file_path: str = file.__str__()
        # print("path : ", parsing_file_path)
        is_need_print = self.is_base_file()
        # print("->", is_need_print)
        if spelling and is_need_print:
            # self.node.kind의 이름을 출력하도록 수정
            print(f"Node found: {spelling} ({self.node.kind.name})")
            print(f"Node : {self.node}")
            print(f"Location : {location}")
            print(f"File : {file}")
            print()

        # 자식 노드에 대해 방문을 재귀적으로 진행
        for child in self.node.get_children():
            visitor = SimpleVisitor(child, self.base_path)
            visitor.visit()

    def for_make_file_map(self, map=dict()):
        spelling = self.node.spelling
        location: clang.cindex.SourceLocation = self.node.location
        file: clang.cindex.File = location.file
        str_file = file.__str__()
        if str_file in map:
            map[str_file].append(self.node)
        else:
            map[str_file] = [self.node]

        # 자식 노드에 대해 방문을 재귀적으로 진행
        for child in self.node.get_children():
            visitor = SimpleVisitor(child, self.base_path)
            visitor.for_make_file_map(map)

    def for_make_stmt_map(self, map):
        try:
            kind = self.node.kind
            if kind in map:
                map[kind].append(self.node)
            else:
                map[kind] = [self.node]

            for child in self.node.get_children():
                visitor = SimpleVisitor(child, self.base_path)
                visitor.for_make_stmt_map(map)

        except ValueError as e:
            print(f"Skipping node with unknown CursorKind: {e}")


    def for_make__map(self, map=dict()):
        spelling = self.node.spelling
        location: clang.cindex.SourceLocation = self.node.location
        file: clang.cindex.File = location.file
        str_file = file.__str__()
        if str_file in map:
            map[str_file].append(self.node)
        else:
            map[str_file] = [self.node]

        # 자식 노드에 대해 방문을 재귀적으로 진행
        for child in self.node.get_children():
            visitor = SimpleVisitor(child, self.base_path)
            visitor.for_make_file_map(map)
    def compare_spelling_display(self):
        if self.node.spelling != self.node.displayname:
            print(f"{node.kind}: spelling='{node.spelling}', displayname='{node.displayname}', location={node.location.file}:{node.location.line}:{node.location.column}")
        for chid_node in self.node.get_children():
            visitor = SimpleVisitor(chid_node, self.base_path)
            visitor.compare_spelling_display()
            

    def visit_for_location(self):
        # print(type(self.node))
        spelling = self.node.spelling
        location: clang.cindex.SourceLocation = self.node.location
        file = location.file
        print("file : ", type(file), " = ", file)

        print(f"{type(location)} = {location}")
        tokens = self.node.get_tokens()
        print(tokens)

        if spelling:  # 노드 이름이 있는 경우에만 출력
            location = self.node.location
            line = location.line
            column = location.column
            print(f"Node found: {spelling} ({self.node.kind.name}) at Line: {line}, Column: {column}")

        # 자식 노드에 대해 방문을 재귀적으로 진행
        for child in self.node.get_children():
            visitor = SimpleVisitor(child)
            visitor.visit_for_location()

# %%
#모든 파일( CompliationUnit) 순환
i =0
for tunit in tus:
    print(f"{[i]}={tunit.spelling}")
    i += 1

#특정 파일 설정
target = tus[6]

#Visitor 생성 및 stmt 파싱
simpleVisit = SimpleVisitor(target.cursor, target.spelling)
stmt_map = {}
simpleVisit.for_make_stmt_map(stmt_map)
print(target.spelling, " has ")
for stmt in stmt_map:
    print(stmt, " : ", stmt_map[stmt].__len__())
print("done")
# Out:
# [0]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorAxialFixture.cpp
# [1]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorAxialFixture.h
# [2]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCrownDesign.cpp
# [3]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCrownDesign.h
# [4]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCSFixture.cpp
# [5]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorCSFixture.h
# [6]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp
# [7]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.h
# [8]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorImplantPreview.cpp
# [9]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorImplantPreview.h
# [10]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorMPRFixrueBase.cpp
# [11]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorMPRFixrueBase.h
# [12]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture - 복사본.cpp
# [13]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture-UpperLower분리.cpp
# [14]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.cpp
# [15]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.h
# [16]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorTgtFixture.cpp
# [17]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorTgtFixture.h
# [18]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\APImplantSimulationMain.cpp
# [19]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\APImplantSimulationMain.h
# [20]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoAiProcess.cpp
# [21]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoAiProcess.h
# [22]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoCrownImplement.cpp
# [23]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\AutoCrownImplement.h
# [24]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CCrownLibTransformSaver.cpp
# [25]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CCrownLibTransformSaver.h
# [26]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CollisionImplant.cpp
# [27]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CollisionImplant.h
# [28]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandContact.cpp
# [29]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandContact.h
# [30]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCopy.cpp
# [31]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCopy.h
# [32]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCrownDesign.cpp
# [33]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandCrownDesign.h
# [34]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureDental.cpp
# [35]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureDental.h
# [36]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureMeasure.cpp
# [37]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandFixtureMeasure.h
# [38]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandLocateCrown.cpp
# [39]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandLocateCrown.h
# [40]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandMorph.cpp
# [41]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandMorph.h
# [42]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandSmoothing.cpp
# [43]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandSmoothing.h
# [44]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandWaxKnife.cpp
# [45]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CommandWaxKnife.h
# [46]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CrownMorphProcessor.cpp
# [47]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\CrownMorphProcessor.h
# [48]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DlgImplantPreview.cpp
# [49]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DlgImplantPreview.h
# [50]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\dllmain.cpp
# [51]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIBoneDensityTable.cpp
# [52]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIBoneDensityTable.h
# [53]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonClipPlane.cpp
# [54]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonClipPlane.h
# [55]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureManual.cpp
# [56]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureManual.h
# [57]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureMeasure.cpp
# [58]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureMeasure.h
# [59]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureView.cpp
# [60]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIButtonFixtureView.h
# [61]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIFixture2D.cpp
# [62]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIFixture2D.h
# [63]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer-UpperLower 분리.cpp
# [64]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer.cpp
# [65]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSILibraryDrawer.h
# [66]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIPlaneFixture.cpp
# [67]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIPlaneFixture.h
# [68]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIShowOrgScan.cpp
# [69]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\DSIShowOrgScan.h
# [70]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\InitLog.cpp
# [71]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\InitLog.h
# [72]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\interface_module.cpp
# [73]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\interface_module.h
# [74]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MakeSafety.cpp
# [75]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MakeSafety.h
# [76]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesign.cpp
# [77]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesign.h
# [78]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignBase.cpp
# [79]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignBase.h
# [80]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignMulti.cpp
# [81]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorCrownDesignMulti.h
# [82]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCS.cpp
# [83]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCS.h
# [84]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCSPlane.cpp
# [85]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureCSPlane.h
# [86]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybrid.cpp
# [87]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybrid.h
# [88]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybridMulti.cpp
# [89]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureHybridMulti.h
# [90]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGT.cpp
# [91]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGT.h
# [92]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGTPlane.cpp
# [93]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorFixtureTGTPlane.h
# [94]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorListIS.cpp
# [95]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ManipulatorListIS.h
# [96]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MeasureImplant.cpp
# [97]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\MeasureImplant.h
# [98]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ModuleDocAPImplantSimulation.cpp
# [99]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ModuleDocAPImplantSimulation.h
# [100]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\mod_APImplantSimulation.cpp
# [101]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\Resource.h
# [102]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\stdafx.cpp
# [103]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\stdafx.h
# [104]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\targetver.h
# [105]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarCrownDesign.cpp
# [106]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarCrownDesign.h
# [107]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarFixture.cpp
# [108]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ToolBarFixture.h
# [109]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulator.cpp
# [110]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulator.h
# [111]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulatorSetting.cpp
# [112]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgArticulatorSetting.h
# [113]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgCrownLibrary.cpp
# [114]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgCrownLibrary.h
# [115]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureGroup.cpp
# [116]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureGroup.h
# [117]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureSafetySet.cpp
# [118]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgFixtureSafetySet.h
# [119]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgImplantLib.cpp
# [120]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UIDlgImplantLib.h
# [121]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UndoRedoFixture.cpp
# [122]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\UndoRedoFixture.h
# [123]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\XMLDocImplantSimulation.cpp
# [124]=D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\XMLDocImplantSimulation.h
# Skipping node with unknown CursorKind: Unknown template argument kind 280
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp  has
# CursorKind.TRANSLATION_UNIT  :  1
# CursorKind.UNEXPOSED_DECL  :  5031
# CursorKind.TYPEDEF_DECL  :  10684
# CursorKind.FUNCTION_DECL  :  19334
# CursorKind.PARM_DECL  :  103042
# CursorKind.TYPE_REF  :  205207
# CursorKind.CLASS_TEMPLATE  :  653
# CursorKind.TEMPLATE_TYPE_PARAMETER  :  4560
# CursorKind.ENUM_DECL  :  2737
# CursorKind.ENUM_CONSTANT_DECL  :  25382
# CursorKind.CXX_BOOL_LITERAL_EXPR  :  874
# CursorKind.CLASS_TEMPLATE_PARTIAL_SPECIALIZATION  :  292
# CursorKind.STATIC_ASSERT  :  87
# CursorKind.UNARY_OPERATOR  :  5763
# CursorKind.DECL_REF_EXPR  :  59689
# CursorKind.TEMPLATE_REF  :  5862
# CursorKind.STRING_LITERAL  :  1380
# CursorKind.FUNCTION_TEMPLATE  :  1748
# CursorKind.TEMPLATE_NON_TYPE_PARAMETER  :  656
# CursorKind.VAR_DECL  :  10764
# CursorKind.NAMESPACE  :  202
# CursorKind.USING_DECLARATION  :  633
# CursorKind.OVERLOADED_DECL_REF  :  2259
# CursorKind.UNEXPOSED_ATTR  :  3296
# CursorKind.STRUCT_DECL  :  11885
# CursorKind.FIELD_DECL  :  58359
# CursorKind.UNION_DECL  :  1114
# CursorKind.INTEGER_LITERAL  :  50383
# CursorKind.COMPOUND_STMT  :  14201
# CursorKind.RETURN_STMT  :  8957
# CursorKind.UNEXPOSED_EXPR  :  82741
# CursorKind.CALL_EXPR  :  31081
# CursorKind.BINARY_OPERATOR  :  24945
# CursorKind.CSTYLE_CAST_EXPR  :  8773
# CursorKind.DECL_STMT  :  5204
# CursorKind.CXX_NULL_PTR_LITERAL_EXPR  :  351
# CursorKind.NAMESPACE_REF  :  2660
# CursorKind.WARN_UNUSED_RESULT_ATTR  :  1707
# CursorKind.PAREN_EXPR  :  28307
# CursorKind.CONDITIONAL_OPERATOR  :  558
# CursorKind.IF_STMT  :  2807
# CursorKind.NULL_STMT  :  275
# CursorKind.CXX_CONST_CAST_EXPR  :  70
# CursorKind.CXX_STATIC_CAST_EXPR  :  1253
# CursorKind.CXX_UNARY_EXPR  :  580
# CursorKind.MEMBER_REF_EXPR  :  18979
# CursorKind.FOR_STMT  :  179
# CursorKind.TYPE_ALIAS_DECL  :  1508
# CursorKind.CONVERSION_FUNCTION  :  205
# CursorKind.CXX_METHOD  :  30232
# CursorKind.TYPE_ALIAS_TEMPLATE_DECL  :  107
# CursorKind.CXX_BASE_SPECIFIER  :  2249
# CursorKind.TEMPLATE_TEMPLATE_PARAMETER  :  7
# CursorKind.CXX_ACCESS_SPEC_DECL  :  5069
# CursorKind.CONSTRUCTOR  :  2667
# CursorKind.MEMBER_REF  :  859
# CursorKind.CLASS_DECL  :  2018
# CursorKind.FLOATING_LITERAL  :  1422
# CursorKind.DO_STMT  :  235
# CursorKind.COMPOUND_ASSIGNMENT_OPERATOR  :  517
# CursorKind.VISIBILITY_ATTR  :  4
# CursorKind.DESTRUCTOR  :  858
# CursorKind.SIZE_OF_PACK_EXPR  :  9
# CursorKind.PACK_EXPANSION_EXPR  :  70
# CursorKind.INIT_LIST_EXPR  :  949
# CursorKind.ARRAY_SUBSCRIPT_EXPR  :  1821
# CursorKind.CXX_REINTERPRET_CAST_EXPR  :  353
# CursorKind.CXX_THIS_EXPR  :  1150
# CursorKind.FRIEND_DECL  :  701
# CursorKind.CXX_THROW_EXPR  :  10
# CursorKind.CXX_FUNCTIONAL_CAST_EXPR  :  463
# CursorKind.BREAK_STMT  :  233
# CursorKind.WHILE_STMT  :  82
# CursorKind.CXX_FINAL_ATTR  :  34
# CursorKind.CHARACTER_LITERAL  :  585
# CursorKind.ALIGNED_ATTR  :  83
# CursorKind.DLLIMPORT_ATTR  :  5217
# CursorKind.SWITCH_STMT  :  42
# CursorKind.CASE_STMT  :  243
# CursorKind.DEFAULT_STMT  :  40
# CursorKind.SEH_TRY_STMT  :  1
# CursorKind.SEH_EXCEPT_STMT  :  1
# CursorKind.CXX_TRY_STMT  :  15
# CursorKind.CXX_CATCH_STMT  :  19
# CursorKind.USING_DIRECTIVE  :  22
# CursorKind.CXX_NEW_EXPR  :  97
# CursorKind.CXX_DELETE_EXPR  :  64
# CursorKind.GOTO_STMT  :  9
# CursorKind.LABEL_REF  :  9
# CursorKind.LABEL_STMT  :  3
# CursorKind.CONTINUE_STMT  :  13
# CursorKind.CXX_OVERRIDE_ATTR  :  186
# CursorKind.LAMBDA_EXPR  :  15
# CursorKind.VARIABLE_REF  :  4
# CursorKind.NAMESPACE_ALIAS  :  1
# CursorKind.DLLEXPORT_ATTR  :  8
# CursorKind.CXX_DYNAMIC_CAST_EXPR  :  10
# done

# %%
from clang.cindex import CursorKind
from clang.cindex import Cursor as ClangCursor
CXX_METHOD_list: ClangCursor = stmt_map[CursorKind.CXX_METHOD]

for node in CXX_METHOD_list:
    print(f"{node.displayname} {getSimpleFileName(node.location.file.name)}")
# Out:
# operator()() include\xtr1common
# begin() include\initializer_list
# end() include\initializer_list
# size() include\initializer_list
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# operator()(const _Ty &, const _Ty &) include\xstddef
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# min() include\limits
# max() include\limits
# lowest() include\limits
# epsilon() include\limits
# round_error() include\limits
# denorm_min() include\limits
# infinity() include\limits
# quiet_NaN() include\limits
# signaling_NaN() include\limits
# _Lockit_ctor(int) include\yvals.h
# _Lockit_dtor(int) include\yvals.h
# _Lockit_ctor(_Lockit *) include\yvals.h
# _Lockit_ctor(_Lockit *, int) include\yvals.h
# _Lockit_dtor(_Lockit *) include\yvals.h
# operator=(const _Lockit &) include\yvals.h
# _Init_locks_ctor(_Init_locks *) include\yvals.h
# _Init_locks_dtor(_Init_locks *) include\yvals.h
# size() include\type_traits
# get() include\type_traits
# operator()(const _Kty &) include\type_traits
# operator=(const _Conditionally_enabled_hash<type-parameter-0-0, false> &) include\type_traits
# operator=(_Conditionally_enabled_hash<type-parameter-0-0, false> &&) include\type_traits
# _Do_hash(const _Kty &) include\type_traits
# operator()(const float) include\type_traits
# operator()(const double) include\type_traits
# operator()(const long double) include\type_traits
# operator()(nullptr_t) include\type_traits
# operator=(const exception &) include\vcruntime_exception.h
# what() include\vcruntime_exception.h
# operator=(const exception_ptr &) include\exception
# operator=(nullptr_t) include\exception
# _Current_exception() include\exception
# _Copy_exception(void *, const void *) include\exception
# operator=(const nested_exception &) include\exception
# rethrow_nested() include\exception
# nested_ptr() include\exception
# operator=(const volatile pair<_Ty1, _Ty2> &) include\utility
# swap(pair<_Ty1, _Ty2> &) include\utility
# pointer_to(_Reftype) include\xutility
# pointer_to(_Reftype) include\xutility
# operator-() include\xutility
# base() include\xutility
# operator*() include\xutility
# operator->() include\xutility
# operator++() include\xutility
# operator++(int) include\xutility
# operator--() include\xutility
# operator--(int) include\xutility
# operator+(const difference_type) include\xutility
# operator+=(const difference_type) include\xutility
# operator-(const difference_type) include\xutility
# operator-=(const difference_type) include\xutility
# operator[](const difference_type) include\xutility
# _Get_current() include\xutility
# base() include\xutility
# operator*() include\xutility
# operator->() include\xutility
# operator++() include\xutility
# operator++(int) include\xutility
# operator--() include\xutility
# operator--(int) include\xutility
# operator+(const difference_type) include\xutility
# operator+=(const difference_type) include\xutility
# operator-(const difference_type) include\xutility
# operator-=(const difference_type) include\xutility
# operator[](const difference_type) include\xutility
# operator()(_Diff) include\xutility
# _Get_all_bits() include\xutility
# operator=(const _Rng_from_urng<_Diff, _Urng> &) include\xutility
# _Get_bits() include\xutility
# _Allocate(const size_t) include\xmemory
# allocate(_Alloc &, const size_type) include\xmemory
# allocate(_Alloc &, const size_type, const const_void_pointer) include\xmemory
# deallocate(_Alloc &, pointer, size_type) include\xmemory
# max_size(const _Alloc &) include\xmemory
# select_on_container_copy_construction(const _Alloc &) include\xmemory
# allocate(_Alloc &, const size_type) include\xmemory
# allocate(_Alloc &, const size_type, const_void_pointer) include\xmemory
# deallocate(_Alloc &, const pointer, const size_type) include\xmemory
# max_size(const _Alloc &) include\xmemory
# select_on_container_copy_construction(const _Alloc &) include\xmemory
# address(_Ty &) include\xmemory
# address(const _Ty &) include\xmemory
# operator=(const allocator<_Ty> &) include\xmemory
# deallocate(_Ty *const, const size_t) include\xmemory
# allocate(const size_t) include\xmemory
# allocate(const size_t, const void *) include\xmemory
# max_size() include\xmemory
# _Release() include\xmemory
# _Allocate() include\xmemory
# operator=(const _Alloc_construct_ptr<_Alloc> &) include\xmemory
# _Orphan_all() include\xmemory
# _Swap_proxy_and_iterators(_Container_base0 &) include\xmemory
# _Alloc_proxy(const _Fake_allocator &) include\xmemory
# _Reload_proxy(const _Fake_allocator &, const _Fake_allocator &) include\xmemory
# _Adopt(const void *) include\xmemory
# _Getcont() include\xmemory
# operator=(const _Container_base12 &) include\xmemory
# _Orphan_all() include\xmemory
# _Swap_proxy_and_iterators(_Container_base12 &) include\xmemory
# _Orphan_all_unlocked_v3() include\xmemory
# _Swap_proxy_and_iterators_unlocked(_Container_base12 &) include\xmemory
# _Orphan_all_locked_v3() include\xmemory
# _Swap_proxy_and_iterators_locked(_Container_base12 &) include\xmemory
# operator=(const _Iterator_base12 &) include\xmemory
# _Adopt(const _Container_base12 *) include\xmemory
# _Getcont() include\xmemory
# _Orphan_all_unlocked_v3() include\xmemory
# _Orphan_all() include\xmemory
# _Swap_proxy_and_iterators_unlocked(_Container_base12 &) include\xmemory
# _Swap_proxy_and_iterators(_Container_base12 &) include\xmemory
# operator=(const _Fake_proxy_ptr_impl &) include\xmemory
# _Bind(const _Fake_allocator &, _Container_base0 *) include\xmemory
# _Release() include\xmemory
# _Release() include\xmemory
# _Bind(_Alloc &, _Container_base12 *) include\xmemory
# _Get_first() include\xmemory
# _Get_first() include\xmemory
# _Get_first() include\xmemory
# _Get_first() include\xmemory
# operator=(const _Uninitialized_backout<_NoThrowFwdIt> &) include\xmemory
# _Release() include\xmemory
# operator=(const _Uninitialized_backout_al<_Alloc> &) include\xmemory
# _Release() include\xmemory
# _Extract(const _Key &) include\xmemory
# _Extract(const _Key &, const _Second &) include\xmemory
# _Extract(const pair<_First, _Second> &) include\xmemory
# _Get_value() include\xmemory
# _Get_value() include\xmemory
# operator=(const _Alloc_temporary2<_Alloc> &) include\xmemory
# operator=(const _Optimistic_temporary_buffer<_Ty> &) include\algorithm
# min() include\algorithm
# max() include\algorithm
# operator()() include\algorithm
# CreateObject() include\afx.h
# IsDerivedFrom(const CRuntimeClass *) include\afx.h
# FromName(LPCSTR) include\afx.h
# FromName(LPCWSTR) include\afx.h
# CreateObject(LPCSTR) include\afx.h
# CreateObject(LPCWSTR) include\afx.h
# Store(CArchive &) include\afx.h
# Load(CArchive &, UINT *) include\afx.h
# GetRuntimeClass() include\afx.h
# operator new(size_t) include\afx.h
# operator new(size_t, void *) include\afx.h
# operator delete(void *) include\afx.h
# operator delete(void *, void *) include\afx.h
# operator=(const CObject &) include\afx.h
# IsSerializable() include\afx.h
# IsKindOf(const CRuntimeClass *) include\afx.h
# Serialize(CArchive &) include\afx.h
# GetRuntimeClass() include\afx.h
# Delete() include\afx.h
# GetErrorMessage(LPTSTR, UINT, PUINT) include\afx.h
# GetErrorMessage(LPTSTR, UINT, PUINT) include\afx.h
# ReportError(UINT, UINT) include\afx.h
# QueryInterface(const IID &, void **) um\unknwnbase.h
# AddRef() um\unknwnbase.h
# Release() um\unknwnbase.h
# Begin_QueryInterface(const IID &) um\unknwnbase.h
# Finish_QueryInterface(void **) um\unknwnbase.h
# Begin_AddRef() um\unknwnbase.h
# Finish_AddRef() um\unknwnbase.h
# Begin_Release() um\unknwnbase.h
# Finish_Release() um\unknwnbase.h
# CreateInstance(IUnknown *, const IID &, void **) um\unknwnbase.h
# LockServer(BOOL) um\unknwnbase.h
# GetUnmarshalClass(const IID &, void *, DWORD, void *, DWORD, CLSID *) um\objidlbase.h
# GetMarshalSizeMax(const IID &, void *, DWORD, void *, DWORD, DWORD *) um\objidlbase.h
# MarshalInterface(IStream *, const IID &, void *, DWORD, void *, DWORD) um\objidlbase.h
# UnmarshalInterface(IStream *, const IID &, void **) um\objidlbase.h
# ReleaseMarshalData(IStream *) um\objidlbase.h
# DisconnectObject(DWORD) um\objidlbase.h
# HandleActivation(DWORD, const IID &, CLSID *) um\objidlbase.h
# Alloc(SIZE_T) um\objidlbase.h
# Realloc(void *, SIZE_T) um\objidlbase.h
# Free(void *) um\objidlbase.h
# GetSize(void *) um\objidlbase.h
# DidAlloc(void *) um\objidlbase.h
# HeapMinimize() um\objidlbase.h
# GetClassForHandler(DWORD, void *, CLSID *) um\objidlbase.h
# AddConnection(DWORD, DWORD) um\objidlbase.h
# ReleaseConnection(DWORD, DWORD, BOOL) um\objidlbase.h
# QueryMultipleInterfaces(ULONG, MULTI_QI *) um\objidlbase.h
# Begin_QueryMultipleInterfaces(ULONG, MULTI_QI *) um\objidlbase.h
# Finish_QueryMultipleInterfaces(MULTI_QI *) um\objidlbase.h
# QueryInternalInterface(const IID &, void **) um\objidlbase.h
# Next(ULONG, IUnknown **, ULONG *) um\objidlbase.h
# Skip(ULONG) um\objidlbase.h
# Reset() um\objidlbase.h
# Clone(IEnumUnknown **) um\objidlbase.h
# Next(ULONG, LPOLESTR *, ULONG *) um\objidlbase.h
# Skip(ULONG) um\objidlbase.h
# Reset() um\objidlbase.h
# Clone(IEnumString **) um\objidlbase.h
# Read(void *, ULONG, ULONG *) um\objidlbase.h
# Write(const void *, ULONG, ULONG *) um\objidlbase.h
# Seek(LARGE_INTEGER, DWORD, ULARGE_INTEGER *) um\objidlbase.h
# SetSize(ULARGE_INTEGER) um\objidlbase.h
# CopyTo(IStream *, ULARGE_INTEGER, ULARGE_INTEGER *, ULARGE_INTEGER *) um\objidlbase.h
# Commit(DWORD) um\objidlbase.h
# Revert() um\objidlbase.h
# LockRegion(ULARGE_INTEGER, ULARGE_INTEGER, DWORD) um\objidlbase.h
# UnlockRegion(ULARGE_INTEGER, ULARGE_INTEGER, DWORD) um\objidlbase.h
# Stat(STATSTG *, DWORD) um\objidlbase.h
# Clone(IStream **) um\objidlbase.h
# GetBuffer(RPCOLEMESSAGE *, const IID &) um\objidlbase.h
# SendReceive(RPCOLEMESSAGE *, ULONG *) um\objidlbase.h
# FreeBuffer(RPCOLEMESSAGE *) um\objidlbase.h
# GetDestCtx(DWORD *, void **) um\objidlbase.h
# IsConnected() um\objidlbase.h
# GetProtocolVersion(DWORD *) um\objidlbase.h
# Send(RPCOLEMESSAGE *, ISynchronize *, ULONG *) um\objidlbase.h
# Receive(RPCOLEMESSAGE *, ULONG *) um\objidlbase.h
# GetDestCtxEx(RPCOLEMESSAGE *, DWORD *, void **) um\objidlbase.h
# Send(RPCOLEMESSAGE *, ULONG *) um\objidlbase.h
# Receive(RPCOLEMESSAGE *, ULONG, ULONG *) um\objidlbase.h
# Cancel(RPCOLEMESSAGE *) um\objidlbase.h
# GetCallContext(RPCOLEMESSAGE *, const IID &, void **) um\objidlbase.h
# GetDestCtxEx(RPCOLEMESSAGE *, DWORD *, void **) um\objidlbase.h
# GetState(RPCOLEMESSAGE *, DWORD *) um\objidlbase.h
# RegisterAsync(RPCOLEMESSAGE *, IAsyncManager *) um\objidlbase.h
# NegotiateSyntax(RPCOLEMESSAGE *) um\objidlbase.h
# Connect(IRpcChannelBuffer *) um\objidlbase.h
# Disconnect() um\objidlbase.h
# Connect(IUnknown *) um\objidlbase.h
# Disconnect() um\objidlbase.h
# Invoke(RPCOLEMESSAGE *, IRpcChannelBuffer *) um\objidlbase.h
# IsIIDSupported(const IID &) um\objidlbase.h
# CountRefs() um\objidlbase.h
# DebugServerQueryInterface(void **) um\objidlbase.h
# DebugServerRelease(void *) um\objidlbase.h
# CreateProxy(IUnknown *, const IID &, IRpcProxyBuffer **, void **) um\objidlbase.h
# CreateStub(const IID &, IUnknown *, IRpcStubBuffer **) um\objidlbase.h
# ClientGetSize(const GUID &, const IID &, ULONG *) um\objidlbase.h
# ClientFillBuffer(const GUID &, const IID &, ULONG *, void *) um\objidlbase.h
# ClientNotify(const GUID &, const IID &, ULONG, void *, DWORD, HRESULT) um\objidlbase.h
# ServerNotify(const GUID &, const IID &, ULONG, void *, DWORD) um\objidlbase.h
# ServerGetSize(const GUID &, const IID &, HRESULT, ULONG *) um\objidlbase.h
# ServerFillBuffer(const GUID &, const IID &, ULONG *, void *, HRESULT) um\objidlbase.h
# QueryBlanket(IUnknown *, DWORD *, DWORD *, OLECHAR **, DWORD *, DWORD *, void **, DWORD *) um\objidlbase.h
# SetBlanket(IUnknown *, DWORD, DWORD, OLECHAR *, DWORD, DWORD, void *, DWORD) um\objidlbase.h
# CopyProxy(IUnknown *, IUnknown **) um\objidlbase.h
# QueryBlanket(DWORD *, DWORD *, OLECHAR **, DWORD *, DWORD *, void **, DWORD *) um\objidlbase.h
# ImpersonateClient() um\objidlbase.h
# RevertToSelf() um\objidlbase.h
# IsImpersonating() um\objidlbase.h
# Set(IUnknown *, RPCOPT_PROPERTIES, ULONG_PTR) um\objidlbase.h
# Query(IUnknown *, RPCOPT_PROPERTIES, ULONG_PTR *) um\objidlbase.h
# Set(GLOBALOPT_PROPERTIES, ULONG_PTR) um\objidlbase.h
# Query(GLOBALOPT_PROPERTIES, ULONG_PTR *) um\objidlbase.h
# LoadDllServer(const IID &) um\objidlbase.h
# FreeSurrogate() um\objidlbase.h
# RegisterInterfaceInGlobal(IUnknown *, const IID &, DWORD *) um\objidlbase.h
# RevokeInterfaceFromGlobal(DWORD) um\objidlbase.h
# GetInterfaceFromGlobal(DWORD, const IID &, void **) um\objidlbase.h
# Wait(DWORD, DWORD) um\objidlbase.h
# Signal() um\objidlbase.h
# Reset() um\objidlbase.h
# GetHandle(HANDLE *) um\objidlbase.h
# SetEventHandle(HANDLE *) um\objidlbase.h
# AddSynchronize(ISynchronize *) um\objidlbase.h
# WaitMultiple(DWORD, DWORD, ISynchronize **) um\objidlbase.h
# ReleaseMutex() um\objidlbase.h
# Cancel(ULONG) um\objidlbase.h
# TestCancel() um\objidlbase.h
# CompleteCall(HRESULT) um\objidlbase.h
# GetCallContext(const IID &, void **) um\objidlbase.h
# GetState(ULONG *) um\objidlbase.h
# CreateCall(const IID &, IUnknown *, const IID &, IUnknown **) um\objidlbase.h
# GetDCOMProtocolVersion(DWORD *) um\objidlbase.h
# GetIIDFromOBJREF(void *, IID **) um\objidlbase.h
# ReleaseMarshalBuffer(RPCOLEMESSAGE *, DWORD, IUnknown *) um\objidlbase.h
# WaitMultiple(DWORD, ISynchronize **) um\objidlbase.h
# AddSynchronize(ISynchronize *) um\objidlbase.h
# EnableCOMDynamicAddrTracking() um\objidlbase.h
# DisableCOMDynamicAddrTracking() um\objidlbase.h
# GetCurrentAddrExclusionList(const IID &, void **) um\objidlbase.h
# UpdateAddrExclusionList(IUnknown *) um\objidlbase.h
# Pull(BYTE *, ULONG, ULONG *) um\objidlbase.h
# Push(BYTE *, ULONG) um\objidlbase.h
# Begin_Pull(ULONG) um\objidlbase.h
# Finish_Pull(BYTE *, ULONG *) um\objidlbase.h
# Begin_Push(BYTE *, ULONG) um\objidlbase.h
# Finish_Push() um\objidlbase.h
# Pull(LONG *, ULONG, ULONG *) um\objidlbase.h
# Push(LONG *, ULONG) um\objidlbase.h
# Begin_Pull(ULONG) um\objidlbase.h
# Finish_Pull(LONG *, ULONG *) um\objidlbase.h
# Begin_Push(LONG *, ULONG) um\objidlbase.h
# Finish_Push() um\objidlbase.h
# Pull(DOUBLE *, ULONG, ULONG *) um\objidlbase.h
# Push(DOUBLE *, ULONG) um\objidlbase.h
# Begin_Pull(ULONG) um\objidlbase.h
# Finish_Pull(DOUBLE *, ULONG *) um\objidlbase.h
# Begin_Push(DOUBLE *, ULONG) um\objidlbase.h
# Finish_Push() um\objidlbase.h
# GetCurrentApartmentType(APTTYPE *) um\objidlbase.h
# GetCurrentThreadType(THDTYPE *) um\objidlbase.h
# GetCurrentLogicalThreadId(GUID *) um\objidlbase.h
# SetCurrentLogicalThreadId(const GUID &) um\objidlbase.h
# ResetInitializerTimeout(DWORD) um\objidlbase.h
# GetMarshalingContextAttribute(CO_MARSHALING_CONTEXT_ATTRIBUTES, ULONG_PTR *) um\objidlbase.h
# Resolve(const IID &, void **) um\objidlbase.h
# RegisterObject(const IID &, LPCWSTR, IUnknown *, MachineGlobalObjectTableRegistrationToken *) um\objidlbase.h
# GetObjectA(const IID &, LPCWSTR, const IID &, void **) um\objidlbase.h
# RevokeObject(MachineGlobalObjectTableRegistrationToken) um\objidlbase.h
# PreAlloc(SIZE_T) um\objidl.h
# PostAlloc(void *) um\objidl.h
# PreFree(void *, BOOL) um\objidl.h
# PostFree(BOOL) um\objidl.h
# PreRealloc(void *, SIZE_T, void **, BOOL) um\objidl.h
# PostRealloc(void *, BOOL) um\objidl.h
# PreGetSize(void *, BOOL) um\objidl.h
# PostGetSize(SIZE_T, BOOL) um\objidl.h
# PreDidAlloc(void *, BOOL) um\objidl.h
# PostDidAlloc(void *, BOOL, int) um\objidl.h
# PreHeapMinimize() um\objidl.h
# PostHeapMinimize() um\objidl.h
# RegisterObjectBound(IUnknown *) um\objidl.h
# RevokeObjectBound(IUnknown *) um\objidl.h
# ReleaseBoundObjects() um\objidl.h
# SetBindOptions(BIND_OPTS *) um\objidl.h
# GetBindOptions(BIND_OPTS *) um\objidl.h
# GetRunningObjectTable(IRunningObjectTable **) um\objidl.h
# RegisterObjectParam(LPOLESTR, IUnknown *) um\objidl.h
# GetObjectParam(LPOLESTR, IUnknown **) um\objidl.h
# EnumObjectParam(IEnumString **) um\objidl.h
# RevokeObjectParam(LPOLESTR) um\objidl.h
# Next(ULONG, IMoniker **, ULONG *) um\objidl.h
# Skip(ULONG) um\objidl.h
# Reset() um\objidl.h
# Clone(IEnumMoniker **) um\objidl.h
# GetRunningClass(LPCLSID) um\objidl.h
# Run(LPBINDCTX) um\objidl.h
# IsRunning() um\objidl.h
# LockRunning(BOOL, BOOL) um\objidl.h
# SetContainedObject(BOOL) um\objidl.h
# Register(DWORD, IUnknown *, IMoniker *, DWORD *) um\objidl.h
# Revoke(DWORD) um\objidl.h
# IsRunning(IMoniker *) um\objidl.h
# GetObjectA(IMoniker *, IUnknown **) um\objidl.h
# NoteChangeTime(DWORD, FILETIME *) um\objidl.h
# GetTimeOfLastChange(IMoniker *, FILETIME *) um\objidl.h
# EnumRunning(IEnumMoniker **) um\objidl.h
# GetClassID(CLSID *) um\objidl.h
# IsDirty() um\objidl.h
# Load(IStream *) um\objidl.h
# Save(IStream *, BOOL) um\objidl.h
# GetSizeMax(ULARGE_INTEGER *) um\objidl.h
# BindToObject(IBindCtx *, IMoniker *, const IID &, void **) um\objidl.h
# BindToStorage(IBindCtx *, IMoniker *, const IID &, void **) um\objidl.h
# Reduce(IBindCtx *, DWORD, IMoniker **, IMoniker **) um\objidl.h
# ComposeWith(IMoniker *, BOOL, IMoniker **) um\objidl.h
# Enum(BOOL, IEnumMoniker **) um\objidl.h
# IsEqual(IMoniker *) um\objidl.h
# Hash(DWORD *) um\objidl.h
# IsRunning(IBindCtx *, IMoniker *, IMoniker *) um\objidl.h
# GetTimeOfLastChange(IBindCtx *, IMoniker *, FILETIME *) um\objidl.h
# Inverse(IMoniker **) um\objidl.h
# CommonPrefixWith(IMoniker *, IMoniker **) um\objidl.h
# RelativePathTo(IMoniker *, IMoniker **) um\objidl.h
# GetDisplayName(IBindCtx *, IMoniker *, LPOLESTR *) um\objidl.h
# ParseDisplayName(IBindCtx *, IMoniker *, LPOLESTR, ULONG *, IMoniker **) um\objidl.h
# IsSystemMoniker(DWORD *) um\objidl.h
# GetComparisonData(byte *, ULONG, ULONG *) um\objidl.h
# Next(ULONG, STATSTG *, ULONG *) um\objidl.h
# Skip(ULONG) um\objidl.h
# Reset() um\objidl.h
# Clone(IEnumSTATSTG **) um\objidl.h
# CreateStream(const OLECHAR *, DWORD, DWORD, DWORD, IStream **) um\objidl.h
# OpenStream(const OLECHAR *, void *, DWORD, DWORD, IStream **) um\objidl.h
# CreateStorage(const OLECHAR *, DWORD, DWORD, DWORD, IStorage **) um\objidl.h
# OpenStorage(const OLECHAR *, IStorage *, DWORD, SNB, DWORD, IStorage **) um\objidl.h
# CopyTo(DWORD, const IID *, SNB, IStorage *) um\objidl.h
# MoveElementTo(const OLECHAR *, IStorage *, const OLECHAR *, DWORD) um\objidl.h
# Commit(DWORD) um\objidl.h
# Revert() um\objidl.h
# EnumElements(DWORD, void *, DWORD, IEnumSTATSTG **) um\objidl.h
# DestroyElement(const OLECHAR *) um\objidl.h
# RenameElement(const OLECHAR *, const OLECHAR *) um\objidl.h
# SetElementTimes(const OLECHAR *, const FILETIME *, const FILETIME *, const FILETIME *) um\objidl.h
# SetClass(const IID &) um\objidl.h
# SetStateBits(DWORD, DWORD) um\objidl.h
# Stat(STATSTG *, DWORD) um\objidl.h
# IsDirty() um\objidl.h
# Load(LPCOLESTR, DWORD) um\objidl.h
# Save(LPCOLESTR, BOOL) um\objidl.h
# SaveCompleted(LPCOLESTR) um\objidl.h
# GetCurFile(LPOLESTR *) um\objidl.h
# IsDirty() um\objidl.h
# InitNew(IStorage *) um\objidl.h
# Load(IStorage *) um\objidl.h
# Save(IStorage *, BOOL) um\objidl.h
# SaveCompleted(IStorage *) um\objidl.h
# HandsOffStorage() um\objidl.h
# ReadAt(ULARGE_INTEGER, void *, ULONG, ULONG *) um\objidl.h
# WriteAt(ULARGE_INTEGER, const void *, ULONG, ULONG *) um\objidl.h
# Flush() um\objidl.h
# SetSize(ULARGE_INTEGER) um\objidl.h
# LockRegion(ULARGE_INTEGER, ULARGE_INTEGER, DWORD) um\objidl.h
# UnlockRegion(ULARGE_INTEGER, ULARGE_INTEGER, DWORD) um\objidl.h
# Stat(STATSTG *, DWORD) um\objidl.h
# Next(ULONG, FORMATETC *, ULONG *) um\objidl.h
# Skip(ULONG) um\objidl.h
# Reset() um\objidl.h
# Clone(IEnumFORMATETC **) um\objidl.h
# Next(ULONG, STATDATA *, ULONG *) um\objidl.h
# Skip(ULONG) um\objidl.h
# Reset() um\objidl.h
# Clone(IEnumSTATDATA **) um\objidl.h
# SwitchToFile(LPOLESTR) um\objidl.h
# OnDataChange(FORMATETC *, STGMEDIUM *) um\objidl.h
# OnViewChange(DWORD, LONG) um\objidl.h
# OnRename(IMoniker *) um\objidl.h
# OnSave() um\objidl.h
# OnClose() um\objidl.h
# Begin_OnDataChange(FORMATETC *, STGMEDIUM *) um\objidl.h
# Finish_OnDataChange() um\objidl.h
# Begin_OnViewChange(DWORD, LONG) um\objidl.h
# Finish_OnViewChange() um\objidl.h
# Begin_OnRename(IMoniker *) um\objidl.h
# Finish_OnRename() um\objidl.h
# Begin_OnSave() um\objidl.h
# Finish_OnSave() um\objidl.h
# Begin_OnClose() um\objidl.h
# Finish_OnClose() um\objidl.h
# OnLinkSrcChange(IMoniker *) um\objidl.h
# Begin_OnLinkSrcChange(IMoniker *) um\objidl.h
# Finish_OnLinkSrcChange() um\objidl.h
# GetData(FORMATETC *, STGMEDIUM *) um\objidl.h
# GetDataHere(FORMATETC *, STGMEDIUM *) um\objidl.h
# QueryGetData(FORMATETC *) um\objidl.h
# GetCanonicalFormatEtc(FORMATETC *, FORMATETC *) um\objidl.h
# SetData(FORMATETC *, STGMEDIUM *, BOOL) um\objidl.h
# EnumFormatEtc(DWORD, IEnumFORMATETC **) um\objidl.h
# DAdvise(FORMATETC *, DWORD, IAdviseSink *, DWORD *) um\objidl.h
# DUnadvise(DWORD) um\objidl.h
# EnumDAdvise(IEnumSTATDATA **) um\objidl.h
# Advise(IDataObject *, FORMATETC *, DWORD, IAdviseSink *, DWORD *) um\objidl.h
# Unadvise(DWORD) um\objidl.h
# EnumAdvise(IEnumSTATDATA **) um\objidl.h
# SendOnDataChange(IDataObject *, DWORD, DWORD) um\objidl.h
# HandleInComingCall(DWORD, HTASK, DWORD, LPINTERFACEINFO) um\objidl.h
# RetryRejectedCall(HTASK, DWORD, DWORD) um\objidl.h
# MessagePending(HTASK, DWORD, DWORD) um\objidl.h
# GetClassObject(const IID &, DWORD, LCID, const IID &, void **) um\objidl.h
# FillAppend(const void *, ULONG, ULONG *) um\objidl.h
# FillAt(ULARGE_INTEGER, const void *, ULONG, ULONG *) um\objidl.h
# SetFillSize(ULARGE_INTEGER) um\objidl.h
# Terminate(BOOL) um\objidl.h
# OnProgress(DWORD, DWORD, BOOL, BOOL) um\objidl.h
# LayoutScript(StorageLayout *, DWORD, DWORD) um\objidl.h
# BeginMonitor() um\objidl.h
# EndMonitor() um\objidl.h
# ReLayoutDocfile(OLECHAR *) um\objidl.h
# ReLayoutDocfileOnILockBytes(ILockBytes *) um\objidl.h
# Lock(DWORD) um\objidl.h
# Unlock() um\objidl.h
# SuppressChanges(DWORD, DWORD) um\objidl.h
# CreateStorageEx(LPCWSTR, DWORD, DWORD, DWORD, const IID &, void **) um\objidl.h
# OpenStorageEx(LPCWSTR, DWORD, DWORD, DWORD, const IID &, void **) um\objidl.h
# WaitForWriteAccess(DWORD) um\objidl.h
# ReleaseWriteAccess() um\objidl.h
# HaveWriteAccess() um\objidl.h
# AsyncGetClassBits(const IID &, LPCWSTR, LPCWSTR, DWORD, DWORD, LPCWSTR, IBindCtx *, DWORD, const IID &, DWORD) um\objidl.h
# AllowForegroundTransfer(void *) um\objidl.h
# ExtractThumbnail(IStorage *, ULONG, ULONG, ULONG *, ULONG *, HBITMAP *) um\objidl.h
# OnFileUpdated(IStorage *) um\objidl.h
# Dummy(HICON, HDC) um\objidl.h
# AddRefOnProcess() um\objidl.h
# ReleaseRefOnProcess() um\objidl.h
# Init(const GUID &, IProcessLock *, BOOL *) um\objidl.h
# ApplicationLaunch(const GUID &, ApplicationType) um\objidl.h
# ApplicationFree(const GUID &) um\objidl.h
# CatalogRefresh(ULONG) um\objidl.h
# ProcessShutdown(ShutdownType) um\objidl.h
# PreInitialize(DWORD, DWORD) um\objidl.h
# PostInitialize(HRESULT, DWORD, DWORD) um\objidl.h
# PreUninitialize(DWORD) um\objidl.h
# PostUninitialize(DWORD) um\objidl.h
# OnUninitialize(UINT64) um\objidl.h
# SetGuid(const GUID &) um\oaidl.h
# SetTypeFlags(UINT) um\oaidl.h
# SetDocString(LPOLESTR) um\oaidl.h
# SetHelpContext(DWORD) um\oaidl.h
# SetVersion(WORD, WORD) um\oaidl.h
# AddRefTypeInfo(ITypeInfo *, HREFTYPE *) um\oaidl.h
# AddFuncDesc(UINT, FUNCDESC *) um\oaidl.h
# AddImplType(UINT, HREFTYPE) um\oaidl.h
# SetImplTypeFlags(UINT, INT) um\oaidl.h
# SetAlignment(WORD) um\oaidl.h
# SetSchema(LPOLESTR) um\oaidl.h
# AddVarDesc(UINT, VARDESC *) um\oaidl.h
# SetFuncAndParamNames(UINT, LPOLESTR *, UINT) um\oaidl.h
# SetVarName(UINT, LPOLESTR) um\oaidl.h
# SetTypeDescAlias(TYPEDESC *) um\oaidl.h
# DefineFuncAsDllEntry(UINT, LPOLESTR, LPOLESTR) um\oaidl.h
# SetFuncDocString(UINT, LPOLESTR) um\oaidl.h
# SetVarDocString(UINT, LPOLESTR) um\oaidl.h
# SetFuncHelpContext(UINT, DWORD) um\oaidl.h
# SetVarHelpContext(UINT, DWORD) um\oaidl.h
# SetMops(UINT, BSTR) um\oaidl.h
# SetTypeIdldesc(IDLDESC *) um\oaidl.h
# LayOut() um\oaidl.h
# DeleteFuncDesc(UINT) um\oaidl.h
# DeleteFuncDescByMemId(MEMBERID, INVOKEKIND) um\oaidl.h
# DeleteVarDesc(UINT) um\oaidl.h
# DeleteVarDescByMemId(MEMBERID) um\oaidl.h
# DeleteImplType(UINT) um\oaidl.h
# SetCustData(const GUID &, VARIANT *) um\oaidl.h
# SetFuncCustData(UINT, const GUID &, VARIANT *) um\oaidl.h
# SetParamCustData(UINT, UINT, const GUID &, VARIANT *) um\oaidl.h
# SetVarCustData(UINT, const GUID &, VARIANT *) um\oaidl.h
# SetImplTypeCustData(UINT, const GUID &, VARIANT *) um\oaidl.h
# SetHelpStringContext(ULONG) um\oaidl.h
# SetFuncHelpStringContext(UINT, ULONG) um\oaidl.h
# SetVarHelpStringContext(UINT, ULONG) um\oaidl.h
# Invalidate() um\oaidl.h
# SetName(LPOLESTR) um\oaidl.h
# CreateTypeInfo(LPOLESTR, TYPEKIND, ICreateTypeInfo **) um\oaidl.h
# SetName(LPOLESTR) um\oaidl.h
# SetVersion(WORD, WORD) um\oaidl.h
# SetGuid(const GUID &) um\oaidl.h
# SetDocString(LPOLESTR) um\oaidl.h
# SetHelpFileName(LPOLESTR) um\oaidl.h
# SetHelpContext(DWORD) um\oaidl.h
# SetLcid(LCID) um\oaidl.h
# SetLibFlags(UINT) um\oaidl.h
# SaveAllChanges() um\oaidl.h
# DeleteTypeInfo(LPOLESTR) um\oaidl.h
# SetCustData(const GUID &, VARIANT *) um\oaidl.h
# SetHelpStringContext(ULONG) um\oaidl.h
# SetHelpStringDll(LPOLESTR) um\oaidl.h
# GetTypeInfoCount(UINT *) um\oaidl.h
# GetTypeInfo(UINT, LCID, ITypeInfo **) um\oaidl.h
# GetIDsOfNames(const IID &, LPOLESTR *, UINT, LCID, DISPID *) um\oaidl.h
# Invoke(DISPID, const IID &, LCID, WORD, DISPPARAMS *, VARIANT *, EXCEPINFO *, UINT *) um\oaidl.h
# Next(ULONG, VARIANT *, ULONG *) um\oaidl.h
# Skip(ULONG) um\oaidl.h
# Reset() um\oaidl.h
# Clone(IEnumVARIANT **) um\oaidl.h
# Bind(LPOLESTR, ULONG, WORD, ITypeInfo **, DESCKIND *, BINDPTR *) um\oaidl.h
# BindType(LPOLESTR, ULONG, ITypeInfo **, ITypeComp **) um\oaidl.h
# GetTypeAttr(TYPEATTR **) um\oaidl.h
# GetTypeComp(ITypeComp **) um\oaidl.h
# GetFuncDesc(UINT, FUNCDESC **) um\oaidl.h
# GetVarDesc(UINT, VARDESC **) um\oaidl.h
# GetNames(MEMBERID, BSTR *, UINT, UINT *) um\oaidl.h
# GetRefTypeOfImplType(UINT, HREFTYPE *) um\oaidl.h
# GetImplTypeFlags(UINT, INT *) um\oaidl.h
# GetIDsOfNames(LPOLESTR *, UINT, MEMBERID *) um\oaidl.h
# Invoke(PVOID, MEMBERID, WORD, DISPPARAMS *, VARIANT *, EXCEPINFO *, UINT *) um\oaidl.h
# GetDocumentation(MEMBERID, BSTR *, BSTR *, DWORD *, BSTR *) um\oaidl.h
# GetDllEntry(MEMBERID, INVOKEKIND, BSTR *, BSTR *, WORD *) um\oaidl.h
# GetRefTypeInfo(HREFTYPE, ITypeInfo **) um\oaidl.h
# AddressOfMember(MEMBERID, INVOKEKIND, PVOID *) um\oaidl.h
# CreateInstance(IUnknown *, const IID &, PVOID *) um\oaidl.h
# GetMops(MEMBERID, BSTR *) um\oaidl.h
# GetContainingTypeLib(ITypeLib **, UINT *) um\oaidl.h
# ReleaseTypeAttr(TYPEATTR *) um\oaidl.h
# ReleaseFuncDesc(FUNCDESC *) um\oaidl.h
# ReleaseVarDesc(VARDESC *) um\oaidl.h
# GetTypeKind(TYPEKIND *) um\oaidl.h
# GetTypeFlags(ULONG *) um\oaidl.h
# GetFuncIndexOfMemId(MEMBERID, INVOKEKIND, UINT *) um\oaidl.h
# GetVarIndexOfMemId(MEMBERID, UINT *) um\oaidl.h
# GetCustData(const GUID &, VARIANT *) um\oaidl.h
# GetFuncCustData(UINT, const GUID &, VARIANT *) um\oaidl.h
# GetParamCustData(UINT, UINT, const GUID &, VARIANT *) um\oaidl.h
# GetVarCustData(UINT, const GUID &, VARIANT *) um\oaidl.h
# GetImplTypeCustData(UINT, const GUID &, VARIANT *) um\oaidl.h
# GetDocumentation2(MEMBERID, LCID, BSTR *, DWORD *, BSTR *) um\oaidl.h
# GetAllCustData(CUSTDATA *) um\oaidl.h
# GetAllFuncCustData(UINT, CUSTDATA *) um\oaidl.h
# GetAllParamCustData(UINT, UINT, CUSTDATA *) um\oaidl.h
# GetAllVarCustData(UINT, CUSTDATA *) um\oaidl.h
# GetAllImplTypeCustData(UINT, CUSTDATA *) um\oaidl.h
# GetTypeInfoCount() um\oaidl.h
# GetTypeInfo(UINT, ITypeInfo **) um\oaidl.h
# GetTypeInfoType(UINT, TYPEKIND *) um\oaidl.h
# GetTypeInfoOfGuid(const GUID &, ITypeInfo **) um\oaidl.h
# GetLibAttr(TLIBATTR **) um\oaidl.h
# GetTypeComp(ITypeComp **) um\oaidl.h
# GetDocumentation(INT, BSTR *, BSTR *, DWORD *, BSTR *) um\oaidl.h
# IsName(LPOLESTR, ULONG, BOOL *) um\oaidl.h
# FindName(LPOLESTR, ULONG, ITypeInfo **, MEMBERID *, USHORT *) um\oaidl.h
# ReleaseTLibAttr(TLIBATTR *) um\oaidl.h
# GetCustData(const GUID &, VARIANT *) um\oaidl.h
# GetLibStatistics(ULONG *, ULONG *) um\oaidl.h
# GetDocumentation2(INT, LCID, BSTR *, DWORD *, BSTR *) um\oaidl.h
# GetAllCustData(CUSTDATA *) um\oaidl.h
# RequestTypeChange(CHANGEKIND, ITypeInfo *, LPOLESTR, INT *) um\oaidl.h
# AfterTypeChange(CHANGEKIND, ITypeInfo *, LPOLESTR) um\oaidl.h
# GetGUID(GUID *) um\oaidl.h
# GetSource(BSTR *) um\oaidl.h
# GetDescription(BSTR *) um\oaidl.h
# GetHelpFile(BSTR *) um\oaidl.h
# GetHelpContext(DWORD *) um\oaidl.h
# SetGUID(const GUID &) um\oaidl.h
# SetSource(LPOLESTR) um\oaidl.h
# SetDescription(LPOLESTR) um\oaidl.h
# SetHelpFile(LPOLESTR) um\oaidl.h
# SetHelpContext(DWORD) um\oaidl.h
# InterfaceSupportsErrorInfo(const IID &) um\oaidl.h
# CreateFromTypeInfo(ITypeInfo *, const IID &, IUnknown **) um\oaidl.h
# Size(PVOID, DWORD, PVOID, ULONG *) um\oaidl.h
# Marshal(PVOID, DWORD, PVOID, ULONG, BYTE *, ULONG *) um\oaidl.h
# Unmarshal(PVOID, DWORD, ULONG, BYTE *, ULONG *) um\oaidl.h
# Free(PVOID) um\oaidl.h
# RecordInit(PVOID) um\oaidl.h
# RecordClear(PVOID) um\oaidl.h
# RecordCopy(PVOID, PVOID) um\oaidl.h
# GetGuid(GUID *) um\oaidl.h
# GetName(BSTR *) um\oaidl.h
# GetSize(ULONG *) um\oaidl.h
# GetTypeInfo(ITypeInfo **) um\oaidl.h
# GetField(PVOID, LPCOLESTR, VARIANT *) um\oaidl.h
# GetFieldNoCopy(PVOID, LPCOLESTR, VARIANT *, PVOID *) um\oaidl.h
# PutField(ULONG, PVOID, LPCOLESTR, VARIANT *) um\oaidl.h
# PutFieldNoCopy(ULONG, PVOID, LPCOLESTR, VARIANT *) um\oaidl.h
# GetFieldNames(ULONG *, BSTR *) um\oaidl.h
# IsMatchingType(IRecordInfo *) um\oaidl.h
# RecordCreate() um\oaidl.h
# RecordCreateCopy(PVOID, PVOID *) um\oaidl.h
# RecordDestroy(PVOID) um\oaidl.h
# AddError(LPCOLESTR, EXCEPINFO *) um\oaidl.h
# Read(LPCOLESTR, VARIANT *, IErrorLog *) um\oaidl.h
# Write(LPCOLESTR, VARIANT *) um\oaidl.h
# EnumTypeLibRegistrations(IEnumUnknown **) um\oaidl.h
# GetGuid(GUID *) um\oaidl.h
# GetVersion(BSTR *) um\oaidl.h
# GetLcid(LCID *) um\oaidl.h
# GetWin32Path(BSTR *) um\oaidl.h
# GetWin64Path(BSTR *) um\oaidl.h
# GetDisplayName(BSTR *) um\oaidl.h
# GetFlags(DWORD *) um\oaidl.h
# GetHelpDir(BSTR *) um\oaidl.h
# ReadMultiple(ULONG, const PROPSPEC *, PROPVARIANT *) um\propidlbase.h
# WriteMultiple(ULONG, const PROPSPEC *, const PROPVARIANT *, PROPID) um\propidlbase.h
# DeleteMultiple(ULONG, const PROPSPEC *) um\propidlbase.h
# ReadPropertyNames(ULONG, const PROPID *, LPOLESTR *) um\propidlbase.h
# WritePropertyNames(ULONG, const PROPID *, const LPOLESTR *) um\propidlbase.h
# DeletePropertyNames(ULONG, const PROPID *) um\propidlbase.h
# Commit(DWORD) um\propidlbase.h
# Revert() um\propidlbase.h
# Enum(IEnumSTATPROPSTG **) um\propidlbase.h
# SetTimes(const FILETIME *, const FILETIME *, const FILETIME *) um\propidlbase.h
# SetClass(const IID &) um\propidlbase.h
# Stat(STATPROPSETSTG *) um\propidlbase.h
# Create(const IID &, const CLSID *, DWORD, DWORD, IPropertyStorage **) um\propidlbase.h
# Open(const IID &, DWORD, IPropertyStorage **) um\propidlbase.h
# Delete(const IID &) um\propidlbase.h
# Enum(IEnumSTATPROPSETSTG **) um\propidlbase.h
# Next(ULONG, STATPROPSTG *, ULONG *) um\propidlbase.h
# Skip(ULONG) um\propidlbase.h
# Reset() um\propidlbase.h
# Clone(IEnumSTATPROPSTG **) um\propidlbase.h
# Next(ULONG, STATPROPSETSTG *, ULONG *) um\propidlbase.h
# Skip(ULONG) um\propidlbase.h
# Reset() um\propidlbase.h
# Clone(IEnumSTATPROPSETSTG **) um\propidlbase.h
# Advise(IAdviseSink *, DWORD *) um\oleidl.h
# Unadvise(DWORD) um\oleidl.h
# EnumAdvise(IEnumSTATDATA **) um\oleidl.h
# SendOnRename(IMoniker *) um\oleidl.h
# SendOnSave() um\oleidl.h
# SendOnClose() um\oleidl.h
# Cache(FORMATETC *, DWORD, DWORD *) um\oleidl.h
# Uncache(DWORD) um\oleidl.h
# EnumCache(IEnumSTATDATA **) um\oleidl.h
# InitCache(IDataObject *) um\oleidl.h
# SetData(FORMATETC *, STGMEDIUM *, BOOL) um\oleidl.h
# UpdateCache(LPDATAOBJECT, DWORD, LPVOID) um\oleidl.h
# DiscardCache(DWORD) um\oleidl.h
# OnRun(LPDATAOBJECT) um\oleidl.h
# OnStop() um\oleidl.h
# ParseDisplayName(IBindCtx *, LPOLESTR, ULONG *, IMoniker **) um\oleidl.h
# EnumObjects(DWORD, IEnumUnknown **) um\oleidl.h
# LockContainer(BOOL) um\oleidl.h
# SaveObject() um\oleidl.h
# GetMoniker(DWORD, DWORD, IMoniker **) um\oleidl.h
# GetContainer(IOleContainer **) um\oleidl.h
# ShowObject() um\oleidl.h
# OnShowWindow(BOOL) um\oleidl.h
# RequestNewObjectLayout() um\oleidl.h
# SetClientSite(IOleClientSite *) um\oleidl.h
# GetClientSite(IOleClientSite **) um\oleidl.h
# SetHostNames(LPCOLESTR, LPCOLESTR) um\oleidl.h
# Close(DWORD) um\oleidl.h
# SetMoniker(DWORD, IMoniker *) um\oleidl.h
# GetMoniker(DWORD, DWORD, IMoniker **) um\oleidl.h
# InitFromData(IDataObject *, BOOL, DWORD) um\oleidl.h
# GetClipboardData(DWORD, IDataObject **) um\oleidl.h
# DoVerb(LONG, LPMSG, IOleClientSite *, LONG, HWND, LPCRECT) um\oleidl.h
# EnumVerbs(IEnumOLEVERB **) um\oleidl.h
# Update() um\oleidl.h
# IsUpToDate() um\oleidl.h
# GetUserClassID(CLSID *) um\oleidl.h
# GetUserType(DWORD, LPOLESTR *) um\oleidl.h
# SetExtent(DWORD, SIZEL *) um\oleidl.h
# GetExtent(DWORD, SIZEL *) um\oleidl.h
# Advise(IAdviseSink *, DWORD *) um\oleidl.h
# Unadvise(DWORD) um\oleidl.h
# EnumAdvise(IEnumSTATDATA **) um\oleidl.h
# GetMiscStatus(DWORD, DWORD *) um\oleidl.h
# SetColorScheme(LOGPALETTE *) um\oleidl.h
# GetWindow(HWND *) um\oleidl.h
# ContextSensitiveHelp(BOOL) um\oleidl.h
# SetUpdateOptions(DWORD) um\oleidl.h
# GetUpdateOptions(DWORD *) um\oleidl.h
# SetSourceMoniker(IMoniker *, const IID &) um\oleidl.h
# GetSourceMoniker(IMoniker **) um\oleidl.h
# SetSourceDisplayName(LPCOLESTR) um\oleidl.h
# GetSourceDisplayName(LPOLESTR *) um\oleidl.h
# BindToSource(DWORD, IBindCtx *) um\oleidl.h
# BindIfRunning() um\oleidl.h
# GetBoundSource(IUnknown **) um\oleidl.h
# UnbindSource() um\oleidl.h
# Update(IBindCtx *) um\oleidl.h
# GetObjectA(LPOLESTR, DWORD, IBindCtx *, const IID &, void **) um\oleidl.h
# GetObjectStorage(LPOLESTR, IBindCtx *, const IID &, void **) um\oleidl.h
# IsRunning(LPOLESTR) um\oleidl.h
# GetBorder(LPRECT) um\oleidl.h
# RequestBorderSpace(LPCBORDERWIDTHS) um\oleidl.h
# SetBorderSpace(LPCBORDERWIDTHS) um\oleidl.h
# SetActiveObject(IOleInPlaceActiveObject *, LPCOLESTR) um\oleidl.h
# TranslateAcceleratorA(LPMSG) um\oleidl.h
# OnFrameWindowActivate(BOOL) um\oleidl.h
# OnDocWindowActivate(BOOL) um\oleidl.h
# ResizeBorder(LPCRECT, IOleInPlaceUIWindow *, BOOL) um\oleidl.h
# EnableModeless(BOOL) um\oleidl.h
# InsertMenus(HMENU, LPOLEMENUGROUPWIDTHS) um\oleidl.h
# SetMenu(HMENU, HOLEMENU, HWND) um\oleidl.h
# RemoveMenus(HMENU) um\oleidl.h
# SetStatusText(LPCOLESTR) um\oleidl.h
# EnableModeless(BOOL) um\oleidl.h
# TranslateAcceleratorA(LPMSG, WORD) um\oleidl.h
# InPlaceDeactivate() um\oleidl.h
# UIDeactivate() um\oleidl.h
# SetObjectRects(LPCRECT, LPCRECT) um\oleidl.h
# ReactivateAndUndo() um\oleidl.h
# CanInPlaceActivate() um\oleidl.h
# OnInPlaceActivate() um\oleidl.h
# OnUIActivate() um\oleidl.h
# GetWindowContext(IOleInPlaceFrame **, IOleInPlaceUIWindow **, LPRECT, LPRECT, LPOLEINPLACEFRAMEINFO) um\oleidl.h
# Scroll(SIZE) um\oleidl.h
# OnUIDeactivate(BOOL) um\oleidl.h
# OnInPlaceDeactivate() um\oleidl.h
# DiscardUndoState() um\oleidl.h
# DeactivateAndUndo() um\oleidl.h
# OnPosRectChange(LPCRECT) um\oleidl.h
# FContinue() um\oleidl.h
# Draw(DWORD, LONG, void *, DVTARGETDEVICE *, HDC, HDC, LPCRECTL, LPCRECTL, BOOL (*)(ULONG_PTR) __attribute__((stdcall)), ULONG_PTR) um\oleidl.h
# GetColorSet(DWORD, LONG, void *, DVTARGETDEVICE *, HDC, LOGPALETTE **) um\oleidl.h
# Freeze(DWORD, LONG, void *, DWORD *) um\oleidl.h
# Unfreeze(DWORD) um\oleidl.h
# SetAdvise(DWORD, DWORD, IAdviseSink *) um\oleidl.h
# GetAdvise(DWORD *, DWORD *, IAdviseSink **) um\oleidl.h
# GetExtent(DWORD, LONG, DVTARGETDEVICE *, LPSIZEL) um\oleidl.h
# QueryContinueDrag(BOOL, DWORD) um\oleidl.h
# GiveFeedback(DWORD) um\oleidl.h
# DragEnter(IDataObject *, DWORD, POINTL, DWORD *) um\oleidl.h
# DragOver(DWORD, POINTL, DWORD *) um\oleidl.h
# DragLeave() um\oleidl.h
# Drop(IDataObject *, DWORD, POINTL, DWORD *) um\oleidl.h
# DragEnterTarget(HWND) um\oleidl.h
# DragLeaveTarget() um\oleidl.h
# SetDropSourceEnterpriseId(LPCWSTR) um\oleidl.h
# IsEvaluatingEdpPolicy(BOOL *) um\oleidl.h
# Next(ULONG, LPOLEVERB, ULONG *) um\oleidl.h
# Skip(ULONG) um\oleidl.h
# Reset() um\oleidl.h
# Clone(IEnumOLEVERB **) um\oleidl.h
# QueryService(const GUID &, const IID &, void **) um\servprov.h
# hasFeature(BSTR, BSTR, VARIANT_BOOL *) um\msxml.h
# get_nodeName(BSTR *) um\msxml.h
# get_nodeValue(VARIANT *) um\msxml.h
# put_nodeValue(VARIANT) um\msxml.h
# get_nodeType(DOMNodeType *) um\msxml.h
# get_parentNode(IXMLDOMNode **) um\msxml.h
# get_childNodes(IXMLDOMNodeList **) um\msxml.h
# get_firstChild(IXMLDOMNode **) um\msxml.h
# get_lastChild(IXMLDOMNode **) um\msxml.h
# get_previousSibling(IXMLDOMNode **) um\msxml.h
# get_nextSibling(IXMLDOMNode **) um\msxml.h
# get_attributes(IXMLDOMNamedNodeMap **) um\msxml.h
# insertBefore(IXMLDOMNode *, VARIANT, IXMLDOMNode **) um\msxml.h
# replaceChild(IXMLDOMNode *, IXMLDOMNode *, IXMLDOMNode **) um\msxml.h
# removeChild(IXMLDOMNode *, IXMLDOMNode **) um\msxml.h
# appendChild(IXMLDOMNode *, IXMLDOMNode **) um\msxml.h
# hasChildNodes(VARIANT_BOOL *) um\msxml.h
# get_ownerDocument(IXMLDOMDocument **) um\msxml.h
# cloneNode(VARIANT_BOOL, IXMLDOMNode **) um\msxml.h
# get_nodeTypeString(BSTR *) um\msxml.h
# get_text(BSTR *) um\msxml.h
# put_text(BSTR) um\msxml.h
# get_specified(VARIANT_BOOL *) um\msxml.h
# get_definition(IXMLDOMNode **) um\msxml.h
# get_nodeTypedValue(VARIANT *) um\msxml.h
# put_nodeTypedValue(VARIANT) um\msxml.h
# get_dataType(VARIANT *) um\msxml.h
# put_dataType(BSTR) um\msxml.h
# get_xml(BSTR *) um\msxml.h
# transformNode(IXMLDOMNode *, BSTR *) um\msxml.h
# selectNodes(BSTR, IXMLDOMNodeList **) um\msxml.h
# selectSingleNode(BSTR, IXMLDOMNode **) um\msxml.h
# get_parsed(VARIANT_BOOL *) um\msxml.h
# get_namespaceURI(BSTR *) um\msxml.h
# get_prefix(BSTR *) um\msxml.h
# get_baseName(BSTR *) um\msxml.h
# transformNodeToObject(IXMLDOMNode *, VARIANT) um\msxml.h
# get_doctype(IXMLDOMDocumentType **) um\msxml.h
# get_implementation(IXMLDOMImplementation **) um\msxml.h
# get_documentElement(IXMLDOMElement **) um\msxml.h
# putref_documentElement(IXMLDOMElement *) um\msxml.h
# createElement(BSTR, IXMLDOMElement **) um\msxml.h
# createDocumentFragment(IXMLDOMDocumentFragment **) um\msxml.h
# createTextNode(BSTR, IXMLDOMText **) um\msxml.h
# createComment(BSTR, IXMLDOMComment **) um\msxml.h
# createCDATASection(BSTR, IXMLDOMCDATASection **) um\msxml.h
# createProcessingInstruction(BSTR, BSTR, IXMLDOMProcessingInstruction **) um\msxml.h
# createAttribute(BSTR, IXMLDOMAttribute **) um\msxml.h
# createEntityReference(BSTR, IXMLDOMEntityReference **) um\msxml.h
# getElementsByTagName(BSTR, IXMLDOMNodeList **) um\msxml.h
# createNode(VARIANT, BSTR, BSTR, IXMLDOMNode **) um\msxml.h
# nodeFromID(BSTR, IXMLDOMNode **) um\msxml.h
# load(VARIANT, VARIANT_BOOL *) um\msxml.h
# get_readyState(long *) um\msxml.h
# get_parseError(IXMLDOMParseError **) um\msxml.h
# get_url(BSTR *) um\msxml.h
# get_async(VARIANT_BOOL *) um\msxml.h
# put_async(VARIANT_BOOL) um\msxml.h
# abort() um\msxml.h
# loadXML(BSTR, VARIANT_BOOL *) um\msxml.h
# save(VARIANT) um\msxml.h
# get_validateOnParse(VARIANT_BOOL *) um\msxml.h
# put_validateOnParse(VARIANT_BOOL) um\msxml.h
# get_resolveExternals(VARIANT_BOOL *) um\msxml.h
# put_resolveExternals(VARIANT_BOOL) um\msxml.h
# get_preserveWhiteSpace(VARIANT_BOOL *) um\msxml.h
# put_preserveWhiteSpace(VARIANT_BOOL) um\msxml.h
# put_onreadystatechange(VARIANT) um\msxml.h
# put_ondataavailable(VARIANT) um\msxml.h
# put_ontransformnode(VARIANT) um\msxml.h
# get_item(long, IXMLDOMNode **) um\msxml.h
# get_length(long *) um\msxml.h
# nextNode(IXMLDOMNode **) um\msxml.h
# reset() um\msxml.h
# get__newEnum(IUnknown **) um\msxml.h
# getNamedItem(BSTR, IXMLDOMNode **) um\msxml.h
# setNamedItem(IXMLDOMNode *, IXMLDOMNode **) um\msxml.h
# removeNamedItem(BSTR, IXMLDOMNode **) um\msxml.h
# get_item(long, IXMLDOMNode **) um\msxml.h
# get_length(long *) um\msxml.h
# getQualifiedItem(BSTR, BSTR, IXMLDOMNode **) um\msxml.h
# removeQualifiedItem(BSTR, BSTR, IXMLDOMNode **) um\msxml.h
# nextNode(IXMLDOMNode **) um\msxml.h
# reset() um\msxml.h
# get__newEnum(IUnknown **) um\msxml.h
# get_data(BSTR *) um\msxml.h
# put_data(BSTR) um\msxml.h
# get_length(long *) um\msxml.h
# substringData(long, long, BSTR *) um\msxml.h
# appendData(BSTR) um\msxml.h
# insertData(long, BSTR) um\msxml.h
# deleteData(long, long) um\msxml.h
# replaceData(long, long, BSTR) um\msxml.h
# get_name(BSTR *) um\msxml.h
# get_value(VARIANT *) um\msxml.h
# put_value(VARIANT) um\msxml.h
# get_tagName(BSTR *) um\msxml.h
# getAttribute(BSTR, VARIANT *) um\msxml.h
# setAttribute(BSTR, VARIANT) um\msxml.h
# removeAttribute(BSTR) um\msxml.h
# getAttributeNode(BSTR, IXMLDOMAttribute **) um\msxml.h
# setAttributeNode(IXMLDOMAttribute *, IXMLDOMAttribute **) um\msxml.h
# removeAttributeNode(IXMLDOMAttribute *, IXMLDOMAttribute **) um\msxml.h
# getElementsByTagName(BSTR, IXMLDOMNodeList **) um\msxml.h
# normalize() um\msxml.h
# splitText(long, IXMLDOMText **) um\msxml.h
# get_target(BSTR *) um\msxml.h
# get_data(BSTR *) um\msxml.h
# put_data(BSTR) um\msxml.h
# get_name(BSTR *) um\msxml.h
# get_entities(IXMLDOMNamedNodeMap **) um\msxml.h
# get_notations(IXMLDOMNamedNodeMap **) um\msxml.h
# get_publicId(VARIANT *) um\msxml.h
# get_systemId(VARIANT *) um\msxml.h
# get_publicId(VARIANT *) um\msxml.h
# get_systemId(VARIANT *) um\msxml.h
# get_notationName(BSTR *) um\msxml.h
# get_errorCode(long *) um\msxml.h
# get_url(BSTR *) um\msxml.h
# get_reason(BSTR *) um\msxml.h
# get_srcText(BSTR *) um\msxml.h
# get_line(long *) um\msxml.h
# get_linepos(long *) um\msxml.h
# get_filepos(long *) um\msxml.h
# uniqueID(IXMLDOMNode *, long *) um\msxml.h
# depth(IXMLDOMNode *, long *) um\msxml.h
# childNumber(IXMLDOMNode *, long *) um\msxml.h
# ancestorChildNumber(BSTR, IXMLDOMNode *, long *) um\msxml.h
# absoluteChildNumber(IXMLDOMNode *, long *) um\msxml.h
# formatIndex(long, BSTR, BSTR *) um\msxml.h
# formatNumber(double, BSTR, BSTR *) um\msxml.h
# formatDate(VARIANT, BSTR, VARIANT, BSTR *) um\msxml.h
# formatTime(VARIANT, BSTR, VARIANT, BSTR *) um\msxml.h
# open(BSTR, BSTR, VARIANT, VARIANT, VARIANT) um\msxml.h
# setRequestHeader(BSTR, BSTR) um\msxml.h
# getResponseHeader(BSTR, BSTR *) um\msxml.h
# getAllResponseHeaders(BSTR *) um\msxml.h
# send(VARIANT) um\msxml.h
# abort() um\msxml.h
# get_status(long *) um\msxml.h
# get_statusText(BSTR *) um\msxml.h
# get_responseXML(IDispatch **) um\msxml.h
# get_responseText(BSTR *) um\msxml.h
# get_responseBody(VARIANT *) um\msxml.h
# get_responseStream(VARIANT *) um\msxml.h
# get_readyState(long *) um\msxml.h
# put_onreadystatechange(IDispatch *) um\msxml.h
# get_XMLDocument(IXMLDOMDocument **) um\msxml.h
# put_XMLDocument(IXMLDOMDocument *) um\msxml.h
# get_JavaDSOCompatible(BOOL *) um\msxml.h
# put_JavaDSOCompatible(BOOL) um\msxml.h
# get_readyState(long *) um\msxml.h
# put_length(long) um\msxml.h
# get_length(long *) um\msxml.h
# get__newEnum(IUnknown **) um\msxml.h
# item(VARIANT, VARIANT, IDispatch **) um\msxml.h
# get_root(IXMLElement **) um\msxml.h
# get_fileSize(BSTR *) um\msxml.h
# get_fileModifiedDate(BSTR *) um\msxml.h
# get_fileUpdatedDate(BSTR *) um\msxml.h
# get_URL(BSTR *) um\msxml.h
# put_URL(BSTR) um\msxml.h
# get_mimeType(BSTR *) um\msxml.h
# get_readyState(long *) um\msxml.h
# get_charset(BSTR *) um\msxml.h
# put_charset(BSTR) um\msxml.h
# get_version(BSTR *) um\msxml.h
# get_doctype(BSTR *) um\msxml.h
# get_dtdURL(BSTR *) um\msxml.h
# createElement(VARIANT, VARIANT, IXMLElement **) um\msxml.h
# get_root(IXMLElement2 **) um\msxml.h
# get_fileSize(BSTR *) um\msxml.h
# get_fileModifiedDate(BSTR *) um\msxml.h
# get_fileUpdatedDate(BSTR *) um\msxml.h
# get_URL(BSTR *) um\msxml.h
# put_URL(BSTR) um\msxml.h
# get_mimeType(BSTR *) um\msxml.h
# get_readyState(long *) um\msxml.h
# get_charset(BSTR *) um\msxml.h
# put_charset(BSTR) um\msxml.h
# get_version(BSTR *) um\msxml.h
# get_doctype(BSTR *) um\msxml.h
# get_dtdURL(BSTR *) um\msxml.h
# createElement(VARIANT, VARIANT, IXMLElement2 **) um\msxml.h
# get_async(VARIANT_BOOL *) um\msxml.h
# put_async(VARIANT_BOOL) um\msxml.h
# get_tagName(BSTR *) um\msxml.h
# put_tagName(BSTR) um\msxml.h
# get_parent(IXMLElement **) um\msxml.h
# setAttribute(BSTR, VARIANT) um\msxml.h
# getAttribute(BSTR, VARIANT *) um\msxml.h
# removeAttribute(BSTR) um\msxml.h
# get_children(IXMLElementCollection **) um\msxml.h
# get_type(long *) um\msxml.h
# get_text(BSTR *) um\msxml.h
# put_text(BSTR) um\msxml.h
# addChild(IXMLElement *, long, long) um\msxml.h
# removeChild(IXMLElement *) um\msxml.h
# get_tagName(BSTR *) um\msxml.h
# put_tagName(BSTR) um\msxml.h
# get_parent(IXMLElement2 **) um\msxml.h
# setAttribute(BSTR, VARIANT) um\msxml.h
# getAttribute(BSTR, VARIANT *) um\msxml.h
# removeAttribute(BSTR) um\msxml.h
# get_children(IXMLElementCollection **) um\msxml.h
# get_type(long *) um\msxml.h
# get_text(BSTR *) um\msxml.h
# put_text(BSTR) um\msxml.h
# addChild(IXMLElement2 *, long, long) um\msxml.h
# removeChild(IXMLElement2 *) um\msxml.h
# get_attributes(IXMLElementCollection **) um\msxml.h
# get_name(BSTR *) um\msxml.h
# get_value(BSTR *) um\msxml.h
# GetErrorInfo(XML_ERROR *) um\msxml.h
# GetClassID(CLSID *) um\urlmon.h
# IsDirty() um\urlmon.h
# Load(BOOL, IMoniker *, LPBC, DWORD) um\urlmon.h
# Save(IMoniker *, LPBC, BOOL) um\urlmon.h
# SaveCompleted(IMoniker *, LPBC) um\urlmon.h
# GetCurMoniker(IMoniker **) um\urlmon.h
# ...
# _updateFixture(int) AppCommon_AP\UpdateMatrixObject.h
# _updateSafety(int) AppCommon_AP\UpdateMatrixObject.h
# _updateSleeve(int) AppCommon_AP\UpdateMatrixObject.h
# _updateAbutment(int) AppCommon_AP\UpdateMatrixObject.h
# SetVolumeData(LPVOID, std::array<double, 3>, std::array<int, 3> &) DoitInterface\InterfaceFixtureBoneDensity.h
# SetFixture(CSurfaceModelItem *, CMatrixMxN &) DoitInterface\InterfaceFixtureBoneDensity.h
# Update() DoitInterface\InterfaceFixtureBoneDensity.h
# GetImages() DoitInterface\InterfaceFixtureBoneDensity.h
# cmat_to_eigmat(CMatrixMxN &, Eigen::Matrix4d &, bool) DoitInterface\InterfaceFixtureBoneDensity.h
# MakeBoneDensityImage() DoitInterface\InterfaceFixtureBoneDensity.h
# GetCustomBands(const double *, const int &, const int &) DoitInterface\InterfaceFixtureBoneDensity.h
# GetColorSeries2() DoitInterface\InterfaceFixtureBoneDensity.h
# GetCategoricalLUT() DoitInterface\InterfaceFixtureBoneDensity.h
# GetPolyDataFromMesh(OpenMesh::TriMesh &, int) DoitInterface\InterfaceFixtureBoneDensity.h
# SetModel(CSurfaceModelItem *, CMatrixMxN, CSurfaceModelItem *, CMatrixMxN) DoitInterface\InterfaceCollisionDetection.h
# SetModel(std::shared_ptr<OpenMesh::TriMesh>, std::shared_ptr<DioBVH::CBVH>, std::shared_ptr<OpenMesh::TriMesh>, std::shared_ptr<DioBVH::CBVH>) DoitInterface\InterfaceCollisionDetection.h
# Update() DoitInterface\InterfaceCollisionDetection.h
# IsCollision() DoitInterface\InterfaceCollisionDetection.h
# AssignMemory() DoitInterface\InterfaceCollisionDetection.h
# SetCenter(DioData::float3) DoitInterface\InterfaceSafeDistance.h
# SetRadialDistance(double) DoitInterface\InterfaceSafeDistance.h
# SetAxisDistance(double) DoitInterface\InterfaceSafeDistance.h
# SetResolution(int) DoitInterface\InterfaceSafeDistance.h
# SetIsCap(bool) DoitInterface\InterfaceSafeDistance.h
# SetModel(CSurfaceModelItem *, CMatrixMxN) DoitInterface\InterfaceSafeDistance.h
# Update() DoitInterface\InterfaceSafeDistance.h
# GetModel() DoitInterface\InterfaceSafeDistance.h
# AssignMemory() DoitInterface\InterfaceSafeDistance.h
# OnMouseLBDown(const UINT &, const CPoint &, const int &) AppCommon_AP\ManipulatorCrossSection.h
# OnMouseLBUp(const UINT &, const CPoint &, const int &) AppCommon_AP\ManipulatorCrossSection.h
# OnMouseMove(const UINT &, const CPoint &, const int &) AppCommon_AP\ManipulatorCrossSection.h
# Init() AppCommon_AP\ManipulatorCrossSection.h
# isRender() AppCommon_AP\ManipulatorCrossSection.h
# Render() AppCommon_AP\ManipulatorCrossSection.h
# RenderOff() AppCommon_AP\ManipulatorCrossSection.h
# Update(bool) AppCommon_AP\ManipulatorCrossSection.h
# ChangeModelDrawable(const bool &) AppCommon_AP\ManipulatorCrossSection.h
# Reset() AppCommon_AP\ManipulatorCrossSection.h
# ApplyMatrixFromView(const CPoint &, const CPoint &) AppCommon_AP\ManipulatorCrossSection.h
# GetCurrentUpVector() AppCommon_AP\ManipulatorCrossSection.h
# GetCurrentCenter() AppCommon_AP\ManipulatorCrossSection.h
# GetCurrentCircleNormal() AppCommon_AP\ManipulatorCrossSection.h
# GetCircleRadius() AppCommon_AP\ManipulatorCrossSection.h
# GetComplete() AppCommon_AP\ManipulatorCrossSection.h
# _renderCircle() AppCommon_AP\ManipulatorCrossSection.h
# _renderOffCircle() AppCommon_AP\ManipulatorCrossSection.h
# _renderTransparentPlane() AppCommon_AP\ManipulatorCrossSection.h
# _renderOffTransparentPlane() AppCommon_AP\ManipulatorCrossSection.h
# _renderTranslateControlPoint() AppCommon_AP\ManipulatorCrossSection.h
# _renderOffTranslateControlPoint() AppCommon_AP\ManipulatorCrossSection.h
# _renderRotateControlPoint() AppCommon_AP\ManipulatorCrossSection.h
# _renderOffRotateControlPoint() AppCommon_AP\ManipulatorCrossSection.h
# _translate(CPoint, CPoint) AppCommon_AP\ManipulatorCrossSection.h
# _rotate(CPoint, CPoint, int) AppCommon_AP\ManipulatorCrossSection.h
# _applyMatirxToModel(CMatrixMxN) AppCommon_AP\ManipulatorCrossSection.h
# _saveInfo() AppCommon_AP\ManipulatorCrossSection.h
# _makeTranslateControlPoint() AppCommon_AP\ManipulatorCrossSection.h
# _makeRotateControlPoint() AppCommon_AP\ManipulatorCrossSection.h
# _replaceController() AppCommon_AP\ManipulatorCrossSection.h
# _calculateBounds() AppCommon_AP\ManipulatorCrossSection.h
# _getTransformMatrixFromBounds(bool) AppCommon_AP\ManipulatorCrossSection.h
# _getPlaneNormals(float3 *) AppCommon_AP\ManipulatorCrossSection.h
# _getRotationMatrixFromBounds() AppCommon_AP\ManipulatorCrossSection.h
# _getScalingfactor() AppCommon_AP\ManipulatorCrossSection.h
# _transformBounds(const CMatrixMxN &) AppCommon_AP\ManipulatorCrossSection.h
# _calculateShowHideState() AppCommon_AP\ManipulatorCrossSection.h
# _makeMatrixToView() AppCommon_AP\ManipulatorCrossSection.h
# _changeDrawablestate(int, int, bool) AppCommon_AP\ManipulatorCrossSection.h
# _mouseHoverEvent(const CPoint &, const CPoint &, const int &) AppCommon_AP\ManipulatorCrossSection.h
# GetCrossSection(int &, int &, float3, float3, float3, float, int &) DoitInterface\InterfaceCrossSection.h
# GetCrossSection(CSurfaceModelItem *, CMatrixMxN &, float3, float3, float3, float, int &) DoitInterface\InterfaceCrossSection.h
# operator=(const ST_VolumeInfo &) DoitRenderer\VolumeItem.h
# SetVolumeData(LPVOID, const ST_VolumeInfo &) DoitRenderer\VolumeItem.h
# GetInfo() DoitRenderer\VolumeItem.h
# GetVolumeIndex() DoitRenderer\VolumeItem.h
# GetVolumePtr() DoitRenderer\VolumeItem.h
# GetVolumeCropPtr() DoitRenderer\VolumeItem.h
# GetBlockOctree() DoitRenderer\VolumeItem.h
# GetMinmax(const __m128) DoitRenderer\VolumeItem.h
# GetLoadedCTPath() DoitRenderer\VolumeItem.h
# SetLoadedCTPath(LPCWSTR) DoitRenderer\VolumeItem.h
# SetLoadedCTfiles(const CStringList *const) DoitRenderer\VolumeItem.h
# GetLoadedCTfiles() DoitRenderer\VolumeItem.h
# GetVolumeROI() DoitRenderer\VolumeItem.h
# SetVolumeROIInfo(unsigned int *) DoitRenderer\VolumeItem.h
# IsVolumeROIApply() DoitRenderer\VolumeItem.h
# TurnOffVolumeROI() DoitRenderer\VolumeItem.h
# ApplyROICurrentCT() DoitRenderer\VolumeItem.h
# GetROIInfoCurrentCT() DoitRenderer\VolumeItem.h
# CreateBlock(const int, const int) DoitRenderer\VolumeItem.h
# _reallocateSliceMem() DoitRenderer\VolumeItem.h
# _deleteSliceMem() DoitRenderer\VolumeItem.h
# AddVolume(CVolumeItem *) AppFrame\VolumeDoc.h
# UpdateCrop() AppFrame\VolumeDoc.h
# RemoveVolume(POSITION) AppFrame\VolumeDoc.h
# RemoveVolume(LPCWSTR) AppFrame\VolumeDoc.h
# RemoveAllVolumes() AppFrame\VolumeDoc.h
# GetVolumeItem(POSITION) AppFrame\VolumeDoc.h
# GetVolumeItem(const ST_VolumeInfo &) AppFrame\VolumeDoc.h
# GetVolumeItem(LPCWSTR) AppFrame\VolumeDoc.h
# GetVolumeInfo(POSITION) AppFrame\VolumeDoc.h
# GetVolumeInfo(LPCWSTR) AppFrame\VolumeDoc.h
# GetWndParam(POSITION) AppFrame\VolumeDoc.h
# GetWndParam(LPCWSTR) AppFrame\VolumeDoc.h
# GetRescaleFactor(POSITION) AppFrame\VolumeDoc.h
# GetRescaleFactor(LPCWSTR) AppFrame\VolumeDoc.h
# FindPosition(LPCWSTR) AppFrame\VolumeDoc.h
# GetHeadPosition() AppFrame\VolumeDoc.h
# GetNext(POSITION &) AppFrame\VolumeDoc.h
# GetAt(POSITION) AppFrame\VolumeDoc.h
# GetCount() AppFrame\VolumeDoc.h
# GetInstance() DoitRenderer\DirectXGlobalData.h
# CreateDevice() DoitRenderer\DirectXGlobalData.h
# CreateVolumeTexture(const CVolumeItem *) DoitRenderer\DirectXGlobalData.h
# IsReSize(CSize, CDirectXRenderer *) DoitRenderer\DirectXGlobalData.h
# GetDevice() DoitRenderer\DirectXGlobalData.h
# GetDeviceContext() DoitRenderer\DirectXGlobalData.h
# GetVolumeShaderResourceView() DoitRenderer\DirectXGlobalData.h
# GetCubeVertexBuffer() DoitRenderer\DirectXGlobalData.h
# GetCubeIndexBuffer() DoitRenderer\DirectXGlobalData.h
# GetVolumeInfo() DoitRenderer\DirectXGlobalData.h
# GetPreSize() DoitRenderer\DirectXGlobalData.h
# GetVRCube() DoitRenderer\DirectXGlobalData.h
# GetVolumeCubeMinMax() DoitRenderer\DirectXGlobalData.h
# _createVolumeCube(float *, int *) DoitRenderer\DirectXGlobalData.h
# Create(const RECT &, CActuatorBase *, CWnd *, CWnd *) AppUICore\UIPane.h
# SetActuator(CActuatorBase *) AppUICore\UIPane.h
# OnMessageCommonAction(UINT, LPARAM) AppUICore\UIPane.h
# OnMessageCommonMode(UINT, BOOL) AppUICore\UIPane.h
# OnMessageCommonTool(UINT, LPARAM) AppUICore\UIPane.h
# OnMessageSpecificAction(UINT, LPARAM) AppUICore\UIPane.h
# OnMessageSpecificMode(UINT, BOOL) AppUICore\UIPane.h
# OnMessageSpecificTool(UINT, LPARAM) AppUICore\UIPane.h
# OnUpdate(UINT, WPARAM, const CUpdateParam *, const LPVOID) AppUICore\UIPane.h
# OnInitialUpdate() AppUICore\UIPane.h
# OnFinalUpdate() AppUICore\UIPane.h
# HasMessageTargetItem(LPVOID) AppUICore\UIPane.h
# Redraw() AppUICore\UIPane.h
# SendStatusToParentFrame(UINT, WPARAM, LPARAM) AppUICore\UIPane.h
# GetScrollInfoFromPanel(int, LPSCROLLINFO, UINT) AppUICore\UIPane.h
# SetScrollInfoToPanel(int, LPSCROLLINFO, BOOL) AppUICore\UIPane.h
# LockPaneDC() AppUICore\UIPane.h
# UnlockPaneDC() AppUICore\UIPane.h
# OnChildUpdate(UINT, WPARAM, LPARAM) AppUICore\UIPane.h
# _createMemDC() AppUICore\UIPane.h
# _destroyMemDC() AppUICore\UIPane.h
# GetThisMessageMap() AppUICore\UIPane.h
# GetMessageMap() AppUICore\UIPane.h
# OnCreate(LPCREATESTRUCT) AppUICore\UIPane.h
# OnDestroy() AppUICore\UIPane.h
# OnPaint() AppUICore\UIPane.h
# OnEraseBkgnd(CDC *) AppUICore\UIPane.h
# OnSize(UINT, int, int) AppUICore\UIPane.h
# OnLButtonDown(UINT, CPoint) AppUICore\UIPane.h
# OnLButtonUp(UINT, CPoint) AppUICore\UIPane.h
# OnLButtonDblClk(UINT, CPoint) AppUICore\UIPane.h
# OnMButtonDown(UINT, CPoint) AppUICore\UIPane.h
# OnMButtonUp(UINT, CPoint) AppUICore\UIPane.h
# OnMButtonDblClk(UINT, CPoint) AppUICore\UIPane.h
# OnMouseMove(UINT, CPoint) AppUICore\UIPane.h
# OnMouseHover(UINT, CPoint) AppUICore\UIPane.h
# OnMouseLeave() AppUICore\UIPane.h
# OnMouseWheel(UINT, short, CPoint) AppUICore\UIPane.h
# OnRButtonDown(UINT, CPoint) AppUICore\UIPane.h
# OnRButtonUp(UINT, CPoint) AppUICore\UIPane.h
# OnRButtonDblClk(UINT, CPoint) AppUICore\UIPane.h
# OnSetCursor(CWnd *, UINT, UINT) AppUICore\UIPane.h
# OnSetFocus(CWnd *) AppUICore\UIPane.h
# OnKillFocus(CWnd *) AppUICore\UIPane.h
# OnHScroll(UINT, UINT, CScrollBar *) AppUICore\UIPane.h
# OnVScroll(UINT, UINT, CScrollBar *) AppUICore\UIPane.h
# OnTimer(UINT_PTR) AppUICore\UIPane.h
# OnKeyDown(UINT, UINT, UINT) AppUICore\UIPane.h
# OnKeyUp(UINT, UINT, UINT) AppUICore\UIPane.h
# PreTranslateMessage(MSG *) AppUICore\UIPane.h
# OnMsgChildStatusChanged(WPARAM, LPARAM) AppUICore\UIPane.h
# OnMsgLockMemoryDC(WPARAM, LPARAM) AppUICore\UIPane.h
# OnMsgUnlockMemoryDC(WPARAM, LPARAM) AppUICore\UIPane.h
# OnMsgSendCommandTool(WPARAM, LPARAM) AppUICore\UIPane.h
# OnMsgImgRenderFinished(WPARAM, LPARAM) AppUICore\UIPane.h
# OnAttach() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _setAlphaBlend(CImage *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnInitialUpdate() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# InitializeData() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnUpdate(UINT, WPARAM, const CUpdateParam *, const LPVOID) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnActLBDown(UINT, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnActLBUp(UINT, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnActMouseMove(UINT, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnActMouseWheel(UINT, short, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# OnActKeyDown(UINT, UINT, UINT) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# UpdateSurfaceDisplay() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _updateUPPERorLOWER_ScanModel(E_SCAN_MODEL_TY) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# GetCurrentScanModel(E_SCAN_MODEL_TY) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _applyLibrary(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _applyFixture(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _applySleeve(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _applyAbutment(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _removeFixtureSleeveModel() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _getOffset(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _getMoveDirection(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _updateMatrixSelectObject(int, bool) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _calManipulatorValue() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# DrawTextOverlay(CDC *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawMeasure(CDC *, ST_FIXTURE_MEASURE, COLORREF) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _getMeasureRect(CPoint, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawMeasureDistance(CDC *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawMeasureAngle(CDC *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawFixtureInfo(CDC *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawSleeveInfo(CDC *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawManipulatorTickInfo(CDC *) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _placeFixtureSleeveAbutment(const int &) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _getModelsCenter(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _getModelsExtent(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _changeActiveFixture(UINT, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _changeHoverFixture(UINT, CPoint) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _makeSafetyOutline(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _makeSafetyOutline(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _makeSafetyThread(LPVOID) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _manipulatorTransformThread(LPVOID) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _changeMPRManipulator(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# GetSameGroup(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _transparentModels() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _transparentUpperSleeveModel(float) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _transparentLowerSleeveModel(float) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _transparentAllModel() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _drawManipulator(LPVOID) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _updateSelectedSafetyModel(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _getSafetyColor(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _transparentSafety(float, int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# DetectCollision() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _crownCrossSectionView(ST_2DCS_INFO &, float3, float3, float3, float) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _fixtureCrossSectionView(ST_2DCS_INFO &, float3, float3, float3, float) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _sleeveCrossSectionView(ST_2DCS_INFO &, float3, float3, float3, float) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _changeColorFromDensity(const CVolumeItem *const, CSurfaceModelItem *const, unsigned int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _initFixture() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _setGrouping(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _crossSectionView() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# SetInitUndoRedo(bool) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# InsertUndo(CString) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# ShowUndoData(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# ShowRedoData(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _undoThread(LPVOID) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _redoThread(LPVOID) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# ShowUndoRedoData(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# SetHistory(CString) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# GetHistory() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# GetEnableUndoRedo() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# SetEnableUndoRedo(bool) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# LoadUndoRedoFixture(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _writeMatrixInfo() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# _CrDensity() mod_APImplantSimulation\ActuatorHybridFixture.cpp
# SaveImgBuf(CImgBuf &, const int) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# SaveImgBufToFile(CImgBuf &, const CString &) mod_APImplantSimulation\ActuatorHybridFixture.cpp
# VolumeDensityImgDraw(int) mod_APImplantSimulation\ActuatorHybridFixture.cpp

# %%
#호출 식 외부 파일 필터링 (cpp 파일에서)
call_exp_node_list:[clang.cindex.Cursor] = stmt_map[clang.cindex.CursorKind.CALL_EXPR      ] 
print(f"외부 파일 포함 {call_exp_node_list.__len__()}")

print(target.spelling)

file_set = set()

file_list = []

temp:[clang.cindex.Cursor] = []
for node in call_exp_node_list:
    if node.location.file.name.__contains__("AutoPlanning"):
        temp.append(node)
        file_set.add(node.location.file.name)
        file_list.append(node)
call_exp_node_list = temp
print(f"내부 파일 {call_exp_node_list.__len__()}")
for fname in file_set:
    print(fname)


check_set = set()
for node in file_list:
    if check_set.__contains__(node.location.file.name):
        continue
    else:
        check_set.add(node.location.file.name)
        print(f"{node.displayname} {node.location}")
# Out:
# <class 'clang.cindex.TranslationUnit'> D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp
# // Added by sckim, on 2018/10/17.
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# #include "stdafx.h"
# #include "Resource.h"
# #include "ActuatorHybridFixture.h"
# #include "MakeSafety.h"
# //#include "CollisionImplant.h"
# #include "../AppCommon_AP/ExtractorCollision.h"
# #include "UndoRedoFixture.h"
#
# #include "interface_module.h"
#
# #include "ManipulatorListIS.h"
# #include "ManipulatorFixtureHybrid.h"
# #include "CommandFixtureDental.h"
# #include "CommandFixtureMeasure.h"
#
# #include "DSIBoneDensityTable.h"
# #include "ModuleDocAPImplantSimulation.h"
#
# #include "../AppFrame/SideSliderDoc.h"
# #include "../AppCommon_AP/DSICrossLine.h"
# #include "../AppCommon_AP/DSIArchDrawing.h"
# #include "../AppCommon_AP/UpdateMatrixObject.h"
#
# #include "../DoitInterface/InterfaceFixtureBoneDensity.h"
# #include "../DoitInterface/InterfaceCollisionDetection.h"
# #include "../DoitInterface/InterfaceSafeDistance.h"
# #include "../AppCommon_AP/ManipulatorCrossSection.h"
# #include "../DoitInterface/InterfaceCrossSection.h"
# #include "../AppFrame/VolumeDoc.h"
# #include "../DoitRenderer/DirectXGlobalData.h"
#
# #include "../AppUICore/UIPane.h"
#
# #include <plog/Log.h>
# #include "../BaseTools/plogger.h"
# #include <Eigen/Geometry>
# #include <Eigen/LU>
# #include <Eigen/SVD>
#
# #ifdef _DEBUG
# #define new DEBUG_NEW
# #endif
#
#
# using namespace statistics_model;
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // constructor
# CActuatorHybridFixture::CActuatorHybridFixture()
# 	: CActuatorHybrid(NAME_ACTUATOR_FIXTURE_HYBRID)
# 	, _pCoordCvt(NULL), _pDSIBtnFixtureImple(NULL), _pImgInfoBackground(NULL)
# 	, _pManipulatorList(NULL)
# 	, _pMakeSafety(NULL),/* _pCollsionImplant(NULL),*/ _drawHandle(NULL)
# 	, _nWheel(0)
# 	, _bDeleteGuide(false)
#
# {
# 	_bAttachDSIViewDirection = true;
# 	_pCoordCvt = new CCoordinateConverter;
#
# 	_font.CreateFont(17, 0, 0, 0, FW_BOLD, FALSE, FALSE, FALSE
# 		, DEFAULT_CHARSET, OUT_DEFAULT_PRECIS, CLIP_DEFAULT_PRECIS, DEFAULT_QUALITY, DEFAULT_PITCH
# 		, _T("Tahoma"));
#
# 	// Safety
# 	_bMakeSafetyThread = true;
# 	_hMakeSafetyEvent = CreateEvent(NULL, FALSE, FALSE, L"MakeSafetyHybridFixture");
# 	_hReceiveMakeSafetyEvent = CreateEvent(NULL, FALSE, FALSE, L"ReceiveMakeSafetyHybridFixture");
#
# 	::AfxBeginThread(_makeSafetyThread, (LPVOID)this);
#
# 	// Manipulator Transform
# 	_bManipulatorTransformThread = true;
# 	_hManipulatorTransformEvent = CreateEvent(NULL, FALSE, FALSE, L"HybridFixtureManipulatorTransform");
# 	_hReceiveManipulatorTransformEvent = CreateEvent(NULL, FALSE, FALSE, L"ReceiveHybridFixtureManipulatorTransform");
#
# 	::AfxBeginThread(_manipulatorTransformThread, (LPVOID)this);
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // destructor
# CActuatorHybridFixture::~CActuatorHybridFixture()
# {
# 	SAFE_DELETE(_pManipulatorList);
# 	SAFE_DELETE(_pImgInfoBackground);
# 	SAFE_DELETE(_pMakeSafety);
# 	//SAFE_DELETE(_pCollsionImplant);
# 	SAFE_DELETE(_pCoordCvt);
#
# 	_bMakeSafetyThread = false;
# 	::SetEvent(_hMakeSafetyEvent);
# 	::WaitForSingleObject(_hReceiveMakeSafetyEvent, INFINITE);
# 	::CloseHandle(_hMakeSafetyEvent);
# 	::CloseHandle(_hReceiveMakeSafetyEvent);
#
# 	_bManipulatorTransformThread = false;
# 	::SetEvent(_hManipulatorTransformEvent);
# 	::WaitForSingleObject(_hReceiveManipulatorTransformEvent, INFINITE);
# 	::CloseHandle(_hManipulatorTransformEvent);
# 	::CloseHandle(_hReceiveManipulatorTransformEvent);
#
# 	_font.DeleteObject();
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Attach event handler
# void CActuatorHybridFixture::OnAttach(void)
# {
# 	// base operation, first.
# 	__super::OnAttach();
#
# 	_pModuleDocAPImplantSimulation = reinterpret_cast<CModuleDocAPImplantSimulation*>(_pLocalDocAP->GetWritableModuleDoc(APMod_ImplantSimul));
#
# 	// Cross Section Manuipulator 라인 생성
# 	CDSICrossLine* pCrossLine = new CDSICrossLine(_T("Cross Line"), this);
# 	ASSERT(pCrossLine);
# 	AddDSI((CDSItemBase*)pCrossLine);
# 	//
# 	_pDSIBoneDensity = new CDSIBoneDensityTable(L"BONE_DENSTIY");
# 	//ASSERT(_pDSIBoneDensity);
# 	AddDSI((CDSItemBase*)_pDSIBoneDensity);
# 	_pDSIBoneDensity->SetVisible(false);
#
#
# 	// Axial Plane DSI Add
# 	CDSIAxialPlane* pDSIAxialPlane = new CDSIAxialPlane(L"DSIAxialPlane", nullptr, _pLocalDocAP);
# 	pDSIAxialPlane->SetDisplayOnly();
# 	// Plane의 Upvector 방향을 물체(Volume)의 뒤쪽에서 바라보는 방향으로 설정
# 	pDSIAxialPlane->SetDirectionForUpVector(E_AXIAL_PLANE_UPVECTOR_DIRECTION::APUD_BACK);
# 	AddDSI((CDSItemBase*)pDSIAxialPlane, true);
#
#
# 	// 2. ArchDrawing DSI (Only Display) Add
# 	CDSIArchDrawing* pDSIArchDrawing = new CDSIArchDrawing(DSI_NAME_ARCH_DRAWING
# 		, nullptr
# 		, _T("")
# 		, nullptr, EDSIBS_Normal, this, true, false);
#
# 	pDSIArchDrawing->SetReadOnly(true);
# 	AddDSI((CDSItemBase*)pDSIArchDrawing);
# 	pDSIArchDrawing->SetVisible(false);
#
#
#
# 	_pCurCommand = new CCommandFixtureDental(this);
# 	_pLocalDocAP->AddCommand(_pCurCommand, COMMAND_FIXTURE_DENTAL);
#
# 	CCommandFixtureDental* pCommandDentalArch = dynamic_cast<CCommandFixtureDental*>(_pCurCommand);
# 	pCommandDentalArch->SetLocalDoc(_pLocalDocAP);
# 	pCommandDentalArch->SetVolumeDSI(pDSIArchDrawing, pDSIAxialPlane);
#
# 	_pCurCommand = new CCommandFixtureMeasure(this);
# 	_pLocalDocAP->AddCommand(_pCurCommand, COMMAND_FIXTURE_MEASURE);
#
# 	CCommandFixtureMeasure* pCommandMeasure = dynamic_cast<CCommandFixtureMeasure*>(_pCurCommand);
# 	pCommandMeasure->SetLocalDoc(_pLocalDocAP);
#
# 	// UndoRedoManager 설정.
# 	_pUndoRedo = new CUndoRedoFixture();
# 	_pLocalDocAP->AddUndoRedoInterface(_pUndoRedo, UNDOREDO_FIXTURE_DESIGN);
#
#
# 	_pManipulatorList = new CManipulatorListIS(this);
# 	_pDelayManipulatorList = _pManipulatorList; //delay Hide 처리를 위해 세팅
#
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_AXIALPLANE);
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_CS);
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_TGT);
#
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS);
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT);
#
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID);
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID_MULTI);
# 	_pManipulatorList->AddManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_CROSSSECTION);
#
# 	if (_pImgRenderer)
# 		_pImgRenderer->SetBackGroundGradationLinear(RGB(21, 23, 32), RGB(37, 39, 53), 0.05f, 0.95f);
#
# 	_pMakeSafety = new CMakeSafety(this);
#
# 	//_pCollsionImplant = new CCollisionImplant(this); -> OnInitialUpdate 에서 생성
#
# 	HINSTANCE hResourceHandle = LoadLibrary(_T("mod_APImplantSimulation.dll"));
#
# 	_pImgInfoBackground = new CImage;
# 	BitmapUtils::LoadPNGFromResource(*_pImgInfoBackground, IDB_PNG_FIXTURE_INFO_BACKGROUND, hResourceHandle);
# 	_setAlphaBlend(_pImgInfoBackground);
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // 이미지 투명 처리
# void CActuatorHybridFixture::_setAlphaBlend(CImage * pImage)
# {
# 	ASSERT(pImage);
#
# 	// Alpha값 처리
# 	if (pImage->GetBPP() == 32)
# 	{
# 		unsigned char * pCol = 0;
# 		long w = pImage->GetWidth();
# 		long h = pImage->GetHeight();
# 		for (long y = 0; y < h; y++)
# 		{
# 			for (long x = 0; x < w; x++)
# 			{
# 				pCol = (unsigned char *)pImage->GetPixelAddress(x, y);
# 				unsigned char alpha = pCol[3];
# 				if (alpha != 255)
# 				{
# 					pCol[0] = ((pCol[0] * alpha) + 128) >> 8;
# 					pCol[1] = ((pCol[1] * alpha) + 128) >> 8;
# 					pCol[2] = ((pCol[2] * alpha) + 128) >> 8;
# 				}
# 			}
# 		}
# 		pImage->SetHasAlphaChannel(true);
# 	}
# }
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // initial update & final update
# void CActuatorHybridFixture::OnInitialUpdate(void)
# {
# 	SetEnableUndoRedo(false);
#
# 	// Crown Scan 행렬 적용
# 	// Crown에서는 Scan 정합 행렬 적용
# 	std::vector<int> listTooth = _pToothDoc->GetToothNumberList();
# 	for (auto nTooth : listTooth)
# 	{
# 		if (END_OF_CROWN_TYPE_STATES != _pToothDoc->GetCrownState(nTooth))
# 		{
# 			auto pCrownData = _pToothDoc->GetToothInfoData()->GetToothData(nTooth)->GetCrownDesignData();
#
# 			if (30 > nTooth)
# 			{
# 				auto pScanData = _pToothDoc->GetToothInfoData()->GetUpperLowerInfoData(UPPER);
# 				pCrownData->SetScanMatrix(pScanData->GetMatrix());
# 			}
# 			else
# 			{
# 				auto pScanData = _pToothDoc->GetToothInfoData()->GetUpperLowerInfoData(LOWER);
# 				pCrownData->SetScanMatrix(pScanData->GetMatrix());
# 			}
# 		}
# 	}
#
# 	__super::OnInitialUpdate();
#
#
# 	 _initFixture();
#
#
# 	// 단면을 자르기 위한 모델을 세팅
# 	auto pUpdateMatrixObject = _pLocalDocAP->GetUpdateMatrixObject();
#
# 	std::vector<E_UPDATE_MATRIX_OBJECT> vObject;
# 	for (int i = UPDATE_MATRIX_SCAN; i < _END_OF_UPDATE_MATRIX_OBJECT; i++)
# 	{
# 		vObject.push_back(static_cast<E_UPDATE_MATRIX_OBJECT>(i));
# 	}
#
# 	pUpdateMatrixObject->UpdateMatrixObject(vObject);
#
# 	_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_AXIALPLANE, true);
# 	_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 	_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
#
# 	_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_CS, false);
# 	_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_TGT, false);
#
# 	ApplyCurrentTransferFunction();
# 	_transparentModels();
#
# 	CExtractorCollision* pCollisionExtractor = _pLocalDocAP->GetExtractorCollision();
# 	pCollisionExtractor->SetCollisionObjects();
#
# 	CCommandFixtureMeasure* pCommandMeasure = dynamic_cast<CCommandFixtureMeasure*>(_pLocalDocAP->GetCommand(COMMAND_FIXTURE_MEASURE));
# 	if (pCommandMeasure)
# 		pCommandMeasure->SetMeasureData();
#
# 	if (pCollisionExtractor->IsNotEmptyBVHModels())
# 		DetectCollision();
#
#
# 	SetEnableUndoRedo(true);
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Actuator Data를 초기화 하는 함수. (Case Load시 호출하면 될듯, 하위클래스에서 Override하여 데이터 초기화하도록 한다.)
# void CActuatorHybridFixture::InitializeData()
# {
# 	__super::InitializeData();
#
# 	_pManipulatorList->InitManipulator();
#
# 	// UndoRedoManager 설정.
# 	_pUndoRedo->RemoveAllUndoInfo();
# 	_pUndoRedo->RemoveAllRedoInfo();
# }
#
# //test
# bool LBDownSet = false;
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Process update messages and broadcast to child message target item.
# //auto-gen-future
# #include <future>
# #define USE_FUTURE auto updateFuture = std::async(std::launch::async, [nId, wParam, pParam, pSender, &bRes, pCommandMeasure, bOn, this](){
# #define END_FUTURE });updateFuture.wait();
# bool CActuatorHybridFixture::OnUpdate(UINT nId, WPARAM wParam, const CUpdateParam* pParam, const LPVOID pSender)
# {
# 	bool bRes = __super::OnUpdate(nId, wParam, pParam, pSender);
#
# 	CCommandFixtureMeasure* pCommandMeasure = dynamic_cast<CCommandFixtureMeasure*>(_pLocalDocAP->GetCommand(COMMAND_FIXTURE_MEASURE));
# 	BOOL bOn = (BOOL)wParam;
#
#
# 	if (nId == BUM::BUM_MODULE_PANO_CS_POS_CHANGED	// 파노라마 영상의 CS Position(Sampling Point)이 변경된 경우
# 		|| nId == BUM::BUM_MODULE_PLANE_CS_ROTATED	// CS PLANE 회전으로 CS Position 관련 벡터 정보가 변경된 경우
# 		|| nId == BUM::BUM_MODULE_PLANE_TGT_ROTATED	// Tgt PLANE 회전으로 CS Position 관련 벡터 정보가 변경된 경우
# 		)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(_pLocalDocAP->GetWritableModuleDoc(APMod_ImplantSimul));
#
# 		if (_pLocalDocAP->GetPanoAxialEvent())
# 			_bUpdate = true;
# 		else bRes = true;
# 		if (MoudleDoc->GetUseCS())
# 		{
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_CS, true);
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_TGT, true);
#
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
# 		}
# 		else
# 		{
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, true);
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, true);
#
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_CS, false);
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_TGT, false);
#
# 		}
#
# 		_pManipulatorList->UpdateModelManipulator(true);
#
#
#
#
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 	}
# 	else if (nId == BUM::BUM_COMMON_SCREENSHOT)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		if(255 == (int)wParam)
# 			_CrDensity();
# 	}
# 	else if (nId == BUM::BUM_UPDATE_PROC)
# 	{
# 		USE_FUTURE
# 			if (GetLogStep()) ProcLogRcvStep(nId);
# 			else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		if (_bUpdate)
# 			bRes = true;
#
# 		_bUpdate = false;
#
# 		END_FUTURE
# 	}
# 	else if ( ( nId == BUM::BUM_COMMON_ACTUATOR_DATA_INITIALIZE ) || ( nId == BUM::BUM_COMMON_RESET_JOBDATA_BY_MODIFY_ORDER ) )
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		if (NULL != _pUndoRedo)
# 		{
# 			CString strExistingFolder;
# 			CEnvSession* pEnv = CEnvSession::GetInstance();
# 			ASSERT(pEnv);
# 			strExistingFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), _pLocalDocAP->GetPatientID(), FIXTURE_FILE_PATH);
#
# 			_pUndoRedo->SetDefaultFolder(strExistingFolder);
#
# 			_pUndoRedo->RemoveAllUndoInfo();
# 			_pUndoRedo->RemoveAllRedoInfo();
# 		}
# 	}
# 	else if ( (nId  == BUM::BUM_COMMON_VOLUMELOADING_COMPLETED ) ||( nId == BUM::BUM_COMMON_RESET_JOBDATA_BY_MODIFY_ORDER) )
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		// 단면을 자르기 위한 모델을 세팅
# 		auto pUpdateMatrixObject = _pLocalDocAP->GetUpdateMatrixObject();
#
# 		std::vector<E_UPDATE_MATRIX_OBJECT> vObject;
# 		for (int i = UPDATE_MATRIX_SCAN; i < _END_OF_UPDATE_MATRIX_OBJECT; i++)
# 		{
# 			vObject.push_back(static_cast<E_UPDATE_MATRIX_OBJECT>(i));
# 		}
#
# 		pUpdateMatrixObject->UpdateMatrixObject(vObject);
#
# 		CExtractorCollision* pCollisionExtractor = _pLocalDocAP->GetExtractorCollision();
# 		pCollisionExtractor->InitializeCollisionObjects();
#
# 		CCommandFixtureMeasure* pCommandMeasure = dynamic_cast<CCommandFixtureMeasure*>(_pLocalDocAP->GetCommand(COMMAND_FIXTURE_MEASURE));
# 		if (pCommandMeasure)
# 			pCommandMeasure->InitialMeasureData();
#
# 	}
# 	else if (nId == BUM::BUM_MODULE_DENTAL_ARCH_CHANGED)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		if (E_APSteps::APStep_FixtureImplantation == _pLocalDocAP->GetCurrentStep())
# 		{
# 			//#4080 관련 버그
# 			//_pManipulatorList->RemoveModelManipulator();
#
# 			//_pManipulatorList->RenderModelManipulator();
#
# 			_pManipulatorList->UpdateModelManipulator();
#
#
# 			if (_pLocalDocAP->GetPanoAxialEvent())
# 				_bUpdate = true;
# 			else bRes = true;
# 		}
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	}
# 	else if (BUM::BUM_MODULE_NERVE_DRAW_DATA_CHANGED == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		_initFixture();
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_HYBRID_MANIPULATOR_CHANGE_MODEL == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		int nSelectedToothNumber = GetSelectedToothNumber();
#
# 		_applyLibrary(nSelectedToothNumber);
# 		_placeFixtureSleeveAbutment(nSelectedToothNumber);
#
# 		_makeSafetyOutline(nSelectedToothNumber);
#
# 		auto pFixtureData = _pToothInfoData->GetToothData(nSelectedToothNumber)->GetFixtureData();
# 		_pImgRenderer->RemoveMeshModel(pFixtureData->GetIndex());
#
# 		_updateSelectedFixtureModel(nSelectedToothNumber);
# 		_updateSelectedSafetyModel(nSelectedToothNumber);
# 		_updateSelectedSleeveModel(nSelectedToothNumber);
# 		_updateSelectedAbutmentModel(nSelectedToothNumber);
#
# 		const auto vecGroup = GetSameGroup(nSelectedToothNumber);
# 		if (1 >= vecGroup.size())
# 		{
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID, true);
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID_MULTI, false);
# 		}
# 		else
# 		{
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID, false);
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID_MULTI, true);
# 		}
#
# 		_pManipulatorList->InitManipulator();
# 		_pManipulatorList->RenderModelManipulator();
#
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
#
# 		// 충돌 확인
# 		std::vector<int> vTooth;
# 		vTooth.push_back(nSelectedToothNumber);
#
# 		CExtractorCollision* pCollisionExtractor = _pLocalDocAP->GetExtractorCollision();
# 		pCollisionExtractor->SetCollisionObjects(true/*bSingle*/);
#
# 		_updateMatrixSelectObject(vTooth);
#
# 		_transparentModels();
#
# 		if (TRUE == (wParam))
# 		{
# 			SetHistory(L"CHANGE_IMPLANT");
# 			InsertUndo(GetHistory());
# 		}
#
#
# 	}
#
#
# 	else if (BUM::BUM_MODULE_FIXTURE_MAKE_SAFETY == nId)
# 	{
# 		USE_FUTURE
# 			if (GetLogStep()) ProcLogRcvStep(nId);
# 			else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		::SetEvent(_hMakeSafetyEvent);
#
# 		END_FUTURE
# 	}
# 	//else if (BUM::BUM_MODULE_FIXTURE_UPDATE_COLOR_ONLY == nId)
# 	else if (BUM::BUM_MODULE_FIXTURE_UPDATE_COLOR == nId)
# 	{
#
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		_transparentModels();
#
# 		auto pMoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(_pLocalDocAP->GetWritableModuleDoc(APMod_ImplantSimul));
# 		if (pMoudleDoc->GetUseCS() == false)
# 			_pManipulatorList->UpdateModelManipulator(false);
#
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		//_pLocalDoc->SetMakeImg(true);
#
# 		if (_pLocalDocAP->GetPanoAxialEvent())
# 			_bUpdate = true;
# 		else bRes = true;
#
# 		SetTimer(TIMER_ID_HIDE_MANIPLATOR, TIME_HIDE_MANIPLATOR);
#
#
# 	}
#
# 	else if (BUM::BUM_COMMON_SLEEVE_ONOFF == nId)
# 	{
# 		USE_FUTURE
# 			if (GetLogStep()) ProcLogRcvStep(nId);
# 			else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		//bRes = true;
#
# 		END_FUTURE
# 	}
# 	else if (BUM::BUM_COMMON_BONE_DENSITY_ONOFF == nId)
# 	{
# 		USE_FUTURE
# 			if (GetLogStep()) ProcLogRcvStep(nId);
# 			else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		_pDSIBoneDensity->SetVisible(static_cast<int>(wParam));
# 		bRes = true;
#
# 		END_FUTURE
# 	}
# 	else if (BUM::BUM_COMMON_ABUTMENT_ONOFF == nId)
# 	{
# 		USE_FUTURE
# 			if (GetLogStep()) ProcLogRcvStep(nId);
# 			else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		//bRes = true;
#
# 		END_FUTURE
# 	}
# 	else if (BUM::BUM_COMMON_EACH_TOOTH_SELECT == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		const int nSelTooNumber = GetSelectedToothNumber();
#
# 		auto pUpdateMatrixObject = _pLocalDocAP->GetUpdateMatrixObject();
# 		std::vector<int> vTooth;
# 		vTooth.push_back(_pToothDoc->GetSelectedToothNumber());
# 		pUpdateMatrixObject->UpdateMatrixSelectObject(vTooth);
#
# 		const auto vecGroup = GetSameGroup(nSelTooNumber);
# 		if (1 >= vecGroup.size())
# 		{
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID, true);
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID_MULTI, false);
# 		}
# 		else
# 		{
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID, false);
# 			_pManipulatorList->SetManipulatorRenderState(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_HYBRID_MULTI, true);
# 		}
#
# 		_pManipulatorList->InitManipulator();
# 		_pManipulatorList->RenderModelManipulator();
# 		_pManipulatorList->UpdateModelManipulator();
#
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
#
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_GROUPING == nId)
# 	{
#
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		int nStandard = static_cast<int>(wParam);
#
# 		_setGrouping(nStandard);
#
# 		auto pUpdateMatrixObject = _pLocalDocAP->GetUpdateMatrixObject();
#
# 		std::vector<E_UPDATE_MATRIX_OBJECT> vObject;
# 		for (int i = UPDATE_MATRIX_CROWN; i < _END_OF_UPDATE_MATRIX_OBJECT; i++)
# 		{
# 			vObject.push_back(static_cast<E_UPDATE_MATRIX_OBJECT>(i));
# 		}
#
# 		pUpdateMatrixObject->UpdateMatrixObject(vObject);
#
# 		_pManipulatorList->InitManipulator();
# 		_pManipulatorList->RenderModelManipulator();
# 		_pManipulatorList->UpdateModelManipulator();
#
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
#
# 		bRes = true;
#
#
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_ATTAHCED == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
#
# 		ST_IMPLANT_STYLE* pImplantStyle = NULL;
# 		_pModuleDocAPImplantSimulation->GetImplantInfo(pImplantStyle);
#
# 		std::vector<int> vlistTooth = _pToothDoc->GetToothNumberList();
# 		std::vector<int> vFixtureList;
# 		for (auto nTooth : vlistTooth)
# 		{
# 			int nEnum = _pToothDoc->ReplaceToothNumberToEnum(nTooth);
# 			if (false == pImplantStyle->vSafety[nEnum].bRemove && IMPLANT_PLANNING_SELECT == _pToothDoc->GetImplantState(nTooth))
# 			{
# 				vFixtureList.push_back(nTooth);
# 			}
# 		}
#
# 		_pToothDoc->SetToothFixtureNumberList(vFixtureList);
#
# 	}
#
# 	else if (BUM::BUM_MODULE_FIXTURE_REMOVED == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		if (_removeFixtureSleeveModel())
# 		{
# 			ST_IMPLANT_STYLE* pImplantStyle = NULL;
# 			_pModuleDocAPImplantSimulation->GetImplantInfo(pImplantStyle);
#
# 			std::vector<int> vlistTooth = _pToothDoc->GetToothNumberList();
# 			std::vector<int> vFixtureList;
# 			for (auto nTooth : vlistTooth)
# 			{
# 				int nEnum = _pToothDoc->ReplaceToothNumberToEnum(nTooth);
# 				if (false == pImplantStyle->vSafety[nEnum].bRemove && IMPLANT_PLANNING_SELECT == _pToothDoc->GetImplantState(nTooth))
# 				{
# 					vFixtureList.push_back(nTooth);
# 				}
# 			}
#
# 			_pToothDoc->SetToothFixtureNumberList(vFixtureList);
#
# 			std::vector<int> vTooth;
# 			vTooth.push_back(_pToothDoc->GetSelectedToothNumber());
# 			_updateMatrixSelectObject(vTooth);
#
# 			SetHistory(L"REMOVE_IMPLANT");
# 			InsertUndo(GetHistory());
# 		}
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_MEASURE_FIXTRUE_DIS == nId || BUM::BUM_MODULE_FIXTURE_MEASURE_NERVE_DIS == nId
# 		|| BUM::BUM_MODULE_FIXTURE_MEASURE_FIXTURE_ANGLE == nId || BUM::BUM_MODULE_FIXTURE_MEASURE_ABUTMENT_ANGLE == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		bRes = true;
#
# 		BOOL bOn = (BOOL)wParam;
#
# 		CCommandFixtureMeasure* pCommandMeasure = dynamic_cast<CCommandFixtureMeasure*>(_pLocalDocAP->GetCommand(COMMAND_FIXTURE_MEASURE));
# 		if (BUM::BUM_MODULE_FIXTURE_MEASURE_FIXTRUE_DIS == nId)
# 		{
# 			USE_FUTURE
# 				if (GetLogStep()) ProcLogRcvStep(nId);
# 				else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 			pCommandMeasure->CalculateFixtureDistance(bOn);
#
# 			END_FUTURE
# 		}
# 		else if (BUM::BUM_MODULE_FIXTURE_MEASURE_NERVE_DIS == nId)
# 		{
# 			USE_FUTURE
# 				if (GetLogStep()) ProcLogRcvStep(nId);
# 				else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 			pCommandMeasure->CalculateNerveDistance(bOn);
#
# 			END_FUTURE
# 		}
# 		else if (BUM::BUM_MODULE_FIXTURE_MEASURE_FIXTURE_ANGLE == nId)
# 		{
# 			USE_FUTURE
# 				if (GetLogStep()) ProcLogRcvStep(nId);
# 				else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 			pCommandMeasure->CalculateFixtureAngle(bOn);
#
# 			END_FUTURE
# 		}
# 		else if (BUM::BUM_MODULE_FIXTURE_MEASURE_ABUTMENT_ANGLE == nId)
# 		{
# 			USE_FUTURE
# 				if (GetLogStep()) ProcLogRcvStep(nId);
# 				else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 			pCommandMeasure->CalculateAbutmentAngle(bOn);
#
# 			END_FUTURE
# 		}
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_HYBRID_MANIPULATOR_TRANSFORM == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, true);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, true);
#
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_CS, false);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_TGT, false);
#
#
# 		::SetEvent(_hManipulatorTransformEvent);
#
#
# 		//bRes = true;
#
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_HYBRID_MANIPULATOR_TRANSFORM_MOUSEUP == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
#
# 		BOOL bUpdate = (BOOL)wParam;
# 		if (TRUE == bUpdate)
# 		{
# 			::SetEvent(_hManipulatorTransformEvent);
#
# 			::WaitForSingleObject(_hReceiveManipulatorTransformEvent, INFINITE);
# 		}
#
# 		InsertUndo(GetHistory());
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_MPR_CS_MANIPULATOR_TRANSFORM == nId || BUM::BUM_MODULE_FIXTURE_MPR_TGT_MANIPULATOR_TRANSFORM == nId)
# 	{
#
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		//BOOL bOn = (BOOL)wParam;
# 		//
# 		_changeMPRManipulator(GetSameGroup(_pToothDoc->GetSelectedToothNumber()));
#
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, true);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, true);
#
# 		::SetEvent(_hManipulatorTransformEvent);
#
#
# 	}
# 	else if (BUM::BUM_MODULE_FIXTURE_MPR_CS_MANIPULATOR_TRANSFORM_UP == nId || BUM::BUM_MODULE_FIXTURE_MPR_TGT_MANIPULATOR_TRANSFORM_UP == nId)
# 	{
#
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		_changeMPRManipulator(GetSameGroup(_pToothDoc->GetSelectedToothNumber()));
#
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
#
# 		::SetEvent(_hManipulatorTransformEvent);
#
# 		::WaitForSingleObject(_hReceiveManipulatorTransformEvent, INFINITE);
#
# 		InsertUndo(GetHistory());
#
#
# 	}
#
#
# 	else if (nId == BUM::BUM_MODULE_HORIZONTAL_LINE_CHANGED)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		// 파노라마와 관련된 DSI에 대한 위치/출력 갱신
# 		E_APSteps eApStepCurr = _pLocalDocAP->GetCurrentStep();
# 		if (APStep_FixtureImplantation == eApStepCurr)
# 		{
# 			_pManipulatorList->OnMouseMove(NULL, CPoint(0, 0), MANIPULATOR_HORIZONPLANE_EDGE_INDEX);
#
# 			//_pManipulatorList->UpdateModelManipulator();
#
# 			// 영상 갱신
# 			//bRes = true;
# 		}
#
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	}
# 	//else if (BUM::BUM_MODULE_DRAW_AXIAL_MANIPULATOR == nId)
# 	//{
# 	//	if (GetLogStep()) ProcLogRcvStep(nId);
# 	//	else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	//	if (TRUE == (wParam))
# 	//	{
# 	//		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_AXIALPLANE, true);
# 	//	}
# 	//	else
# 	//	{
# 	//		_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_AXIALPLANE, false);
# 	//	}
#
# 	//	_pManipulatorList->UpdateModelManipulator();
#
# 	//	bRes = true;
# 	//}
# 	else if (BUM::BUM_MODULE_DRAW_TGT_CS_MANIPULATOR == nId)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		if (TRUE == (wParam))
# 		{
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, true);
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, true);
# 		}
# 		else
# 		{
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_CS, false);
# 			_pManipulatorList->ChangeModelDrawable(E_MANIPULATOR_TYPE::MANIPULATOR_FIXTURE_TGT, false);
# 		}
#
# 		_pManipulatorList->UpdateModelManipulator();
#
# 		bRes = true;
# 	}
# 	else if (nId == BUM::BUM_MODULE_MOUSEWHEEL)
# 	{
#
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		if (GetEnableUndoRedo())
# 		{
# 			if (_pManipulatorList)
# 			{
# 				short zDelta = static_cast<short>(wParam);
# 				CPoint point(0, 0);
# 				if (_pManipulatorList->OnMouseWheel(MK_CONTROL, zDelta, point, _nSelectedModelIndex))
# 				{
# 					_nDrawTime = 0;
#
# 					if (NULL == _drawHandle)
# 					{
# 						auto pWinThread = ::AfxBeginThread(_drawManipulator, (LPVOID)this);
# 						_drawHandle = pWinThread->m_hThread;
#
# 						SetHistory(L"ROTATE_IMPLANT");
# 						InsertUndo(GetHistory());
# 					}
#
# 					bRes = true;
# 				}
# 			}
#
# 			++_nWheel;
# 			if (5 == _nWheel)
# 			{
# 				_nWheel = 0;
#
# 				MSG msg;
# 				while (PeekMessage(&msg, NULL, WM_LBUTTONDOWN, WM_MOUSEWHEEL, PM_REMOVE));
# 			}
# 		}
#
#
# 	}
# 	else if (nId == BUM::BUM_COMMON_UNDO)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		if (GetEnableUndoRedo())
# 		{
# 			_pUndoRedo->EnableUndoRedo(false);
#
# 			_nUndoRedoIndex = (int)wParam;
#
# 			::AfxBeginThread(_undoThread, (LPVOID)this);
# 		}
# 	}
# 	else if (nId == BUM::BUM_COMMON_REDO)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		if (GetEnableUndoRedo())
# 		{
# 			_pUndoRedo->EnableUndoRedo(false);
#
# 			_nUndoRedoIndex = (int)wParam;
#
# 			::AfxBeginThread(_redoThread, (LPVOID)this);
# 		}
# 	}
# 	else if (nId == BUM::BUM_COMMON_SHOW_2D)
# 	{
#
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		int nTemp = (int)wParam;
#
#
# 		if (nTemp == 0)
# 		{
# 			CManipulatorCrossSection* pManipulator = reinterpret_cast<CManipulatorCrossSection*>(_pManipulatorList->GetManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_CROSSSECTION));
# 			pManipulator->Reset();
# 			bRes = true;
# 		}
# 		else if (nTemp == 1)
# 		{
#
#
# 		}
# 		else if (nTemp == 2 && !_bMakeCrossSection) { // bMakeCrossSection 확인.
#
# 		}
#
#
#
# 	}
# 	//else if (nId == BUM::BUM_MODULE_PANO_CS_POS_CHANGED)
# 	//{
# 	//	//MPR -> POS
# 	//	_transparentAllModel();
#
# 	//	_pManipulatorList->UpdateModelManipulator(false);
#
# 	//	bRes = true;
# 	//}
# 	else if (nId == BUM::BUM_COMMON_IMPLANTFIXTURE_SHOW)
# 	{
# 		if (_bDeleteGuide)
# 		{
# 			_bDeleteGuide = false;
# 			SendGlobalUpdateMessage(BUM::BUM_MODULE_FIXTURE_HYBRID_DELETE_SURGICAL_GUIDE_DATA, NULL);
# 		}
# 	}
#
# 	return bRes;
# }
#
# // CImgBuf 객체를 CImage 객체로 변환하는 함수
# bool ConvertImgBufToCImage(const CImgBuf& imgBuf, CImage& image) {
# 	// CImgBuf가 초기화되지 않았으면 실패를 반환
# 	if (!imgBuf.IsInitialized())
# 		return false;
#
# 	// 이미지 크기 정보를 얻음
# 	int width = imgBuf.Width();
# 	int height = imgBuf.Height();
#
# 	// CImage 객체 초기화
# 	HRESULT hr = image.Create(width, height, 24); // 예시: 24비트 이미지 (RGB)
# 	if (FAILED(hr))
# 		return false;
#
# 	// 이미지 데이터를 CImage 객체로 복사
# 	BYTE* pSrcBuffer = imgBuf.GetBuffer();
# 	if (pSrcBuffer == nullptr)
# 		return false;
#
# 	for (int y = 0; y < height; y++) {
# 		BYTE* pDest = (BYTE*)image.GetPixelAddress(0, y);
# 		for (int x = 0; x < width; x++) {
# 			// pSrcBuffer에서 데이터를 읽어와 pDest에 복사
# 			// 예: RGB 형식을 가정 (채널 순서 및 데이터 형식에 따라 조정 필요)
# 			pDest[0] = pSrcBuffer[0]; // Blue
# 			pDest[1] = pSrcBuffer[1]; // Green
# 			pDest[2] = pSrcBuffer[2]; // Red
#
# 			pSrcBuffer += 3; // 다음 픽셀로 이동 (RGB)
# 			pDest += 3;
# 		}
# 	}
#
# 	return true;
# }
#
# //void SaveImgBufWithAlphaToFile(CImgBuf& pImgBuf, const CString& strFileName)
# //{
# //	if (!pImgBuf.IsInitialized()) {
# //		return;
# //	}
# //
# //	CImage image;
# //	// CImage는 알파 채널을 지원하지만, 이를 직접 설정할 수는 없습니다.
# //	// 32비트로 이미지를 생성하여 나중에 알파 채널을 포함하여 저장합니다.
# //	image.Create(pImgBuf.Width(), pImgBuf.Height(), 32);
# //
# //	BYTE* pSrc = pImgBuf.GetBuffer();
# //	if (pSrc == nullptr) {
# //		return;
# //	}
# //
# //	int nSrcStride = pImgBuf.Width() * 4; // RGBA이므로 너비 * 4 바이트
# //
# //	for (int y = 0; y < pImgBuf.Height(); ++y) {
# //		BYTE* pDest = (BYTE*)image.GetPixelAddress(0, y);
# //		BYTE* pSrcLine = pSrc + nSrcStride * y; // 현재 라인에 대한 포인터 계산
# //		memcpy(pDest, pSrcLine, nSrcStride); // 전체 라인을 복사합니다.
# //	}
# //
# //	// GdiplusStartupInput gdiplusStartupInput;
# //	// ULONG_PTR gdiplusToken;
# //	// Gdiplus::GdiplusStartup(&gdiplusToken, &gdiplusStartupInput, NULL);
# //
# //	// PNG 형식으로 알파 채널을 포함하여 이미지를 저장합니다.
# //	HRESULT hr = image.Save(strFileName, Gdiplus::ImageFormatPNG);
# //
# //	// Gdiplus::GdiplusShutdown(gdiplusToken);
# //
# //	if (FAILED(hr)) {
# //		// 저장 실패 처리
# //	}
# //}
#
#
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // WM_LBUTTONDOWN
# bool  CActuatorHybridFixture::OnActLBDown(UINT nFlags, CPoint point)
# {
# 	bool bRes = false;
#
# 	SetCapture();
#
# 	//CList<int, int> FList;
#
# 	//auto modelMap = _pImgRenderer->GetSurfaceModelMap();
# 	//for (auto pair : modelMap)
# 	//{
# 	//	int nIdx = pair.first;
# 	//	CSurfaceModelItem* pModel = pair.second;
# 	//	if (nIdx >= 230 && nIdx <= 261)
# 	//		//if (nIdx == 241)
# 	//	{
# 	//		FList.AddTail(nIdx);
# 	//	}
# 	//	_pImgRenderer->SetDrawable(false, nIdx);
#
# 	//	std::cout << nIdx << " : " << CT2CA(pModel->GetName()) << std::endl;
# 	//	//SAFE_DELETE(pModel);
# 	//}
#
# 	//HWND hwnd = m_pParentPane->GetSafeHwnd();
# 	//static bool result = _pImgRenderer->InitSR_VolumeDensity(hwnd);
#
# 	//POSITION pos = FList.GetHeadPosition(); // 리스트의 첫 번째 요소 위치 얻기
# 	//while (pos != NULL)
# 	//{
# 	//	int value = FList.GetNext(pos);
#
# 	//	_pImgRenderer->SetDrawable(true, value);
# 	//	VolumeDensityImgDraw(value);
# 	//	_pImgRenderer->SetDrawable(false, value);
# 	//}
#
# 	//for (auto pair : modelMap)
# 	//{
# 	//	int nIdx = pair.first;
#
# 	//	_pImgRenderer->SetDrawable(true, nIdx);
#
# 	//}
#
# 	if (GetEnableUndoRedo())
# 	{
# 		// Manipulator가 있는 것은 Manipulator가 우선이다.
# 		if (_pManipulatorList)
# 		{
# 			__super::OnActLBDown(nFlags, point);
#
# 			if (false == bRes)
# 			{
# 				bRes = _changeActiveFixture(nFlags, point);
# 				if (bRes)
# 				{
# 					SetEnableUndoRedo(false);
# 				}
#
# 				if (bRes)
# 				{
# 					CManipulatorCrossSection* pManipulator = reinterpret_cast<CManipulatorCrossSection*>(_pManipulatorList->GetManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_CROSSSECTION));
# 					if (pManipulator && pManipulator->GetComplete())
# 					{
# 						_crossSectionView();
# 					}
#
# 				}
# 			}
#
# 			if (_pManipulatorList)
# 			{
# 				_pManipulatorList->OnMouseLBDown(nFlags, point, _nSelectedModelIndex);
# 			}
# 		}
# 	}
#
# 	LBDownSet = true;
# 	//_pLocalDoc->SetMakeImg(true);
#
# 	return bRes;
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // WM_LBUTTONUP
# bool CActuatorHybridFixture::OnActLBUp(UINT nFlags, CPoint point)
# {
# 	LBDownSet = false;
# 	//_pLocalDoc->SetMakeImg(false);
# 	::SetEvent(_hManipulatorTransformEvent);
# 	bool bRes = __super::OnActLBUp(nFlags, point);
#
# 	ReleaseCapture();
#
# 	if (GetEnableUndoRedo())
# 	{
# 		if (_pManipulatorList)
# 		{
# 			bRes = _pManipulatorList->OnMouseLBUp(nFlags, point, _nSelectedModelIndex);
# 		}
# 	}
#
#
# 	if (_bMakeCrossSection)
# 	{
# 		bRes = _createCrossSection();
#
# 		if (bRes)
# 		{
# 			AfxBeginThread(_checkCrossSection, this);
# 		}
# 	}
#
# 	SetEnableUndoRedo(true);
#
# 	return bRes;
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // WM_MOUSEMOVE
# bool CActuatorHybridFixture::OnActMouseMove(UINT nFlags, CPoint point)
# {
# 	if(LBDownSet)
# 		LOGN_(System) << "	<Event@Fixture Move>" << "( " << (const wchar_t*)_strName << " )";
#
# 	bool bRes = __super::OnActMouseMove(nFlags, point);
#
# 	bool bHover = false;
# 	if (GetEnableUndoRedo())
# 	{
# 		if (_pManipulatorList)
# 		{
# 			if (_pManipulatorList->OnMouseMove(nFlags, point, _nSelectedModelIndex))
# 			{
# 				bRes = true;
#
# 				_calManipulatorValue();
#
# 				CManipulatorCrossSection* pManipulator = reinterpret_cast<CManipulatorCrossSection*>(_pManipulatorList->GetManipulator(E_MANIPULATOR_TYPE::MANIPULATOR_CROSSSECTION));
# 				if ((nFlags & MK_LBUTTON) && pManipulator && pManipulator->GetComplete())
# 				{
# 					_crossSectionView();
#
# 					return bRes;
# 				}
# 			}
# 		}
#
# 		if (false == (nFlags & MK_LBUTTON) && false == (nFlags & MK_RBUTTON) && false == (nFlags & MK_MBUTTON))
# 		{
# 			bHover = _changeHoverFixture(nFlags, point);
# 		}
# 	}
#
# 	if ((nFlags & MK_LBUTTON) || bHover)
# 	{
# 		bRes = false;
# 	}
# 	else if (nFlags & MK_RBUTTON)
# 	{
# 		bRes = true;
# 	}
#
# 	return bRes;
# }
#
# bool CActuatorHybridFixture::OnActMouseWheel(UINT nFlags, short zDelta, CPoint point)
# {
# 	bool bRes = __super::OnActMouseWheel(nFlags, zDelta, point);
# 	if ((GetKeyState(VK_CONTROL) & 0x8000) || (GetKeyState(VK_LMENU) & 0x8000))
# 	{
# 		/*Bug #4092
# 		* CManipulatorFixtureHybrid 가  OnMouseWheel에서 처리됨
# 		* HybridFixtrue에서 해당 분기에서는 수행되는 기능 없어야함
# 		*/
# 	}
# 	else if (GetEnableUndoRedo())
# 	{
# 		if (_pManipulatorList)
# 		{
# 			if (_pManipulatorList->OnMouseWheel(nFlags, zDelta, point, _nSelectedModelIndex))
# 			{
# 				_nDrawTime = 0;
#
# 				if (NULL == _drawHandle)
# 				{
# 					auto pWinThread = ::AfxBeginThread(_drawManipulator, (LPVOID)this);
# 					_drawHandle = pWinThread->m_hThread;
#
# 					SetHistory(L"ROTATE_IMPLANT");
# 					InsertUndo(GetHistory());
# 				}
#
# 				bRes = true;
# 			}
# 		}
#
# 		++_nWheel;
# 		if (5 == _nWheel)
# 		{
# 			_nWheel = 0;
#
# 			MSG msg;
# 			while (PeekMessage(&msg, NULL, WM_LBUTTONDOWN, WM_MOUSEWHEEL, PM_REMOVE));
# 		}
# 	}
#
# 	return bRes;
# }
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // WM_KEYDOWN event handler
# bool CActuatorHybridFixture::OnActKeyDown(UINT nChar, UINT nRepCnt, UINT nFlags)
# {
# 	bool bRes = __super::OnActKeyDown(nChar, nRepCnt, nFlags);
#
#
# 	if (GetKeyState(VK_CONTROL) & 0x8000)
# 	{
# 		if (nChar == 'z' || nChar == 'Z')
# 		{
# 			PostUpdateMessage(BUM::BUM_COMMON_UNDO, 1);
# 		}
# 		else if (nChar == 'x' || nChar == 'X')
# 		{
# 			PostUpdateMessage(BUM::BUM_COMMON_REDO, 1);
# 		}
# 	}
#
# 	return bRes;
# }
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Scan data를 찾아서 화면을 갱신한다.
# void CActuatorHybridFixture::UpdateSurfaceDisplay(void)
# {
# 	if (_pImgRenderer)
# 	{
# 		_pImgRenderer->RemoveAllMeshModel();
#
# 		_updateUPPERorLOWER_ScanModel(E_SCAN_MODEL_TY::UPPER);
# 		_updateUPPERorLOWER_ScanModel(E_SCAN_MODEL_TY::LOWER);
#
# 		_updateUpperPreprep1ScanModel();
# 		_updateUpperPreprep2ScanModel();
#
# 		_updateLowerPreprep1ScanModel();
# 		_updateLowerPreprep2ScanModel();
#
# 		_updateAllCrownModel();
# 		_updateAllFixtureModel();
# 		_updateAllSleeveModel();
# 		_updateAllAbutmentModel();
#
# 		_updateAllNerveModel();
# 	}
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // 렌더러에 넣어줄 상악 모델을 업데이트한다 (행렬을 단위행렬로 넣기위해서 override 함.)
# bool CActuatorHybridFixture::_updateUPPERorLOWER_ScanModel(E_SCAN_MODEL_TY eScanType)
# {
# 	bool bRes = false;
# 	auto pCurrentScanInfoData = _pToothInfoData->GetUpperLowerInfoData(eScanType);
#
# 	ST_SIDESLIDER_DATA* pData = nullptr;
# 	GetLocalDoc()->GetSideSliderDoc()->GetSideSliderInfo(pData);
#
# 	float fScanModelColorAlpha = (float)pData->nPreparation / 100;
#
#
# 	if (eScanType != GetLocalDoc()->GetSelScanModelTy())
# 		fScanModelColorAlpha = (float)pData->nAntagonist / 100;
#
# 	if (_pImgRenderer)
# 	{
# 		CSurfaceModelItem* pCurrentScanModel;
# 		CSurfaceModelDoc* pModelDoc = GetLocalDoc()->GetSurfaceDoc();
#
# 		if (E_SCAN_MODEL_TY::UPPER == eScanType)
# 		{
# 			pCurrentScanModel = pModelDoc->GetItem(UPPER_SCAN_MODEL_TOOTHDEFORM);
# 		}
# 		else
# 		{
# 			pCurrentScanModel = pModelDoc->GetItem(LOWER_SCAN_MODEL_TOOTHDEFORM);
# 		}
#
# 		if (pCurrentScanModel)
# 		{
# 			CMatrixMxN mTrans = pCurrentScanInfoData->GetMatrix();
#
# 			int nIndex = pCurrentScanInfoData->GetIndex();
# 			_pImgRenderer->RemoveMeshModel(nIndex);
#
# 			_pImgRenderer->AddMeshModel(pCurrentScanModel, nIndex, true, 0U, true, true, 1U);
# 			_pImgRenderer->SetTransformedMatrix(&mTrans, nIndex);
# 			_pImgRenderer->SetLightColor(SCAN_MODEL_COLOR, fScanModelColorAlpha, nIndex);
# 			bRes = true;
# 		}
# 	}
# 	else
# 	{
# 		ASSERT(0);
# 	}
#
# 	return bRes;
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // 현재 선택한 상악(혹은 하악) 모델 반환 함수.
# CSurfaceModelItem * CActuatorHybridFixture::GetCurrentScanModel(E_SCAN_MODEL_TY eType) const
# {
# 	CSurfaceModelDoc* pModelDoc = GetLocalDoc()->GetSurfaceDoc();
# 	ASSERT(pModelDoc);
#
# 	CSurfaceModelItem* pReturn = nullptr;
#
# 	switch (eType)
# 	{
# 	case E_SCAN_MODEL_TY::UPPER:
# 		pReturn = pModelDoc->GetItem(UPPER_SCAN_MODEL_TOOTHREMOVE);
# 		break;
# 	case E_SCAN_MODEL_TY::LOWER:
# 		pReturn = pModelDoc->GetItem(LOWER_SCAN_MODEL_TOOTHREMOVE);
# 		break;
# 	case E_SCAN_MODEL_TY::UNKNOWN:
# 		break;
# 	default:
# 		// 정의되지 않은 유형 반환 시 확인 필요
# 		ASSERT(0);
# 		break;
# 	}
#
# 	return pReturn;
# }
#
#
# void CActuatorHybridFixture::_applyLibrary(int nTooth)
# {
# 	_applyFixture(nTooth);
# 	_applySleeve(nTooth);
# 	_applyAbutment(nTooth);
# }
#
# void CActuatorHybridFixture::_applyFixture(int nTooth)
# {
# 	auto pFixtureData = _pToothInfoData->GetToothData(nTooth)->GetFixtureData();
# 	auto pFixtureInfo = pFixtureData->GetFixtureInfo();
#
# 	auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pFixtureData->GetName());
# 	if (pPrevItem)
# 	{
# 		_pLocalDocAP->RemoveSurfaceModel(pFixtureData->GetName());
#
# 		SAFE_DELETE(pPrevItem);
# 	}
#
# 	if (pFixtureInfo)
# 	{
# 		auto pItem = pFixtureData->LoadFixture(pFixtureInfo->strFilePath);
#
# 		if (pItem)
# 		{
# 			_pLocalDocAP->AddSurfaceModel(pItem);
#
# 			pFixtureData->SaveFixture(pItem);
# 		}
# 	}
# 	pFixtureData->SaveFixtureInfo();
# }
#
# void CActuatorHybridFixture::_applySleeve(int nTooth)
# {
# 	auto pSleeveData = _pToothInfoData->GetToothData(nTooth)->GetSleeveData();
# 	auto pSleeveInfo = pSleeveData->GetSleeveInfo();
#
# 	auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pSleeveData->GetName());
# 	if (pPrevItem)
# 	{
# 		_pLocalDocAP->RemoveSurfaceModel(pSleeveData->GetName());
#
# 		SAFE_DELETE(pPrevItem);
# 	}
#
# 	if (pSleeveInfo)
# 	{
# 		auto pItem = pSleeveData->LoadSleeve(pSleeveInfo->strFilePath);
#
# 		if (pItem)
# 		{
# 			_pLocalDocAP->AddSurfaceModel(pItem);
#
# 			pSleeveData->SaveSleeve(pItem);
# 		}
# 	}
#
# 	pSleeveData->SaveSleeveInfo();
# }
#
# void CActuatorHybridFixture::_applyAbutment(int nTooth)
# {
# 	auto pFixtureData = _pToothInfoData->GetToothData(nTooth)->GetFixtureData();
#
# 	auto pAbutmentData = _pToothInfoData->GetToothData(nTooth)->GetAbutmentData();
# 	auto pAbutmentInfo = pAbutmentData->GetAbutmentInfo();
#
# 	auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pAbutmentData->GetName());
# 	if (pPrevItem)
# 	{
# 		_pLocalDocAP->RemoveSurfaceModel(pAbutmentData->GetName());
#
# 		SAFE_DELETE(pPrevItem);
# 	}
#
# 	if (pAbutmentInfo)
# 	{
# 		auto pItem = pAbutmentData->LoadAbutment(pAbutmentInfo->strFilePath);
#
# 		if (pItem)
# 		{
# 			_pLocalDocAP->AddSurfaceModel(pItem);
#
# 			pAbutmentData->SetMatrix(pFixtureData->GetMatrix());
# 			pAbutmentData->SaveAbutment(pItem);
# 		}
# 	}
#
# 	pAbutmentData->SaveAbutmentInfo();
# }
#
#
#
# bool CActuatorHybridFixture::_removeFixtureSleeveModel(void)
# {
# 	bool bRes = false;
#
# 	auto pFixtureData = _pToothInfoData->GetToothData(_pToothDoc->GetSelectedToothNumber())->GetFixtureData();
# 	pFixtureData->DeleteFixture(false);
# 	pFixtureData->DeleteFixtureInfo();
#
# 	int nFixtureIndex = pFixtureData->GetIndex();
# 	if (pFixtureData)
# 	{
# 		auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pFixtureData->GetName());
# 		if (pPrevItem)
# 		{
# 			_pLocalDocAP->RemoveSurfaceModel(pFixtureData->GetName());
#
# 			SAFE_DELETE(pPrevItem);
# 		}
#
# 		if (!_pImgRenderer->IsEmptyModelNumber(nFixtureIndex))
# 		{
# 			_pImgRenderer->RemoveMeshModel(nFixtureIndex);
# 			bRes = true;
# 		}
#
# 	}
#
# 	pFixtureData->DeleteSafety();
# 	int nSafetyIndex = pFixtureData->GetSafetyIndex();
# 	if (pFixtureData)
# 	{
# 		auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pFixtureData->GetSafetyName());
# 		if (pPrevItem)
# 		{
# 			_pLocalDocAP->RemoveSurfaceModel(pFixtureData->GetSafetyName());
#
# 			SAFE_DELETE(pPrevItem);
# 		}
#
# 		if (!_pImgRenderer->IsEmptyModelNumber(nSafetyIndex))
# 		{
# 			_pImgRenderer->RemoveMeshModel(nSafetyIndex);
# 			bRes = true;
# 		}
# 	}
#
# 	auto pSleeveData = _pToothInfoData->GetToothData(_pToothDoc->GetSelectedToothNumber())->GetSleeveData();
# 	pSleeveData->DeleteSleeve(false);
# 	pSleeveData->DeleteSleeveInfo();
#
# 	int nSleeveIndex = pSleeveData->GetIndex();
# 	if (pSleeveData)
# 	{
# 		auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pSleeveData->GetName());
# 		if (pPrevItem)
# 		{
# 			_pLocalDocAP->RemoveSurfaceModel(pSleeveData->GetName());
#
# 			SAFE_DELETE(pPrevItem);
# 		}
#
# 		if (!_pImgRenderer->IsEmptyModelNumber(nSleeveIndex))
# 		{
# 			_pImgRenderer->RemoveMeshModel(nSleeveIndex);
# 			bRes = true;
# 		}
# 	}
#
# 	auto pAbutmentData = _pToothInfoData->GetToothData(_pToothDoc->GetSelectedToothNumber())->GetAbutmentData();
# 	pAbutmentData->DeleteAbutment(false);
# 	pAbutmentData->DeleteAbutmentInfo();
#
# 	int nAbutmentIndex = pAbutmentData->GetIndex();
# 	if (pAbutmentData)
# 	{
# 		auto pPrevItem = _pLocalDocAP->GetSurfaceModel(pAbutmentData->GetName());
# 		if (pPrevItem)
# 		{
# 			_pLocalDocAP->RemoveSurfaceModel(pAbutmentData->GetName());
#
# 			SAFE_DELETE(pPrevItem);
# 		}
#
# 		if (!_pImgRenderer->IsEmptyModelNumber(nAbutmentIndex))
# 		{
# 			_pImgRenderer->RemoveMeshModel(nAbutmentIndex);
# 			bRes = true;
# 		}
# 	}
#
# 	// Collision date도 삭제
# 	CExtractorCollision* pCollisionExtractor = _pLocalDocAP->GetExtractorCollision();
# 	pCollisionExtractor->SetCollisionObjects(true/*bSingle*/, true/*bErase*/);
#
# 	return bRes;
# }
#
#
# float CActuatorHybridFixture::_getOffset(int nTooth)
# {
# 	float fOffset = 0.f;
#
# 	auto pFixtureData = _pToothInfoData->GetToothData(nTooth)->GetFixtureData();
# 	auto pFixtureInfo = pFixtureData->GetFixtureInfo();
#
# 	if (-1 < pFixtureInfo->strOrder.Find(L"UF(II) 4005S") || -1 < pFixtureInfo->strOrder.Find(L"UF(II) 4505S") || -1 < pFixtureInfo->strOrder.Find(L"UF(II) 5005S"))
# 	{
# ...
#
# 	CString strTooth;
# 	std::vector<CString> vTooth;
#
# 	auto listTooth = _pToothDoc->GetToothNumberList();
# 	for (auto nTooth : listTooth)
# 	{
# 		if (IMPLANT_PLANNING_SELECT == _pToothDoc->GetImplantState(nTooth))
# 		{
# 			strTooth.Format(L"%d", nTooth);
# 			vTooth.push_back(strTooth);
# 		}
# 	}
#
# 	_pUndoRedo->RemoveAllUndoInfo();
# 	_pUndoRedo->RemoveAllRedoInfo();
#
# 	_pUndoRedo->SetInitUndoRedo(strExistingFolder, vTooth);
# }
#
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Insert Undo
# void CActuatorHybridFixture::InsertUndo(CString strHistory)
# {
# 	int nSelectTooth = _pToothDoc->GetSelectedToothNumber();
# 	std::vector<int> vGroupList = _pModuleDocAPImplantSimulation->GetGroupTooth(_pToothDoc->ReplaceToothNumberToEnum(nSelectTooth));
# 	if (0 == vGroupList.size())
# 	{
# 		vGroupList.push_back(nSelectTooth);
# 	}
#
# 	std::vector<CString> vstrGroupList;
# 	for (auto nTooth : vGroupList)
# 	{
# 		CString strTooth;
# 		strTooth.Format(L"%d", nTooth);
#
# 		vstrGroupList.push_back(strTooth);
# 	}
#
# 	_writeMatrixInfo();
#
# 	CString strExistingFolder;
# 	CEnvSession* pEnv = CEnvSession::GetInstance();
# 	ASSERT(pEnv);
# 	strExistingFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), _pLocalDocAP->GetPatientID(), FIXTURE_FILE_PATH);
#
# 	_pUndoRedo->InsertUndo(strExistingFolder, strHistory, vstrGroupList);
#
# 	SetHistory(L"");
#
# 	PostUpdateMessage(BUM::BUM_COMMON_REFLESH_UNDOREDO, TRUE);
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // 선택된 언두 데이터를 보여준다.
# void CActuatorHybridFixture::ShowUndoData(int nUndoIndex)
# {
# 	ShowUndoRedoData(_pUndoRedo->GetChangeUndoInfo(nUndoIndex));
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // 선택된 리두 데이터를 보여준다.
# void CActuatorHybridFixture::ShowRedoData(int nRedoIndex)
# {
# 	ShowUndoRedoData(_pUndoRedo->GetChangeRedoInfo(nRedoIndex));
# }
#
#
# UINT CActuatorHybridFixture::_undoThread(LPVOID lpParam)
# {
# 	CActuatorHybridFixture* pThis = (CActuatorHybridFixture*)lpParam;
#
# 	pThis->_pUndoRedo->Undo(-pThis->_nUndoRedoIndex);
# 	pThis->ShowUndoData(pThis->_nUndoRedoIndex);
#
# 	pThis->SendUpdateMessage(BUM::BUM_COMMON_REFLESH_UNDOREDO, TRUE);
#
# 	pThis->_pUndoRedo->EnableUndoRedo(true);
#
# 	return 1;
# }
#
#
# UINT CActuatorHybridFixture::_redoThread(LPVOID lpParam)
# {
# 	CActuatorHybridFixture* pThis = (CActuatorHybridFixture*)lpParam;
#
# 	pThis->_pUndoRedo->Redo(pThis->_nUndoRedoIndex);
# 	pThis->ShowRedoData(pThis->_nUndoRedoIndex);
#
# 	pThis->SendUpdateMessage(BUM::BUM_COMMON_REFLESH_UNDOREDO, TRUE);
#
# 	pThis->_pUndoRedo->EnableUndoRedo(true);
#
# 	return 1;
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // 선택된 언두 데이터를 보여준다.
# void CActuatorHybridFixture::ShowUndoRedoData(std::vector<int> vTooth)
# {
# 	for (auto nTooth : vTooth)
# 	{
# 		if (11 <= nTooth)
# 		{
# 			LoadUndoRedoFixture(nTooth);
# 		}
# 	}
#
# 	_updateMatrixSelectObject(vTooth);
#
# 	CToothInfoData* pToothInfoData = GetToothInfoData();
# 	CToothData* ToothData = pToothInfoData->GetToothData(_pToothDoc->GetSelectedToothNumber());
# 	CFixtureData* pFixtureData = ToothData->GetFixtureData();
#
# 	CSurfaceModelItem* pFixtureModel = _pLocalDocAP->GetSurfaceModel(pFixtureData->GetName());
# 	//if (NULL != pFixtureModel)
# 	{
# 		_pManipulatorList->InitManipulator();
# 		_pManipulatorList->RenderModelManipulator();
# 		_pManipulatorList->UpdateModelManipulator();
# 	}
#
# 	PostUpdateMessage(BUM::BUM_MODULE_DRAW_TGT_CS_MANIPULATOR, FALSE);
#
# 	_pModuleDocAPImplantSimulation->CheckImplantXml();
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Undo Redo에 사용할 히스토리 값을 세팅한다. (느린 컴퓨터에서는 사용자가 모드를 변경한 후에 언두 인설트가 끝나 히스토리 값 오류 때문에 추가)
# void CActuatorHybridFixture::SetHistory(CString strHistory)
# {
# 	_strHistory = strHistory;
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Undo Redo에 사용할 히스토리 값을 가져 온다.
# CString CActuatorHybridFixture::GetHistory()
# {
# 	return _strHistory;
# }
#
#
# bool CActuatorHybridFixture::GetEnableUndoRedo()
# {
# 	return _pUndoRedo->GetEnableUndoRedo();
# }
#
# void CActuatorHybridFixture::SetEnableUndoRedo(bool bEnable)
# {
# 	_pUndoRedo->EnableUndoRedo(bEnable);
# }
#
# void CActuatorHybridFixture::LoadUndoRedoFixture(int nTooth)
# {
# 	// Fixture
# 	auto pFixtureData = _pToothDoc->GetToothInfoData()->GetToothData(nTooth)->GetFixtureData();
#
# 	auto pPrev = _pLocalDocAP->GetSurfaceModel(pFixtureData->GetName());
# 	_pLocalDocAP->RemoveSurfaceModel(pFixtureData->GetName());
# 	SAFE_RELEASE(pPrev);
#
# 	pFixtureData->LoadFixtureInfo();
# 	auto pItem = pFixtureData->LoadFixture();
# 	if (NULL != pItem)
# 		_pLocalDocAP->AddSurfaceModel(pItem);
#
# 	_pImgRenderer->RemoveMeshModel(pFixtureData->GetIndex());
# 	_updateSelectedFixtureModel(nTooth);
#
# 	// Safety
# 	pFixtureData->LoadView();
#
# 	pPrev = _pLocalDocAP->GetSurfaceModel(pFixtureData->GetSafetyName());
# 	_pLocalDocAP->RemoveSurfaceModel(pFixtureData->GetSafetyName());
# 	SAFE_RELEASE(pPrev);
#
# 	pItem = pFixtureData->LoadSafety();
# 	if (NULL != pItem)
# 		_pLocalDocAP->AddSurfaceModel(pItem);
#
# 	_pImgRenderer->RemoveMeshModel(pFixtureData->GetSafetyIndex());
# 	_updateSelectedSafetyModel(nTooth);
#
# 	// Sleeve
# 	auto pSleeveData = _pToothDoc->GetToothInfoData()->GetToothData(nTooth)->GetSleeveData();
#
# 	pPrev = _pLocalDocAP->GetSurfaceModel(pSleeveData->GetName());
# 	_pLocalDocAP->RemoveSurfaceModel(pSleeveData->GetName());
# 	SAFE_RELEASE(pPrev);
#
# 	pSleeveData->LoadSleeveInfo();
#
# 	pItem = pSleeveData->LoadSleeve();
# 	if (NULL != pItem)
# 		_pLocalDocAP->AddSurfaceModel(pItem);
#
# 	_pImgRenderer->RemoveMeshModel(pSleeveData->GetIndex());
# 	_updateSelectedSleeveModel(nTooth);
#
# 	// Abutment
# 	auto pAbutmentData = _pToothDoc->GetToothInfoData()->GetToothData(nTooth)->GetAbutmentData();
#
# 	pPrev = _pLocalDocAP->GetSurfaceModel(pAbutmentData->GetName());
# 	_pLocalDocAP->RemoveSurfaceModel(pAbutmentData->GetName());
# 	SAFE_RELEASE(pPrev);
#
# 	pAbutmentData->LoadAbutmentInfo();
#
# 	pItem = pAbutmentData->LoadAbutment();
# 	if (NULL != pItem)
# 		_pLocalDocAP->AddSurfaceModel(pItem);
#
# 	_pLocalDocAP->AddSurfaceModel(pItem);
# 	_pImgRenderer->RemoveMeshModel(pAbutmentData->GetIndex());
# 	_updateSelectedAbutmentModel(nTooth);
#
# 	// Zoom
# 	pFixtureData->LoadAllZoom();
# }
#
# bool CActuatorHybridFixture::_writeMatrixInfo()
# {
# 	bool bRes = false;
#
# 	auto pToothInfoData = GetToothInfoData();
#
# 	const int nSelectedToothNumber = GetSelectedToothNumber();
# 	const auto vecGroup = GetSameGroup(nSelectedToothNumber);
#
# 	for (auto iter = vecGroup.begin(); iter != vecGroup.end(); iter++)
# 	{
# 		CToothData* pToothData = pToothInfoData->GetToothData(*iter);
# 		if (pToothData)
# 		{
# 			CFixtureData* pFixtureData = pToothData->GetFixtureData();
# 			CSleeveData* pSleeveData = pToothData->GetSleeveData();
# 			CAbutmentData* pAbutmentData = pToothData->GetAbutmentData();
#
#
# 			int nFixture = pFixtureData->GetIndex();
# 			int nSleeve = pSleeveData->GetIndex();
# 			int nAbutment = pAbutmentData->GetIndex();
#
# 			if (!_pImgRenderer->IsEmptyModelNumber(nFixture))
# 			{
# 				pFixtureData->SaveFixture(nullptr);
#
# 				pFixtureData->SaveView();
# 			}
# 			if (!_pImgRenderer->IsEmptyModelNumber(nSleeve))
# 			{
# 				pSleeveData->SaveSleeve(nullptr);
# 			}
# 			if (!_pImgRenderer->IsEmptyModelNumber(nAbutment))
# 			{
# 				pAbutmentData->SaveAbutment(nullptr);
# 			}
#
# 			bRes = true;
# 		}
# 	}
#
# 	return bRes;
# }
#
#
# void CActuatorHybridFixture::_CrDensity()
# {
# 	CList<int, int> FList;
#
# 	auto modelMap = _pImgRenderer->GetSurfaceModelMap();
# 	for (auto pair : modelMap)
# 	{
# 		int nIdx = pair.first;
# 		CSurfaceModelItem* pModel = pair.second;
# 		if (nIdx >= FIXTURE_MODEL_INDEX && nIdx <= FIXTURE_MODEL_END_INDEX)
# 			//if (nIdx == 241)
# 		{
# 			FList.AddTail(nIdx);
# 		}
# 		_pImgRenderer->SetDrawable(false, nIdx);
#
# 		std::cout << nIdx << " : " << CT2CA(pModel->GetName()) << std::endl;
# 		//SAFE_DELETE(pModel);
# 	}
#
# 	HWND hwnd = m_pParentPane->GetSafeHwnd();
# 	static bool result = _pImgRenderer->InitSR_VolumeDensity(hwnd);
#
# 	POSITION pos = FList.GetHeadPosition(); // 리스트의 첫 번째 요소 위치 얻기
# 	while (pos != NULL)
# 	{
# 		int value = FList.GetNext(pos);
#
# 		_pImgRenderer->SetDrawable(true, value);
# 		VolumeDensityImgDraw(value);
# 		_pImgRenderer->SetDrawable(false, value);
# 	}
#
# 	for (auto pair : modelMap)
# 	{
# 		int nIdx = pair.first;
#
# 		_pImgRenderer->SetDrawable(true, nIdx);
#
# 	}
# }
#
#
#
#
# void CActuatorHybridFixture::SaveImgBuf(CImgBuf& pImgBuf, const int nModelNo)
# {
# 	if (!pImgBuf.IsInitialized()) {
# 		return;
# 	}
#
# 	if (nModelNo == 0) {
# 		int newWidth = accumulatedWidth + pImgBuf.Width();
# 		int height = max(pImgBuf.Height(), FixtureDensityimage.IsNull() ? 0 : FixtureDensityimage.GetHeight());
#
# 		if (FixtureDensityimage.IsNull()) {
# 			// CImage가 초기화되지 않은 경우, 새 이미지를 생성합니다.
# 			FixtureDensityimage.Create(newWidth, height, 32);
# 		}
# 		else {
# 			// CImage의 크기를 조정합니다.
# 			CImage newImage;
# 			newImage.Create(newWidth, height, 32);
#
# 			// 기존 이미지를 새 이미지에 복사합니다.
# 			HDC newDC = newImage.GetDC();
# 			HDC oldDC = FixtureDensityimage.GetDC();
# 			BitBlt(newDC, 0, 0, accumulatedWidth, height, oldDC, 0, 0, SRCCOPY);
# 			FixtureDensityimage.ReleaseDC();
# 			newImage.ReleaseDC();
#
# 			// 새 이미지로 교체합니다.
# 			FixtureDensityimage.Attach(newImage.Detach());
# 		}
#
# 		BYTE* pSrc = pImgBuf.GetBuffer();
# 		if (pSrc == nullptr) {
# 			return;
# 		}
#
# 		int nSrcStride = pImgBuf.Width() * 4;
#
# 		for (int y = 0; y < pImgBuf.Height(); ++y) {
# 			BYTE* pDest = (BYTE*)FixtureDensityimage.GetPixelAddress(accumulatedWidth, y);
# 			BYTE* pSrcLine = pSrc + nSrcStride * y;
# 			memcpy(pDest, pSrcLine, nSrcStride); // 새 이미지 부분에 복사
# 		}
#
# 		accumulatedWidth = newWidth; // 누적된 너비 업데이트
# 	}
# 	else {
# 		if (!FixtureDensityimage.IsNull())
# 		{
#
# 			//_pToothDoc->ReplaceEnumToToothNumber(nModelNo);
# 			/*CString str;
# 			str.Format(_T("%d"), nModelNo - FIXTURE_MODEL_INDEX);*/
# 			//CImage tempImage;
# 			//tempImage.Attach(FixtureDensityimage.Detach()); // 기존 image 객체를 tempImage로 이동
# 			//_pLocalDocAP->SetDensityImg(tempImage); // tempImage를 벡터에 저장
# 			//_pLocalDocAP->SetDensityNum(str);
#
# 			//_pLocalDocAP->SetDensityImgMap(nModelNo - FIXTURE_MODEL_INDEX, tempImage);
# 			CEnvSession* pEnv = CEnvSession::GetInstance();
# 			ASSERT(pEnv);
#
# 			CString strPath;
# 			CString strFileName;
#
# 			strPath.Format(_T("%s%s\\%s"), pEnv->GetPath_UserData(), _pLocalDoc->GetPatientID(), DENSITY_FILE_PATH);
#
# 			if (!PathFileExists(strPath)) {
# 				SHCreateDirectoryEx(NULL, strPath, NULL);
# 			}
#
# 			strFileName.Format(_T("%d.png"), nModelNo - FIXTURE_MODEL_INDEX);
#
# 			strPath = strPath + strFileName;
#
# 			HRESULT hr = FixtureDensityimage.Save(strPath, Gdiplus::ImageFormatPNG);
# 			if (FAILED(hr)) {
# 				// 저장 실패 처리
# 			}
#
# 			//_pLocalDocAP->SetDensityImg(image);
# 			FixtureDensityimage.Destroy(); // 이미지 저장 후 리소스 해제
# 			accumulatedWidth = 0; // 누적된 너비 초기화
# 		}
# 	}
# }
#
#
#
#
# void CActuatorHybridFixture::SaveImgBufToFile(CImgBuf& pImgBuf, const CString& strFileName)
# {
# 	if (!pImgBuf.IsInitialized()) {
# 		return; // 이미지 버퍼가 초기화되지 않은 경우 함수를 종료합니다.
# 	}
#
# 	CImage image;
# 	int width = pImgBuf.Width();
# 	int height = pImgBuf.Height();
#
# 	// CImage를 이미지 버퍼의 크기에 맞게 생성합니다.
# 	image.Create(width, height, 32);
#
# 	BYTE* pSrc = pImgBuf.GetBuffer();
# 	if (pSrc == nullptr) {
# 		return; // 이미지 버퍼에서 데이터를 가져올 수 없는 경우 함수를 종료합니다.
# 	}
#
# 	int nSrcStride = width * 4;
#
# 	for (int y = 0; y < height; ++y) {
# 		BYTE* pDest = (BYTE*)image.GetPixelAddress(0, y);
# 		BYTE* pSrcLine = pSrc + nSrcStride * y;
# 		memcpy(pDest, pSrcLine, nSrcStride); // 이미지 데이터를 CImage 객체에 복사합니다.
# 	}
#
# 	// 이미지 파일을 저장할 경로를 설정합니다.
# 	CEnvSession* pEnv = CEnvSession::GetInstance();
# 	ASSERT(pEnv);
#
# 	CString strPath;
# 	strPath.Format(_T("%s%s\\%s"), pEnv->GetPath_UserData(), _pLocalDoc->GetPatientID(), DENSITY_FILE_PATH);
#
# 	if (!PathFileExists(strPath)) {
# 		SHCreateDirectoryEx(NULL, strPath, NULL);
# 	}
#
# 	strPath = strPath + strFileName;
#
# 	HRESULT hr = image.Save(strPath, Gdiplus::ImageFormatPNG);
# 	if (FAILED(hr)) {
# 		// 저장 실패 처리
# 	}
#
# 	image.Destroy(); // 이미지 리소스 해제
# }
#
#
#
#
# void CActuatorHybridFixture::VolumeDensityImgDraw(int nModelNum)
# {
# 	CLocalDocAP* pLocalDoc = reinterpret_cast<CLocalDocAP*>(GetLocalDoc());
# 	const CVolumeDoc* pVolumeDoc = pLocalDoc->GetVolumeDoc();
# 	POSITION pos = pVolumeDoc->GetHeadPosition();
# 	CVolumeItem* pVolumeItem = pVolumeDoc->GetVolumeItem(pos);
# 	ASSERT(pVolumeItem);
#
# 	ST_VolumeInfo volumeInfo = pVolumeItem->GetInfo();
#
# 	std::array<double, 3> spacing = { volumeInfo.fResX, volumeInfo.fResY, volumeInfo.fSliceGap /*+ volumeInfo.fThickness*/ };
# 	std::array<int, 3> dimension = { volumeInfo.nImgWidth, volumeInfo.nImgHeight, volumeInfo.nImgSlices };
#
#
# 	CSurfaceModelItem* pFixtureModel = nullptr;
# 	CMatrixMxN mTrans(4, 4);
# 	mTrans.eye();
#
# 	//int nToothNumber = GetSelectedToothNumber();
# 	int nToothNumber = nModelNum - FIXTURE_MODEL_INDEX;
# 	CToothData* cToothData = _pToothInfoData->GetToothData(nToothNumber);
# 	CFixtureData* pFixtureData = cToothData->GetFixtureData();
# 	CSurfaceModelDoc* pModelDoc = GetLocalDoc()->GetSurfaceDoc();
#
# 	if (cToothData != nullptr && pFixtureData != nullptr)
# 	{
# 		int nIndex = pFixtureData->GetIndex();
# 		mTrans = pFixtureData->GetMatrix();
# 		CString strName = pFixtureData->GetName();
#
# 		pFixtureModel = pModelDoc->GetItem(strName);
# 	}
#
#
# 	if (pFixtureModel != nullptr)
# 	{
# 		std::shared_ptr<CImage> pImgDeleteAll = std::make_shared<CImage>();
#
# 		CInterfaceFixtureBoneDensity interfaceDensity;
# 		interfaceDensity.SetVolumeData(*pVolumeItem->GetVolumePtr(), spacing, dimension);
# 		interfaceDensity.SetFixture(pFixtureModel, mTrans);
# 		interfaceDensity.Update();
# 		std::vector<std::shared_ptr<CImgBuf>> vecImgBuf = interfaceDensity.GetImages();
#
#
# 		// vecImgBuf에서 첫 번째 이미지 버퍼부터 세 번째 이미지 버퍼까지 순회하며 파일로 저장
# 		for (int i = 0; i < std::min(static_cast<int>(vecImgBuf.size()), 4); ++i) // 최대 4개의 이미지 버퍼 처리
# 		{
# 			std::shared_ptr<CImgBuf> pImagBuf = vecImgBuf.at(i);
#
# 			CString strFileName;
# 			// 파일 이름에 인덱스를 추가하여 각 이미지를 구분
# 			strFileName.Format(_T("%d_%d.png"), nModelNum - FIXTURE_MODEL_INDEX, i);
#
# 			SaveImgBufToFile(*pImagBuf, strFileName);
# 		}
# 	}
#
#
#
#
# 	// <------------> Old
# 	//DirectX::XMMATRIX mt;
# 	//tempM.GetDXMatrix(&mt);
#
# 	//DirectX::XMVECTOR S, R, T;
# 	//DirectX::XMMatrixDecompose(&S, &R, &T, mt);
# 	//CMatrixMxN axisMatrix;
# 	//axisMatrix.SetDXMatrix(&(DirectX::XMMatrixRotationQuaternion(R)));
#
# 	//float3 crossV{ axisMatrix.val[0] };
# 	//float3 upV{ axisMatrix.val[1] };
# 	//float3 lookV{ axisMatrix.val[2] };
#
# 	//float3 cen;
# 	//_pImgRenderer->GetCurrentCenterPos(nModelNum, &cen);
#
#
# 	////CImgBuf& pImgBuf = GetImageBuf();
#
# 	//// CImgBuf 객체 생성
# 	////CImgBuf pImgBuf;
#
# 	//const CSize ImgSize(46, 83);
#
# 	//ST_ImageInfo stImgInfo;
# 	//stImgInfo.nImgType = bufType_RGB;
# 	//stImgInfo.nImgWidth = ImgSize.cx;
# 	//stImgInfo.nImgHeight = ImgSize.cy;
#
# 	//std::unique_ptr<CImgBuf> pImgBuf = std::make_unique<CImgBuf>();
# 	//pImgBuf->SetImageInfo(stImgInfo);
# 	//pImgBuf->ClearImage();
#
#
# 	//if (pImgBuf->IsInitialized() && pos)
# 	//{
# 	//	//float fMMperPixel = GetCurrentPixelSpace();
# 	//	float fMMperPixel = 0.155369788f; //일정한 크기의 이미지를 위해 값 고정.
#
# 	//	CVolumeItem* pVolumeItem = pVolumeDoc->GetVolumeItem(pos);
# 	//	ASSERT(pVolumeItem);
#
# 	//	float3 fCPos = cen + lookV * 30;
# 	//	// 정면
# 	//	_pImgRenderer->DrawImage_FixtureDensity(pVolumeItem, fCPos, cen, upV, crossV, fMMperPixel, *pImgBuf);
#
# 	//	CEnvSession* pEnv = CEnvSession::GetInstance();
# 	//	ASSERT(pEnv);
#
#
# 	//	SaveImgBuf(*pImgBuf, 0);
#
# 	//	fCPos = cen + -lookV * 30;
# 	//	// 후면
# 	//	_pImgRenderer->DrawImage_FixtureDensity(pVolumeItem, fCPos, cen, upV, crossV, fMMperPixel, *pImgBuf);
#
# 	//	SaveImgBuf(*pImgBuf, 0);
#
# 	//	fCPos = cen + crossV * 30;
# 	//	// 옆면1
# 	//	_pImgRenderer->DrawImage_FixtureDensity(pVolumeItem, fCPos, cen, upV, crossV, fMMperPixel, *pImgBuf);
#
# 	//	SaveImgBuf(*pImgBuf, 0);
#
# 	//	fCPos = cen + -crossV * 30;
# 	//	// 옆면2
# 	//	_pImgRenderer->DrawImage_FixtureDensity(pVolumeItem, fCPos, cen, upV, crossV, fMMperPixel, *pImgBuf);
#
# 	//	SaveImgBuf(*pImgBuf, 0);
#
# 	//	SaveImgBuf(*pImgBuf, nModelNum);
#
# 	//}
# }

# %%
#cpp File 커서에서 특정 구문 전체 검색 (클래스 검색?) 

cpp_cursor:clang.cindex.Cursor  = target.cursor
cppVisitor = SimpleVisitor(cpp_cursor, target.spelling)
stmt_map = {}
simpleVisit.for_make_stmt_map(stmt_map)


memberRefExprs = stmt_map[clang.cindex.CursorKind.MEMBER_REF_EXPR]
name_set = set()
temp = []
updateMSG=[]

for node in memberRefExprs:
    if node.spelling.__contains__("UpdateMessage"):
        updateMSG.append(node)
    
    if node.location.file and node.location.file.name.__contains__("AutoPlanning"):
        temp.append(node)
        # print(f"{node.displayname} {node.location.file.name}")
        name_set.add(node.displayname)
memberRefExprs = temp
#계층 구조
# visit_node(update_node)

print(updateMSG.__len__())
for node in updateMSG:
    print(f"{node.displayname} {node.location.line}")
# for name in name_set:
    # print(name)
# Out:
# Skipping node with unknown CursorKind: Unknown template argument kind 280
# 12
# PostUpdateMessage 1280
# PostUpdateMessage 1284
# SendUpdateMessage 2578
# PostUpdateMessage 2882
# SendUpdateMessage 3051
# SendUpdateMessage 3074
# SendUpdateMessage 3078
# PostUpdateMessage 3741
# PostUpdateMessage 3814
# SendUpdateMessage 3841
# SendUpdateMessage 3856
# PostUpdateMessage 3890

# %%
#cpp File 커서에서 특정 메서드 커서로 
target_cursor:clang.cindex.Cursor  = target.cursor
for child in target_cursor.get_children():
    if child.kind.name == "CXX_METHOD" and child.spelling == "OnUpdate":
        update_node = child
        break

#특정 메서드 분석
update_visitor = SimpleVisitor(update_node, update_node.location.file.name)
stmt_map={}
update_visitor.for_make_stmt_map(stmt_map)
for stmt_key in stmt_map:
    print(f"{stmt_key} : {stmt_map[stmt_key].__len__()}")

#계층 구조
# visit_node(update_node)
# Out:
# CursorKind.CXX_METHOD : 1
# CursorKind.TYPE_REF : 75
# CursorKind.PARM_DECL : 4
# CursorKind.COMPOUND_STMT : 60
# CursorKind.DECL_STMT : 52
# CursorKind.VAR_DECL : 52
# CursorKind.UNEXPOSED_EXPR : 564
# CursorKind.MEMBER_REF_EXPR : 343
# CursorKind.DECL_REF_EXPR : 500
# CursorKind.CXX_DYNAMIC_CAST_EXPR : 3
# CursorKind.STRING_LITERAL : 120
# CursorKind.CSTYLE_CAST_EXPR : 39
# CursorKind.IF_STMT : 82
# CursorKind.BINARY_OPERATOR : 82
# CursorKind.NAMESPACE_REF : 42
# CursorKind.CALL_EXPR : 291
# CursorKind.OVERLOADED_DECL_REF : 200
# CursorKind.CXX_REINTERPRET_CAST_EXPR : 3
# CursorKind.CXX_BOOL_LITERAL_EXPR : 53
# CursorKind.INTEGER_LITERAL : 31
# CursorKind.PAREN_EXPR : 7
# CursorKind.FOR_STMT : 2
# CursorKind.UNARY_OPERATOR : 5
# CursorKind.CXX_STATIC_CAST_EXPR : 4
# CursorKind.CXX_THIS_EXPR : 3
# CursorKind.WHILE_STMT : 1
# CursorKind.NULL_STMT : 1
# CursorKind.RETURN_STMT : 1

# %%
call_exp_node_list:[clang.cindex.Cursor] = stmt_map[clang.cindex.CursorKind.CALL_EXPR      ] 
print(f"외부 파일 포함 {call_exp_node_list.__len__()}")

print(target.spelling)

file_set = set()

file_list = []

temp:[clang.cindex.Cursor] = []
for node in call_exp_node_list:
    if node.location.file.name.__contains__("AutoPlanning"):
        temp.append(node)
        file_set.add(node.location.file.name)
        file_list.append(node)
call_exp_node_list = temp
print(f"내부 파일 {call_exp_node_list.__len__()}")
for fname in file_set:
    print(fname)


check_set = set()
for node in file_list:
    if check_set.__contains__(node.location.file.name):
        continue
    else:
        check_set.add(node.location.file.name)
        print(f"{node.displayname} {node.location}")
# Out:
# 외부 파일 포함 291
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp
# 내부 파일 291
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorHybridFixture.cpp
#  <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorHybridFixture.cpp', line 332, column 8>

# %%
for expNode in stmt_map[clang.cindex.CursorKind.MEMBER_REF_EXPR   ]:
    print(f"Node found: {expNode.spelling} ({expNode.kind.name})")
    # print(f"Location : {expNode.location}")
    print(f"Location : {expNode.location.line} : {expNode.location.column}") #(파일은 동일한듯?)
# Out:
# Node found: OnUpdate (MEMBER_REF_EXPR)
# Location : 320 : 23
# Node found: GetCommand (MEMBER_REF_EXPR)
# Location : 322 : 96
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 322 : 82
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 331 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 331 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 332 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 332 : 94
# Node found: GetWritableModuleDoc (MEMBER_REF_EXPR)
# Location : 333 : 83
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 333 : 69
# Node found: GetPanoAxialEvent (MEMBER_REF_EXPR)
# Location : 335 : 21
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 335 : 7
# Node found: _bUpdate (MEMBER_REF_EXPR)
# Location : 336 : 4
# Node found: GetUseCS (MEMBER_REF_EXPR)
# Location : 338 : 18
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 340 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 340 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 341 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 341 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 343 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 343 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 344 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 344 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 348 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 348 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 349 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 349 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 351 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 351 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 352 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 352 : 4
# Node found: UpdateModelManipulator (MEMBER_REF_EXPR)
# Location : 356 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 356 : 3
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 361 : 46
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 361 : 90
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 366 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 366 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 367 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 367 : 94
# Node found: _CrDensity (MEMBER_REF_EXPR)
# Location : 370 : 4
# Node found:  (MEMBER_REF_EXPR)
# Location : 383 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 387 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 387 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 388 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 388 : 94
# Node found: _pUndoRedo (MEMBER_REF_EXPR)
# Location : 389 : 15
# Node found:  (MEMBER_REF_EXPR)
# Location : 394 : 4
# Node found: GetPath_UserData (MEMBER_REF_EXPR)
# Location : 394 : 49
# Node found: GetPatientID (MEMBER_REF_EXPR)
# Location : 394 : 83
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 394 : 69
# Node found: SetDefaultFolder (MEMBER_REF_EXPR)
# Location : 396 : 16
# Node found: _pUndoRedo (MEMBER_REF_EXPR)
# Location : 396 : 4
# Node found: RemoveAllUndoInfo (MEMBER_REF_EXPR)
# Location : 398 : 16
# Node found: _pUndoRedo (MEMBER_REF_EXPR)
# Location : 398 : 4
# Node found: RemoveAllRedoInfo (MEMBER_REF_EXPR)
# Location : 399 : 16
# Node found: _pUndoRedo (MEMBER_REF_EXPR)
# Location : 399 : 4
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 404 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 404 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 405 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 405 : 94
# Node found: GetUpdateMatrixObject (MEMBER_REF_EXPR)
# Location : 407 : 44
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 407 : 30
# Node found:  (MEMBER_REF_EXPR)
# Location : 412 : 4
# Node found: UpdateMatrixObject (MEMBER_REF_EXPR)
# Location : 415 : 24
# Node found: GetExtractorCollision (MEMBER_REF_EXPR)
# Location : 417 : 60
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 417 : 46
# Node found: InitializeCollisionObjects (MEMBER_REF_EXPR)
# Location : 418 : 24
# Node found: GetCommand (MEMBER_REF_EXPR)
# Location : 420 : 97
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 420 : 83
# Node found: InitialMeasureData (MEMBER_REF_EXPR)
# Location : 422 : 21
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 427 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 427 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 428 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 428 : 94
# Node found: GetCurrentStep (MEMBER_REF_EXPR)
# Location : 429 : 62
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 429 : 48
# Node found: UpdateModelManipulator (MEMBER_REF_EXPR)
# Location : 436 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 436 : 4
# Node found: GetPanoAxialEvent (MEMBER_REF_EXPR)
# Location : 439 : 22
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 439 : 8
# Node found: _bUpdate (MEMBER_REF_EXPR)
# Location : 440 : 5
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 443 : 46
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 443 : 90
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 447 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 447 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 448 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 448 : 94
# Node found: _initFixture (MEMBER_REF_EXPR)
# Location : 449 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 453 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 453 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 454 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 454 : 94
# Node found: GetSelectedToothNumber (MEMBER_REF_EXPR)
# Location : 455 : 30
# Node found: _applyLibrary (MEMBER_REF_EXPR)
# Location : 457 : 3
# Node found: _placeFixtureSleeveAbutment (MEMBER_REF_EXPR)
# Location : 458 : 3
# Node found: GetFixtureData (MEMBER_REF_EXPR)
# Location : 462 : 76
# Node found: GetToothData (MEMBER_REF_EXPR)
# Location : 462 : 40
# Node found: _pToothInfoData (MEMBER_REF_EXPR)
# Location : 462 : 23
# Node found: RemoveMeshModel (MEMBER_REF_EXPR)
# Location : 463 : 18
# Node found: _pImgRenderer (MEMBER_REF_EXPR)
# Location : 463 : 3
# Node found:  (MEMBER_REF_EXPR)
# Location : 463 : 34
# Node found: _updateSelectedFixtureModel (MEMBER_REF_EXPR)
# Location : 465 : 3
# Node found: _updateSelectedSafetyModel (MEMBER_REF_EXPR)
# Location : 466 : 3
# Node found: _updateSelectedSleeveModel (MEMBER_REF_EXPR)
# Location : 467 : 3
# Node found: _updateSelectedAbutmentModel (MEMBER_REF_EXPR)
# Location : 468 : 3
# Node found:  (MEMBER_REF_EXPR)
# Location : 471 : 12
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 473 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 473 : 4
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 474 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 474 : 4
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 478 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 478 : 4
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 479 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 479 : 4
# Node found: InitManipulator (MEMBER_REF_EXPR)
# Location : 482 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 482 : 3
# Node found: RenderModelManipulator (MEMBER_REF_EXPR)
# Location : 483 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 483 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 485 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 485 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 486 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 486 : 3
# Node found:  (MEMBER_REF_EXPR)
# Location : 490 : 3
# Node found: GetExtractorCollision (MEMBER_REF_EXPR)
# Location : 492 : 60
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 492 : 46
# Node found: SetCollisionObjects (MEMBER_REF_EXPR)
# Location : 493 : 24
# Node found: _transparentModels (MEMBER_REF_EXPR)
# Location : 497 : 3
# Node found: SetHistory (MEMBER_REF_EXPR)
# Location : 501 : 4
# Node found: InsertUndo (MEMBER_REF_EXPR)
# Location : 502 : 4
# Node found: GetHistory (MEMBER_REF_EXPR)
# Location : 502 : 15
# Node found:  (MEMBER_REF_EXPR)
# Location : 516 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 522 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 522 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 523 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 523 : 94
# Node found: _transparentModels (MEMBER_REF_EXPR)
# Location : 524 : 3
# Node found: GetWritableModuleDoc (MEMBER_REF_EXPR)
# Location : 526 : 84
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 526 : 70
# Node found: GetUseCS (MEMBER_REF_EXPR)
# Location : 527 : 19
# Node found: UpdateModelManipulator (MEMBER_REF_EXPR)
# Location : 528 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 528 : 4
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 530 : 46
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 530 : 90
# Node found: GetPanoAxialEvent (MEMBER_REF_EXPR)
# Location : 534 : 21
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 534 : 7
# Node found: _bUpdate (MEMBER_REF_EXPR)
# Location : 535 : 4
# Node found: SetTimer (MEMBER_REF_EXPR)
# Location : 538 : 3
# Node found:  (MEMBER_REF_EXPR)
# Location : 550 : 3
# Node found:  (MEMBER_REF_EXPR)
# Location : 560 : 3
# Node found:  (MEMBER_REF_EXPR)
# Location : 569 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 573 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 573 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 574 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 574 : 94
# Node found: GetSelectedToothNumber (MEMBER_REF_EXPR)
# Location : 575 : 29
# Node found: GetUpdateMatrixObject (MEMBER_REF_EXPR)
# Location : 577 : 44
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 577 : 30
# Node found:  (MEMBER_REF_EXPR)
# Location : 579 : 3
# Node found: GetSelectedToothNumber (MEMBER_REF_EXPR)
# Location : 579 : 32
# Node found: _pToothDoc (MEMBER_REF_EXPR)
# Location : 579 : 20
# Node found:  (MEMBER_REF_EXPR)
# Location : 583 : 12
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 585 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 585 : 4
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 586 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 586 : 4
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 590 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 590 : 4
# Node found: SetManipulatorRenderState (MEMBER_REF_EXPR)
# Location : 591 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 591 : 4
# Node found: InitManipulator (MEMBER_REF_EXPR)
# Location : 594 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 594 : 3
# Node found: RenderModelManipulator (MEMBER_REF_EXPR)
# Location : 595 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 595 : 3
# Node found: UpdateModelManipulator (MEMBER_REF_EXPR)
# Location : 596 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 596 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 598 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 598 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 599 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 599 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 605 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 605 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 606 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 606 : 94
# Node found: _setGrouping (MEMBER_REF_EXPR)
# Location : 609 : 3
# Node found: GetUpdateMatrixObject (MEMBER_REF_EXPR)
# Location : 611 : 44
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 611 : 30
# Node found:  (MEMBER_REF_EXPR)
# Location : 616 : 4
# Node found: UpdateMatrixObject (MEMBER_REF_EXPR)
# Location : 619 : 24
# Node found: InitManipulator (MEMBER_REF_EXPR)
# Location : 621 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 621 : 3
# Node found: RenderModelManipulator (MEMBER_REF_EXPR)
# Location : 622 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 622 : 3
# Node found: UpdateModelManipulator (MEMBER_REF_EXPR)
# Location : 623 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 623 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 625 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 625 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 626 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 626 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 634 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 634 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 635 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 635 : 94
# Node found: GetImplantInfo (MEMBER_REF_EXPR)
# Location : 639 : 35
# Node found: _pModuleDocAPImplantSimulation (MEMBER_REF_EXPR)
# Location : 639 : 3
# Node found: _pToothDoc (MEMBER_REF_EXPR)
# Location : 652 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 658 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 658 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 659 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 659 : 94
# Node found: _removeFixtureSleeveModel (MEMBER_REF_EXPR)
# Location : 661 : 7
# Node found: GetImplantInfo (MEMBER_REF_EXPR)
# Location : 664 : 36
# Node found: _pModuleDocAPImplantSimulation (MEMBER_REF_EXPR)
# Location : 664 : 4
# Node found: _pToothDoc (MEMBER_REF_EXPR)
# Location : 677 : 4
# Node found:  (MEMBER_REF_EXPR)
# Location : 680 : 4
# Node found: GetSelectedToothNumber (MEMBER_REF_EXPR)
# Location : 680 : 33
# Node found: _pToothDoc (MEMBER_REF_EXPR)
# Location : 680 : 21
# Node found: SetHistory (MEMBER_REF_EXPR)
# Location : 683 : 4
# Node found: InsertUndo (MEMBER_REF_EXPR)
# Location : 684 : 4
# Node found: GetHistory (MEMBER_REF_EXPR)
# Location : 684 : 15
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 690 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 690 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 691 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 691 : 94
# Node found: GetCommand (MEMBER_REF_EXPR)
# Location : 696 : 97
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 696 : 83
# Node found:  (MEMBER_REF_EXPR)
# Location : 704 : 4
# Node found:  (MEMBER_REF_EXPR)
# Location : 713 : 4
# Node found:  (MEMBER_REF_EXPR)
# Location : 722 : 4
# Node found:  (MEMBER_REF_EXPR)
# Location : 731 : 4
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 736 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 736 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 737 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 737 : 94
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 738 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 738 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 739 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 739 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 741 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 741 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 742 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 742 : 3
# Node found: _hManipulatorTransformEvent (MEMBER_REF_EXPR)
# Location : 745 : 14
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 750 : 46
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 750 : 90
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 754 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 754 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 755 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 755 : 94
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 756 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 756 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 757 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 757 : 3
# Node found: _hManipulatorTransformEvent (MEMBER_REF_EXPR)
# Location : 762 : 15
# Node found: _hReceiveManipulatorTransformEvent (MEMBER_REF_EXPR)
# Location : 764 : 26
# Node found: InsertUndo (MEMBER_REF_EXPR)
# Location : 767 : 3
# Node found: GetHistory (MEMBER_REF_EXPR)
# Location : 767 : 14
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 772 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 772 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 773 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 773 : 94
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 778 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 778 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 779 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 779 : 3
# Node found: _hManipulatorTransformEvent (MEMBER_REF_EXPR)
# Location : 781 : 14
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 788 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 788 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 789 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 789 : 94
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 792 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 792 : 3
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 793 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 793 : 3
# Node found: _hManipulatorTransformEvent (MEMBER_REF_EXPR)
# Location : 795 : 14
# Node found: _hReceiveManipulatorTransformEvent (MEMBER_REF_EXPR)
# Location : 797 : 25
# Node found: InsertUndo (MEMBER_REF_EXPR)
# Location : 799 : 3
# Node found: GetHistory (MEMBER_REF_EXPR)
# Location : 799 : 14
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 807 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 807 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 808 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 808 : 94
# Node found: GetCurrentStep (MEMBER_REF_EXPR)
# Location : 810 : 41
# Node found: _pLocalDocAP (MEMBER_REF_EXPR)
# Location : 810 : 27
# Node found: OnMouseMove (MEMBER_REF_EXPR)
# Location : 813 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 813 : 4
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 821 : 46
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 821 : 90
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 842 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 842 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 843 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 843 : 94
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 846 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 846 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 847 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 847 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 851 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 851 : 4
# Node found: ChangeModelDrawable (MEMBER_REF_EXPR)
# Location : 852 : 23
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 852 : 4
# Node found: UpdateModelManipulator (MEMBER_REF_EXPR)
# Location : 855 : 22
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 855 : 3
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 862 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 862 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 863 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 863 : 94
# Node found: GetEnableUndoRedo (MEMBER_REF_EXPR)
# Location : 864 : 7
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 866 : 8
# Node found: OnMouseWheel (MEMBER_REF_EXPR)
# Location : 870 : 28
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 870 : 9
# Node found: _nSelectedModelIndex (MEMBER_REF_EXPR)
# Location : 870 : 68
# Node found: _nDrawTime (MEMBER_REF_EXPR)
# Location : 872 : 6
# Node found: _drawHandle (MEMBER_REF_EXPR)
# Location : 874 : 18
# Node found: _drawHandle (MEMBER_REF_EXPR)
# Location : 877 : 7
# Node found: m_hThread (MEMBER_REF_EXPR)
# Location : 877 : 33
# Node found: SetHistory (MEMBER_REF_EXPR)
# Location : 879 : 7
# Node found: InsertUndo (MEMBER_REF_EXPR)
# Location : 880 : 7
# Node found: GetHistory (MEMBER_REF_EXPR)
# Location : 880 : 18
# Node found: _nWheel (MEMBER_REF_EXPR)
# Location : 887 : 6
# Node found: _nWheel (MEMBER_REF_EXPR)
# Location : 888 : 13
# Node found: _nWheel (MEMBER_REF_EXPR)
# Location : 890 : 5
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 901 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 901 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 902 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 902 : 94
# Node found: GetEnableUndoRedo (MEMBER_REF_EXPR)
# Location : 903 : 7
# Node found: EnableUndoRedo (MEMBER_REF_EXPR)
# Location : 905 : 16
# Node found: _pUndoRedo (MEMBER_REF_EXPR)
# Location : 905 : 4
# Node found: _nUndoRedoIndex (MEMBER_REF_EXPR)
# Location : 907 : 4
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 914 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 914 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 915 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 915 : 94
# Node found: GetEnableUndoRedo (MEMBER_REF_EXPR)
# Location : 916 : 7
# Node found: EnableUndoRedo (MEMBER_REF_EXPR)
# Location : 918 : 16
# Node found: _pUndoRedo (MEMBER_REF_EXPR)
# Location : 918 : 4
# Node found: _nUndoRedoIndex (MEMBER_REF_EXPR)
# Location : 920 : 4
# Node found: GetLogStep (MEMBER_REF_EXPR)
# Location : 928 : 7
# Node found: ProcLogRcvStep (MEMBER_REF_EXPR)
# Location : 928 : 21
# Node found: _strName (MEMBER_REF_EXPR)
# Location : 929 : 50
# Node found: ConEventMessage (MEMBER_REF_EXPR)
# Location : 929 : 94
# Node found: GetManipulator (MEMBER_REF_EXPR)
# Location : 935 : 108
# Node found: _pManipulatorList (MEMBER_REF_EXPR)
# Location : 935 : 89
# Node found: Reset (MEMBER_REF_EXPR)
# Location : 936 : 18
# Node found: _bMakeCrossSection (MEMBER_REF_EXPR)
# Location : 944 : 27
# Node found:  (MEMBER_REF_EXPR)
# Location : 970 : 4

# %%
#1차 자식만 탐색
root_node: clang.cindex.Cursor = target.cursor


other_file_nodes = []
nodes = []

for node in root_node.get_children():
    node_file: clang.cindex.File = node.location.file

    if node_file and node_file.name == target.spelling:
        nodes.append(node)
    else:
        other_file_nodes.append(node)

for node in nodes:
    print(f"Node found: {node.spelling} ({node.kind.name})")
    print(f"Location : {node.location}")



print(f"other size : {other_file_nodes.__len__()} size : {nodes.__len__()}")

code = None
for node in nodes:
    simpleVisit = SimpleVisitor(node, target.spelling)
    code = simpleVisit.make_comment_code(code)

# print(code)

# 파일을 쓰기 모드로 열기 (파일이 없다면 생성됩니다)
with open('result.cpp', 'w') as file:
    file.write(code)



source = simpleVisit.make_comment_code()
print(target.spelling)

#많이 나온다.. 파일 필터링은 필수.
# for node in other_file_nodes:
#     if node.kind == clang.cindex.CursorKind.CXX_METHOD or node.kind == clang.cindex.CursorKind.CONSTRUCTOR:
#         print(f"Node found: {node.spelling} ({node.kind.name})")
#         print(f"Location : {node.location}")
# Out:
# Node found: CActuatorPanoFixture (CONSTRUCTOR)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 31, column 23>
# Node found: ~CActuatorPanoFixture (DESTRUCTOR)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 39, column 23>
# Node found: OnUpdate (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 50, column 28>
# Node found: OnInitialUpdate (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 184, column 28>
# Node found: OnActLBDown (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 216, column 28>
# Node found: OnActMouseMove (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 232, column 28>
# Node found: OnActRBDown (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 248, column 28>
# Node found: OnActMouseWheel (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 256, column 28>
# Node found: DrawTitleBar (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 263, column 28>
# Node found: DrawTextOverlay (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 276, column 28>
# Node found: DrawLibModel (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 305, column 28>
# Node found: MakeImage (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 359, column 28>
# Node found: UpdateActuator (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 406, column 28>
# Node found: TestDrawFixture (CXX_METHOD)
# Location : <SourceLocation file 'D:\\dev\\AutoPlanning\\trunk\\AP_trunk_pure\\mod_APImplantSimulation\\ActuatorPanoFixture.cpp', line 415, column 28>
# other size : 9587 size : 14
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\mod_APImplantSimulation\ActuatorPanoFixture.cpp

# %%
source_code = simpleVisit.get_source_code()

#print(source_code)
print("========")

source_code = simpleVisit.make_comment_code()
print(source_code)
# Out:
# ========
# // Added by sckim, on 2018/10/17.
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# #include "stdafx.h"
# #include "ActuatorPanoFixture.h"
#
# #include "../BaseTools/plogger.h"
# #include "../AppFrame/VolumeDoc.h"
# #ifdef _DEBUG
# #define new DEBUG_NEW
# #endif
# #include "../AppFrame/SideSliderDoc.h"
# #include "../Doitinterface/RayIntersection.h"
# #include "ModuleDocAPImplantSimulation.h"
#
# #include "../AppCommon_AP/DSICSPositioning.h"
# #include "../AppCommon_AP/DSIPanoAxialPlane.h"
# #include <chrono>
#
# #include "DSILibraryDrawer.h"
#
# #define AND	&&
# #define NOT	!
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // macro constants
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // constructor
# CActuatorPanoFixture::CActuatorPanoFixture()
# 	: CActuatorPanoNerveBase(NAME_ACTUATOR_FIXTURE_PANO, true)
# {
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // destructor
# CActuatorPanoFixture::~CActuatorPanoFixture()
# {
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Process update messages and broadcast to child message target item.
# //auto-gen-future
# #include <future>
# #define USE_FUTURE auto updateFuture = std::async(std::launch::async, [nId, wParam, pParam, pSender, &bRes, pLocalDoc,this](){
# #define END_FUTURE });updateFuture.wait();
# bool CActuatorPanoFixture::OnUpdate(UINT nId, WPARAM wParam, const CUpdateParam* pParam, const LPVOID pSender)
# {
# 	// base operation
# 	bool bRes = __super::OnUpdate(nId, wParam, pParam, pSender);
#
# 	// VR영상의 opacity curve나 object 속성등이 변경되었음을 알리는 이벤트를 처리해야 한다.
# 	UNREFERENCED_PARAMETER(wParam);
# 	UNREFERENCED_PARAMETER(pParam);
#
# 	///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# 	// 자기 자신이 보낸 메시지만 처리하는 경우.
# 	if (pSender == this)
# 	{
# 	}
# 	///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# 	// 남이 보낸 메시지만 처리하는 경우.On
# 	else
# 	{
# 	}
#
# 	CLocalDocAP* pLocalDoc = reinterpret_cast<CLocalDocAP*>(GetLocalDoc());
#
# 	if (nId == BUM::BUM_MODULE_FIXTURE_UPDATE_COLOR)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		//RedrawActuator();	//MakeImage는 제외하고 다시 그린다.
# 		bRes = true;	//렌더러 측에서 그리기 위해 MakeImage 필요
# 	}
# 	else if (nId == BUM::BUM_MODULE_PANO_CS_POS_CHANGED	// 파노라마 영상의 CS Position(Sampling Point)이 변경된 경우
# 		|| nId == BUM::BUM_MODULE_PLANE_CS_ROTATED	// CS PLANE 회전으로 CS Position 관련 벡터 정보가 변경된 경우
# 		|| nId == BUM::BUM_MODULE_PLANE_TGT_ROTATED	// Tgt PLANE 회전으로 CS Position 관련 벡터 정보가 변경된 경우
# 		)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		auto pDSItemCSPos = dynamic_cast<CDSICSPositioning*>(LookupDSI(DSI_NAME_PANO_CS_POS, 0));
# 		auto pDsipanoAxial = dynamic_cast<CDSIPanoAxialPlane*>(LookupDSI(DSI_NAME_PANO_AXIAL, 0));
# 		auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(GetLocalDocAP()->GetWritableModuleDoc(APMod_ImplantSimul));
#
# 		//#4072 수직선은 항상 필요할듯
# 		if (MoudleDoc->GetUseCS())
# 		{
# 			pDSItemCSPos->EnableDSI(true);
# 			//pDsipanoAxial->SetVisible(true);
# 		}
# 		else
# 		{
# 			pDSItemCSPos->EnableDSI(false);
# 			//pDsipanoAxial->SetVisible(false);
# 		}
#
# 		if (pLocalDoc->GetPanoAxialEvent())
# 			_bUpdate = true;
# 		else bRes = true;
#
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	}
#
# 	else if (nId == BUM::BUM_MODULE_FIXTURE_HYBRID_MANIPULATOR_TRANSFORM)
# 	{
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		auto pDSItemCSPos = dynamic_cast<CDSICSPositioning*>(LookupDSI(DSI_NAME_PANO_CS_POS, 0));
# 		pDSItemCSPos->EnableDSI(false);
# 	}
#
# 	else if (nId == BUM::BUM_UPDATE_PROC)
# 	{
# USE_FUTURE
# 		if (GetLogStep()) ProcLogRcvStep(nId);
# 		else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
#
# 		if (_bUpdate)
# 		bRes = true;
#
# 		_bUpdate = false;
#
# END_FUTURE
# 	}
# 	else if (nId == BUM::BUM_COMMON_EACH_TOOTH_SELECT)
# 	{
# 		_bNeedDrawCT = true;
#
# 		auto pDSI = (CDSILibraryDrawer*)LookupDSI(DSI_NAME_PANO_IMP_LIB_DRAWER, 0);
# 		//pDSI->clearRecord();
#
# 		auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(GetLocalDocAP()->GetWritableModuleDoc(APMod_ImplantSimul));
# 		MoudleDoc->SetUseCS(false);
# 		CalPanoActImgAndCsInfo();
#
# 		_updateDsiRelatedPano();
#
# 		if (pLocalDoc->GetPanoAxialEvent())
# 			_bUpdate = true;
# 		else bRes = true;
#
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	}
# 	////CActuatorAxialFixture의 ctrl + Mouse Wheel
# 	//else if(nId == BUM::BUM_MODULE_PANO_HORIZONTAL_LINE_CHANGED_BY_MOUSEWHEEL)
# 	//{
# 	//	CalPanoActImgAndCsInfo();
#
# 	//	_updateDsiRelatedPano();
# 	//}
# 	//
# 	///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# 	// Sender에 상관없이 항상 처리해야 하는 경우.
# 	if (nId == BUM::BUM_MODULE_DENTAL_ARCH_CHANGED || nId == BUM::BUM_MODULE_HORIZONTAL_LINE_CHANGED)
# 	{
# if (GetLogStep()) ProcLogRcvStep(nId);
# else LOGN_(System) << " < RcvMsg > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 		CLocalDocAP* pLocalDoc = reinterpret_cast<CLocalDocAP*>(GetLocalDoc());
# 		if (E_APSteps::APStep_FixtureImplantation == pLocalDoc->GetCurrentStep())
# 		{
# 			auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(GetLocalDocAP()->GetWritableModuleDoc(APMod_ImplantSimul));
#
# 			if (MoudleDoc->GetUseCS())	//CSLine을 사용하는 경우에만 계산
# 				CalPanoActImgAndCsInfo();
#
# 			_updateDsiRelatedPano();
# 			if (pLocalDoc->GetPanoAxialEvent())
# 				_bUpdate = true;
# 			else bRes = true;
# 		}
# 		LOGN_(System) << " < MsgComp > " << "(" << _strName << ")" << " : " << (const wchar_t*)ConEventMessage(nId);
# 	}
#
# 	return bRes;
# }
#
# void CActuatorPanoFixture::OnInitialUpdate(void) // CXX_METHOD(OnInitialUpdate) // TYPE_REF(class CActuatorPanoFixture)
# { // COMPOUND_STMT()
# 	__super::OnInitialUpdate(); // UNEXPOSED_EXPR() // MEMBER_REF_EXPR(OnInitialUpdate)
#
# 	auto pDSI = (CDSILibraryDrawer*)LookupDSI(DSI_NAME_PANO_IMP_LIB_DRAWER, 0); // DECL_STMT() // VAR_DECL(pDSI) // CSTYLE_CAST_EXPR() // TYPE_REF(class CDSILibraryDrawer) // UNEXPOSED_EXPR() // MEMBER_REF_EXPR(LookupDSI) // STRING_LITERAL(L"DSI_MODEL_DRAWER") // INTEGER_LITERAL()
#
# 	if (pDSI == nullptr) // IF_STMT() // CALL_EXPR() // UNEXPOSED_EXPR() // DECL_REF_EXPR(pDSI) // DECL_REF_EXPR() // OVERLOADED_DECL_REF(operator==) // CXX_NULL_PTR_LITERAL_EXPR()
# 	{ // COMPOUND_STMT()
# 		pDSI = new CDSILibraryDrawer(DSI_NAME_PANO_IMP_LIB_DRAWER, this, GetLocalDocAP(), true); // BINARY_OPERATOR() // UNEXPOSED_EXPR() // DECL_REF_EXPR(pDSI) // CXX_NEW_EXPR() // TYPE_REF(class CDSILibraryDrawer) // UNEXPOSED_EXPR() // STRING_LITERAL(L"DSI_MODEL_DRAWER") // CXX_THIS_EXPR() // UNEXPOSED_EXPR() // MEMBER_REF_EXPR(GetLocalDocAP) // CXX_BOOL_LITERAL_EXPR()
# 		pDSI->setRenderer(_pImgRenderer); // CALL_EXPR() // MEMBER_REF_EXPR() // UNEXPOSED_EXPR() // DECL_REF_EXPR(pDSI) // MEMBER_REF_EXPR(_pImgRenderer)
# 		AddDSI(pDSI); // CALL_EXPR(AddDSI) // MEMBER_REF_EXPR(AddDSI) // UNEXPOSED_EXPR()
# 	}
# 	auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(GetLocalDocAP()->GetWritableModuleDoc(APMod_ImplantSimul)); // DECL_STMT() // VAR_DECL(MoudleDoc) // CXX_REINTERPRET_CAST_EXPR() // TYPE_REF(class CModuleDocAPImplantSimulation) // CALL_EXPR() // MEMBER_REF_EXPR() // UNEXPOSED_EXPR() // MEMBER_REF_EXPR(GetLocalDocAP) // DECL_REF_EXPR(APMod_ImplantSimul)
# 	MoudleDoc->SetUseCS(false); // CALL_EXPR() // MEMBER_REF_EXPR() // UNEXPOSED_EXPR() // DECL_REF_EXPR(MoudleDoc) // CXX_BOOL_LITERAL_EXPR()
#
#
# 	pDSI->clearRecord(); // CALL_EXPR() // MEMBER_REF_EXPR() // UNEXPOSED_EXPR() // DECL_REF_EXPR(pDSI)
# 	pDSI->setRenderer(_pImgRenderer); // CALL_EXPR() // MEMBER_REF_EXPR() // UNEXPOSED_EXPR() // DECL_REF_EXPR(pDSI) // MEMBER_REF_EXPR(_pImgRenderer)
# 	//pDSI->setCenterPanoActImgInfo(GetCenterPanoActImgInfo());
#
# 	//CLocalDocAP* pLocalDoc = reinterpret_cast<CLocalDocAP*>(GetLocalDoc());
# 	//if (E_APSteps::APStep_FixtureImplantation == pLocalDoc->GetCurrentStep())
# 	//{
# 	//	CalPanoActImgAndCsInfo();
#
# 	//	_updateDsiRelatedPano();
# 	//}
# }
#
# #include "../AppCommon_AP/DSICSPositioning.h"
# #include "../AppCommon_AP/DSIPanoAxialPlane.h"
#
# bool CActuatorPanoFixture::OnActLBDown(UINT nFlags, CPoint point)
# {
# 	auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(GetLocalDocAP()->GetWritableModuleDoc(APMod_ImplantSimul));
# 	if (MoudleDoc->GetUseCS())
# 		return __super::OnActLBDown(nFlags, point);
# 	else
# 	{
# 		//이전 위치로 (3Shape 기준)
# 		auto pDsiCSPos = dynamic_cast<CDSICSPositioning*>(LookupDSI(DSI_NAME_PANO_CS_POS, 0));
# 		if (pDsiCSPos)
# 			point.x = pDsiCSPos->GetPanoScreenX();
#
# 		return __super::OnActLBDown(nFlags, point);
# }
# }
#
# bool CActuatorPanoFixture::OnActMouseMove(UINT nFlags, CPoint point)
# {
# 	auto MoudleDoc = reinterpret_cast<CModuleDocAPImplantSimulation*>(GetLocalDocAP()->GetWritableModuleDoc(APMod_ImplantSimul));
# 	if (MoudleDoc->GetUseCS())
# 		return __super::OnActMouseMove(nFlags, point);
# 	else
# 	{
# 		//이전 위치로 (3Shape 기준)
# 		auto pDsiCSPos = dynamic_cast<CDSICSPositioning*>(LookupDSI(DSI_NAME_PANO_CS_POS, 0));
# 		if (pDsiCSPos)
# 			point.x = pDsiCSPos->GetPanoScreenX();
#
# 		return __super::OnActMouseMove(nFlags, point);
# 	}
#
# }
# bool CActuatorPanoFixture::OnActRBDown(UINT nFlags, CPoint point)
# {
# 	if(LookupDSI(DSI_NAME_PANO_IMP_LIB_DRAWER , 0) == nullptr)
# 		AddDSI(new CDSILibraryDrawer(DSI_NAME_PANO_IMP_LIB_DRAWER, this, GetLocalDocAP(), false));
#
# 	return __super::OnActRBDown(nFlags, point);
# }
#
# bool CActuatorPanoFixture::OnActMouseWheel(UINT nFlags, short zDelta, CPoint point)
# {
# 	return __super::OnActMouseWheel(nFlags, zDelta, point);
# }
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // TitleBar를 memory dc에 그린다.
# void CActuatorPanoFixture::DrawTitleBar(CDC* pDC)
# {
# 	CRect rcTemp;
# 	::GetClientRect(GetParentPaneHwnd(), rcTemp);
#
# 	Gdiplus::Graphics graphics(pDC->GetSafeHdc());
# 	Gdiplus::SolidBrush br(Gdiplus::Color(178, 89, 101, 139));
# 	graphics.FillRectangle(&br, 0, 0, rcTemp.Width(), TITLE_BAR_HEIGHT);
# }
#
#
# ///////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# // Text overlay를 memory dc에 그린다.
# void CActuatorPanoFixture::DrawTextOverlay(CDC* pDC)
# {
# 	UNREFERENCED_PARAMETER(pDC);
#
# 	Gdiplus::Graphics* pGraphic = BitmapUtils::GetGDIplusGraphics(pDC);
# 	ASSERT(pGraphic);
#
# 	// 글자색/그림자색은 디자이너와 상의한 값. 추후 option 처리 해야 함.
# 	Gdiplus::Color clrText = Gdiplus::Color::MakeARGB(255, 135, 241, 255);
# 	Gdiplus::Color clrShadow = Gdiplus::Color::MakeARGB(225, 10, 15, 30);
# 	Gdiplus::SolidBrush brush(clrText);
# 	Gdiplus::SolidBrush brushShadow(clrShadow);
#
# 	const Gdiplus::Font font(L"Tahoma", 11, Gdiplus::FontStyleBold);
# 	const float fTextGap = 11;
#
# 	CString strName = StringTable::Ready(L"PANORAMA");
#
# 	// Patient name (with shadow)
# 	Gdiplus::StringFormat strFormat;
# 	strFormat.SetAlignment(Gdiplus::StringAlignmentNear);
# 	strFormat.SetLineAlignment(Gdiplus::StringAlignmentNear);
# 	Gdiplus::PointF ptString((Gdiplus::REAL)fTextGap + 1, (Gdiplus::REAL)5);
# 	pGraphic->DrawString(strName, -1, &font, ptString, &strFormat, &brushShadow);
# 	ptString.X = (Gdiplus::REAL)fTextGap;
# 	ptString.Y = (Gdiplus::REAL)4;
# 	pGraphic->DrawString(strName, -1, &font, ptString, &strFormat, &brush);
# }
#
# void CActuatorPanoFixture::DrawLibModel(CImgBuf* pImgbuf)
# {
# 	auto pDSI = (CDSILibraryDrawer*)LookupDSI(DSI_NAME_PANO_IMP_LIB_DRAWER, 0);
# 	if (pDSI)
# 	{
# 		auto start = std::chrono::steady_clock::now();
#
# 		pDSI->UpdateModel();
# 		auto vInfo = pDSI->getCamInfoForDraw();
# 		int tempIdx = PATCHLINE_PREVIEW_SPHERE_INDEX;
#
# 		CPanoActImgInfo panoInfo;
# 		GetPanoActImgInfo(panoInfo);
#
# 		auto vNormal = panoInfo.GetVNormalVectorPosMv();
# 		if (vNormal.size())
# 		{
# 			//auto fNormal = vNormal[vNormal.size() / 2];
# 			//auto fUp = panoInfo.GetVScrVector()[0];
# 			//auto fCross = vTan[vTan.size() / 2];
#
# 			for (int i = 0; i < vInfo.size(); ++i)
# 			{
# 				_pImgRenderer->RemoveAllMeshModel();
# 				if (_pImgRenderer->IsEmptyModelNumber(tempIdx))
# 					_pImgRenderer->AddMeshModel(vInfo[i].pDocModel, tempIdx);
# 				_pImgRenderer->SetLightColor(vInfo[i].color, 1.f, tempIdx);
# 				_pImgRenderer->SetTransformedMatrix(&vInfo[i].mTrans, tempIdx++);
#
# 				float3 fPos = vInfo[i].fPos;
# 				float3 fNormal = vInfo[i].fNormal;
# 				float3 fUp = vInfo[i].fUp;
# 				//float sqrDis = vInfo[i].sqrDistance;
# 				//float3 shortestPt = vInfo[i].shortestPt;
#
# 				auto CP = vInfo[i].world2Point;
#
#
# 				_pImgRenderer->SetScreenPos(CP);
#
# 				const CSize ImgSize(pImgbuf->Width(), pImgbuf->Height());
# 				_pImgRenderer->DrawModelPanorama(fPos, fNormal, fUp, float3(1, 0, 0), m_fMilliMeterPerPixel, ImgSize);
#
# 			}
#
# 			_pImgRenderer->GetImage_PanoMesh(*pImgbuf);
#
# 			auto end = std::chrono::steady_clock::now();
# 			std::chrono::duration<double> totalTime = end - start;
# 			cout << "PanoFixture Draw Lib total : " << totalTime.count() << endl;
# 		}
# 	}
# }
#
# void CActuatorPanoFixture::MakeImage(volatile bool* pbContinue /*= nullptr*/)
# {
# 	auto start = std::chrono::steady_clock::now();
# 	UNREFERENCED_PARAMETER(pbContinue);
#
# 	auto eType = GetLocalDocAP()->GetSelScanModelTy();
# 	auto eStep = GetLocalDocAP()->GetCurrentStep();
# 	bool bNeedChange = true;
#
# 	auto panoInfo = GetLocalDocAP()->GetWritablePanoInfo();
#
# 	panoInfo->GetNeedChngPano(eStep, eType, bNeedChange);
# 	bNeedChange = _bNeedDrawCT || bNeedChange;
#
# 	//변화가 필요없고 재사용 가능하면 재사용
# 	if(NOT bNeedChange AND _pCTImgBuf.get())
# 	{
# 		auto copy_start = std::chrono::high_resolution_clock::now();
#
# 		CImgBuf& imgBuf = GetImageBuf();
# 		imgBuf.CopyFrom(*_pCTImgBuf.get());
#
# 		auto copy_end = std::chrono::high_resolution_clock::now();
# 		auto copy_time = std::chrono::duration_cast<std::chrono::milliseconds>(copy_end - copy_start).count();
# 	}
# 	else //그 외는 전부 갱신
# 	{
#
# 		auto make_start = std::chrono::high_resolution_clock::now();
# 		__super::MakeImage(pbContinue);
# 		auto make_end = std::chrono::high_resolution_clock::now();
# 		auto make_time = std::chrono::duration_cast<std::chrono::milliseconds>(make_end - make_start).count();
#
# 		panoInfo->SetNeedChngPano(eStep, eType, false);
# 	}
# 	//SR 그리기 태스트 #3959
# 	CImgBuf& imgBuf = GetImageBuf();
#
# 	//_pCTImgBuf = std::make_shared<CImgBuf>(imgBuf);
# 	DrawLibModel(&imgBuf);
#
# 	auto end = std::chrono::steady_clock::now();
# 	std::chrono::duration<double> totalTime = end - start;
# 	cout << "PanoFixture MakeImage total : " << totalTime.count() << endl;
# }
#
# #include "../AppUICore/UIPane.h"
# void CActuatorPanoFixture::UpdateActuator(bool bMakeImage)
# {
# 	__super::UpdateActuator(bMakeImage);
# }
#
#
# #include "../DoitPrimitive/SurfaceModelitem.h"
# #include "../AppUICore/UIPane.h"
# //#define ALL_ADD
# void CActuatorPanoFixture::TestDrawFixture()
# {
# 	//PanoActImgInfo가 있을 경우
# 	CPanoActImgInfo panoImgInfo;
# 	auto start = std::chrono::high_resolution_clock::now();
# 	if (_pLocalDoc && GetPanoActImgInfo(panoImgInfo))
# 	{
# 		auto start = std::chrono::high_resolution_clock::now();
# 		int checkDecimal = 1000;	//
#
# 		std::vector<CPoint> vNervePanoPoint;	//결과
# 		//이상하긴 하지만 key는 float의 int화 값 pair는 min, max의 인덱스 <key : floatX, value<MinIdx, MaxIdx >>
# 		std::map<int, std::pair<int, int>> xBaseMinMaxMap;
#
# 		auto pToothDoc = _pLocalDoc->GetToothDoc();
# 		for (auto nTooth : pToothDoc->GetToothNumberList())
# 		{
# 			auto pToothData = _pToothInfoData->GetToothData(nTooth);
# 			auto fixtureName = pToothData->GetFixtureData()->GetName();
# 			auto pFixtureModel = _pLocalDoc->GetSurfaceModel(fixtureName);
# 			if (pFixtureModel == nullptr)
# 				continue;
#
# 			CSurfaceModelItem copyFixture = *pFixtureModel;
# 			copyFixture.UpdateDataWithTransMatrix(pToothData->GetFixtureData()->GetMatrix());
# 			auto pInfo =copyFixture.GetInfo();
# 			for (int i = 0; i < pInfo->nVertexCount; i++)
# 			{
# 				auto fPos = pInfo->pVertex[i].fPosition;
# 				int x2int = (checkDecimal * fPos.fValue[0] + 0.5); //첫째 자리만 , 2 이후 반올림 처리
#
# 				//빈경우 추가
# 				if (xBaseMinMaxMap.find(x2int) == xBaseMinMaxMap.end())
# 				{
# 					xBaseMinMaxMap[x2int] = std::pair<int, int>(i, i);
# 				}
# 				else
# 				{
# 					int minIdx = xBaseMinMaxMap[x2int].first;
# 					int maxIdx = xBaseMinMaxMap[x2int].second;
#
# 					if (fPos.fValue[1] < pInfo->pVertex[minIdx].fPosition[1])
# 						xBaseMinMaxMap[x2int] = std::pair<int, int>(i, maxIdx);
# 					else if (pInfo->pVertex[maxIdx].fPosition[1] < fPos.fValue[1])
# 						xBaseMinMaxMap[x2int] = std::pair<int, int>(minIdx, i);
# 				}
#
# 			}
#
# 			for (auto result : xBaseMinMaxMap)
# 			{
# 				vNervePanoPoint.push_back(World2PanoPoint(pInfo->pVertex[result.second.first].fPosition));
# 				if (result.second.first != result.second.second)
# 					vNervePanoPoint.push_back(World2PanoPoint(pInfo->pVertex[result.second.second].fPosition));
# 			}
#
#
# 		}
#
# 		auto end = std::chrono::high_resolution_clock::now();
# 		auto callPassMs = std::chrono::duration_cast<std::chrono::milliseconds>(end - start).count();
# 		std::cout << "Call Pass : " << callPassMs << " ms " << std::endl;
#
#
# 		auto pDC = m_pParentPane->GetDC();
# 		for (auto point : vNervePanoPoint)
# 			pDC->SetPixel(point, RGB(113, 120, 135));
# 		m_pParentPane->ReleaseDC(pDC);
# 		end = std::chrono::high_resolution_clock::now();
# 		auto printPassMs = std::chrono::duration_cast<std::chrono::milliseconds>(end - start).count();
# 		std::cout << printPassMs << " ms" << std::endl;
#
# 		std::cout << "total" << callPassMs + printPassMs << " ms" << std::endl;
# 	}
# }

# %%
dataMap:dict[str, list] = {}

cpp_list = []
simpleVisit.for_make_file_map(dataMap)
for key in dataMap:
    print(f"{key} : {dataMap[key].__len__()}")
    if key.__contains__(".cpp"):
        cpp_list.append((key, dataMap[key]))

print("=================")

for key, data in cpp_list:
    print(f"{key} : {data.__len__()}")
    for node in data:
        location: clang.cindex.SourceLocation = node.location
        source = read_specific_column(key, location.line, location.column)
        print("====")
        print(f"{source}[{location.line}:{location.column}]{node.spelling} {node.kind}" )
        print("====")


stmt_map = {}
simpleVisit.for_make_stmt_map(stmt_map)

for stmt in stmt_map:
    print(f"{stmt.name} {stmt_map[stmt].__len__()}")

for node in stmt_map[clang.cindex.CursorKind.CALL_EXPR]:
    location: clang.cindex.SourceLocation = node.location

    file_name: str = location.file.name
    if file_name.__contains__(target.spelling):
        print(f"{file_name} contains {target.spelling}")
        source = read_specific_column(location.file.name, location.line, location.column)
        print("=================")
        print(f"{source}[{location.line}:{location.column}]{node.spelling} {node.kind}")
# Out:
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# <class 'str'>
# None : 895
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\sal.h : 1
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\concurrencysal.h : 1
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vadefs.h : 32
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime.h : 23
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\stdint.h : 26
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cstdint : 115
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt.h : 67
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_math.h : 1231
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_malloc.h : 136
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\stddef.h : 17
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_search.h : 92
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wstdlib.h : 335
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\limits.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\stdlib.h : 940
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cstdlib : 115
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\float.h : 44
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_stdio_config.h : 18
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wstdio.h : 4099
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\stdio.h : 4067
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cstdio : 101
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\errno.h : 15
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime_string.h : 52
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_memcpy_s.h : 274
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wconio.h : 748
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wctype.h : 163
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wdirect.h : 16
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wio.h : 209
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wprocess.h : 79
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wstring.h : 499
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_wtime.h : 147
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\sys/types.h : 9
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\sys/stat.h : 190
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\wchar.h : 355
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cwchar : 131
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\intrin0.inl.h : 235
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\isa_availability.h : 21
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xtr1common : 266
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cstddef : 9
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\initializer_list : 84
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xstddef : 459
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\limits : 1586
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime_new.h : 85
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime_new_debug.h : 27
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\crtdbg.h : 51
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\yvals.h : 48
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\use_ansi.h : 1
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\type_traits : 4178
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\exception : 433
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\malloc.h : 129
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_terminate.h : 11
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\eh.h : 27
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime_exception.h : 161
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\new : 9
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xatomic.h : 23
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_memory.h : 49
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\string.h : 480
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cstring : 47
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\utility : 1269
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xutility : 3278
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xmemory : 2014
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\algorithm : 2480
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/stdafx.h : 11
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\new.h : 25
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\excpt.h : 27
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\stdarg.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\windef.h : 321
# C:\Windows Kits\10\Include\10.0.22000.0\shared\specstrings.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\driverspecs.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\minwindef.h : 140
# C:\Windows Kits\10\Include\10.0.22000.0\um\winnt.h : 27250
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\ctype.h : 398
# C:\Windows Kits\10\Include\10.0.22000.0\shared\kernelspecs.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\basetsd.h : 257
# C:\Windows Kits\10\Include\10.0.22000.0\shared\guiddef.h : 151
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ktmtypes.h : 284
# C:\Windows Kits\10\Include\10.0.22000.0\um\minwinbase.h : 1222
# C:\Windows Kits\10\Include\10.0.22000.0\um\apiquery2.h : 5
# C:\Windows Kits\10\Include\10.0.22000.0\um\processenv.h : 163
# C:\Windows Kits\10\Include\10.0.22000.0\um\fileapi.h : 1145
# C:\Windows Kits\10\Include\10.0.22000.0\um\fileapifromapp.h : 110
# C:\Windows Kits\10\Include\10.0.22000.0\um\debugapi.h : 54
# C:\Windows Kits\10\Include\10.0.22000.0\um\utilapiset.h : 46
# C:\Windows Kits\10\Include\10.0.22000.0\um\handleapi.h : 46
# C:\Windows Kits\10\Include\10.0.22000.0\um\errhandlingapi.h : 100
# C:\Windows Kits\10\Include\10.0.22000.0\um\fibersapi.h : 26
# C:\Windows Kits\10\Include\10.0.22000.0\um\namedpipeapi.h : 154
# C:\Windows Kits\10\Include\10.0.22000.0\um\profileapi.h : 11
# C:\Windows Kits\10\Include\10.0.22000.0\um\heapapi.h : 167
# C:\Windows Kits\10\Include\10.0.22000.0\um\ioapiset.h : 111
# C:\Windows Kits\10\Include\10.0.22000.0\um\synchapi.h : 507
# C:\Windows Kits\10\Include\10.0.22000.0\um\interlockedapi.h : 38
# C:\Windows Kits\10\Include\10.0.22000.0\um\processthreadsapi.h : 1473
# C:\Windows Kits\10\Include\10.0.22000.0\um\sysinfoapi.h : 462
# C:\Windows Kits\10\Include\10.0.22000.0\um\memoryapi.h : 916
# C:\Windows Kits\10\Include\10.0.22000.0\um\enclaveapi.h : 96
# C:\Windows Kits\10\Include\10.0.22000.0\um\threadpoollegacyapiset.h : 69
# C:\Windows Kits\10\Include\10.0.22000.0\um\threadpoolapiset.h : 250
# C:\Windows Kits\10\Include\10.0.22000.0\um\jobapi.h : 10
# C:\Windows Kits\10\Include\10.0.22000.0\um\jobapi2.h : 103
# C:\Windows Kits\10\Include\10.0.22000.0\um\wow64apiset.h : 95
# C:\Windows Kits\10\Include\10.0.22000.0\um\libloaderapi.h : 453
# C:\Windows Kits\10\Include\10.0.22000.0\um\securitybaseapi.h : 1232
# C:\Windows Kits\10\Include\10.0.22000.0\um\namespaceapi.h : 42
# C:\Windows Kits\10\Include\10.0.22000.0\um\systemtopologyapi.h : 31
# C:\Windows Kits\10\Include\10.0.22000.0\um\processtopologyapi.h : 26
# C:\Windows Kits\10\Include\10.0.22000.0\um\securityappcontainer.h : 13
# C:\Windows Kits\10\Include\10.0.22000.0\um\realtimeapiset.h : 71
# C:\Windows Kits\10\Include\10.0.22000.0\um\winbase.h : 8249
# C:\Windows Kits\10\Include\10.0.22000.0\shared\winerror.h : 42
# C:\Windows Kits\10\Include\10.0.22000.0\um\timezoneapi.h : 252
# C:\Windows Kits\10\Include\10.0.22000.0\um\wingdi.h : 14526
# C:\Windows Kits\10\Include\10.0.22000.0\um\winuser.h : 12824
# C:\Windows Kits\10\Include\10.0.22000.0\shared\tvout.h : 195
# C:\Windows Kits\10\Include\10.0.22000.0\um\winnls.h : 1764
# C:\Windows Kits\10\Include\10.0.22000.0\um\datetimeapi.h : 96
# C:\Windows Kits\10\Include\10.0.22000.0\um\stringapiset.h : 101
# C:\Windows Kits\10\Include\10.0.22000.0\um\wincon.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\um\wincontypes.h : 319
# C:\Windows Kits\10\Include\10.0.22000.0\um\consoleapi.h : 197
# C:\Windows Kits\10\Include\10.0.22000.0\um\consoleapi2.h : 480
# C:\Windows Kits\10\Include\10.0.22000.0\um\consoleapi3.h : 313
# C:\Windows Kits\10\Include\10.0.22000.0\um\verrsrc.h : 56
# C:\Windows Kits\10\Include\10.0.22000.0\um\winver.h : 181
# C:\Windows Kits\10\Include\10.0.22000.0\um\winreg.h : 1255
# C:\Windows Kits\10\Include\10.0.22000.0\um\winnetwk.h : 859
# C:\Windows Kits\10\Include\10.0.22000.0\shared\stralign.h : 386
# C:\Windows Kits\10\Include\10.0.22000.0\um\zmouse.h : 119
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxv_w32.h : 92
# C:\Windows Kits\10\Include\10.0.22000.0\um\CommCtrl.h : 6803
# C:\Windows Kits\10\Include\10.0.22000.0\um\prsht.h : 1377
# C:\Windows Kits\10\Include\10.0.22000.0\um\dpa_dsa.h : 468
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\tchar.h : 456
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afx.h : 1738
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\time.h : 392
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\mbstring.h : 1224
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxstr.h : 64
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atldef.h : 29
# C:\Windows Kits\10\Include\10.0.22000.0\um\WinSock2.h : 3489
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ws2def.h : 1654
# C:\Windows Kits\10\Include\10.0.22000.0\shared\inaddr.h : 275
# C:\Windows Kits\10\Include\10.0.22000.0\shared\qos.h : 124
# C:\Windows Kits\10\Include\10.0.22000.0\shared\rpc.h : 3
# C:\Windows Kits\10\Include\10.0.22000.0\shared\rpcdce.h : 2231
# C:\Windows Kits\10\Include\10.0.22000.0\shared\rpcdcep.h : 932
# C:\Windows Kits\10\Include\10.0.22000.0\um\rpcnsi.h : 488
# C:\Windows Kits\10\Include\10.0.22000.0\shared\rpcasync.h : 920
# C:\Windows Kits\10\Include\10.0.22000.0\um\rpcnsip.h : 55
# C:\Windows Kits\10\Include\10.0.22000.0\shared\rpcsal.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\rpcndr.h : 2545
# C:\Windows Kits\10\Include\10.0.22000.0\um\combaseapi.h : 907
# C:\Windows Kits\10\Include\10.0.22000.0\shared\wtypesbase.h : 414
# C:\Windows Kits\10\Include\10.0.22000.0\um\unknwnbase.h : 209
# C:\Windows Kits\10\Include\10.0.22000.0\um\objidlbase.h : 2520
# C:\Windows Kits\10\Include\10.0.22000.0\um\cguid.h : 165
# C:\Windows Kits\10\Include\10.0.22000.0\um\objidl.h : 3868
# C:\Windows Kits\10\Include\10.0.22000.0\shared\wtypes.h : 1025
# C:\Windows Kits\10\Include\10.0.22000.0\um/unknwn.h : 46
# C:\Windows Kits\10\Include\10.0.22000.0\um\propidlbase.h : 843
# C:\Windows Kits\10\Include\10.0.22000.0\um/oaidl.h : 4183
# C:\Windows Kits\10\Include\10.0.22000.0\um\coml2api.h : 251
# C:\Windows Kits\10\Include\10.0.22000.0\um\objbase.h : 449
# C:\Windows Kits\10\Include\10.0.22000.0\um\urlmon.h : 6896
# C:\Windows Kits\10\Include\10.0.22000.0\um/oleidl.h : 1925
# C:\Windows Kits\10\Include\10.0.22000.0\um/servprov.h : 77
# C:\Windows Kits\10\Include\10.0.22000.0\um/msxml.h : 1602
# C:\Windows Kits\10\Include\10.0.22000.0\um\propidl.h : 243
# C:\Windows Kits\10\Include\10.0.22000.0\um\oleauto.h : 3427
# C:\Windows Kits\10\Include\10.0.22000.0\um\Ole2.h : 796
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlalloc.h : 981
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlconv.h : 1966
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atltrace.h : 381
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlexcept.h : 102
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlchecked.h : 839
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlsimpcoll.h : 518
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlwinverapi.h : 60
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlcore.h : 1862
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlmem.h : 524
# C:\Windows Kits\10\Include\10.0.22000.0\um\ocidl.h : 2804
# C:\Windows Kits\10\Include\10.0.22000.0\um\OleCtl.h : 518
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlcomcli.h : 10802
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\ATLComMem.h : 659
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\setjmp.h : 93
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\mmintrin.h : 39
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xmmintrin.h : 520
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\emmintrin.h : 1142
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\pmmintrin.h : 64
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\tmmintrin.h : 93
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\smmintrin.h : 276
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\nmmintrin.h : 124
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\wmmintrin.h : 42
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\immintrin.h : 4040
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\zmmintrin.h : 34295
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\ammintrin.h : 790
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\intrin.h : 2647
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlsimpstr.h : 676
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\cstringt.h : 3293
# C:\Windows Kits\10\Include\10.0.22000.0\um\ktmw32.h : 295
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atltransactionmanager.h : 1574
# C:\Windows Kits\10\Include\10.0.22000.0\um\oledb.h : 8230
# C:\Windows Kits\10\Include\10.0.22000.0\um/transact.h : 565
# C:\Windows Kits\10\Include\10.0.22000.0\um\accctrl.h : 922
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atltime.h : 3409
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcoll.h : 2101
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atltypes.h : 2409
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxtls_.h : 280
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxstat_.h : 303
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcoll.inl : 2921
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afx.inl : 1615
# C:\Windows Kits\10\Include\10.0.22000.0\um\shellapi.h : 2146
# C:\Windows Kits\10\Include\10.0.22000.0\um\commdlg.h : 2054
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxctrlcontainer.h : 61
# C:\Windows Kits\10\Include\10.0.22000.0\um\ShObjIdl.h : 3463
# C:\Windows Kits\10\Include\10.0.22000.0\um/docobj.h : 1444
# C:\Windows Kits\10\Include\10.0.22000.0\um/shtypes.h : 350
# C:\Windows Kits\10\Include\10.0.22000.0\um/comcat.h : 426
# C:\Windows Kits\10\Include\10.0.22000.0\um/propsys.h : 3128
# C:\Windows Kits\10\Include\10.0.22000.0\um/StructuredQueryCondition.h : 526
# C:\Windows Kits\10\Include\10.0.22000.0\um\propkeydef.h : 47
# C:\Windows Kits\10\Include\10.0.22000.0\um/ObjectArray.h : 58
# C:\Windows Kits\10\Include\10.0.22000.0\um/shobjidl_core.h : 20087
# C:\Windows Kits\10\Include\10.0.22000.0\um\thumbcache.h : 958
# C:\Windows Kits\10\Include\10.0.22000.0\um\Filter.h : 213
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atliface.h : 1852
# C:\Windows Kits\10\Include\10.0.22000.0\um\oleacc.h : 897
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime_startup.h : 43
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\corecrt_startup.h : 107
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\process.h : 244
# C:\Windows Kits\10\Include\10.0.22000.0\um\Shlwapi.h : 4300
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlbase.h : 16578
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\statreg.h : 7170
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlstr.h : 2268
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlhandler.h : 329
# C:\Windows Kits\10\Include\10.0.22000.0\um\tpcshrd.h : 181
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxwin.h : 12380
# C:\Windows Kits\10\Include\10.0.22000.0\um/VSStyle.h : 1965
# C:\Windows Kits\10\Include\10.0.22000.0\um\vssym32.h : 417
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ws2ipdef.h : 1944
# C:\Windows Kits\10\Include\10.0.22000.0\shared\in6addr.h : 67
# C:\Windows Kits\10\Include\10.0.22000.0\um\WinDNS.h : 6067
# C:\Windows Kits\10\Include\10.0.22000.0\um\iphlpapi.h : 973
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ipifcons.h : 57
# C:\Windows Kits\10\Include\10.0.22000.0\shared\iprtrmib.h : 370
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ifdef.h : 730
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ifmib.h : 189
# C:\Windows Kits\10\Include\10.0.22000.0\shared\nldef.h : 839
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ipmib.h : 1697
# C:\Windows Kits\10\Include\10.0.22000.0\shared\tcpmib.h : 1043
# C:\Windows Kits\10\Include\10.0.22000.0\shared\udpmib.h : 588
# C:\Windows Kits\10\Include\10.0.22000.0\um\ipexport.h : 368
# C:\Windows Kits\10\Include\10.0.22000.0\um\iptypes.h : 1303
# C:\Windows Kits\10\Include\10.0.22000.0\shared\tcpestats.h : 888
# C:\Windows Kits\10\Include\10.0.22000.0\shared\netioapi.h : 2201
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ntddndis.h : 5954
# C:\Windows Kits\10\Include\10.0.22000.0\shared\devpropdef.h : 224
# C:\Windows Kits\10\Include\10.0.22000.0\shared\devpkey.h : 582
# C:\Windows Kits\10\Include\10.0.22000.0\shared\pciprop.h : 168
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/ioctltypes.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/oidtypes.h : 46
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/objectheader.h : 35
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/types.h : 7
# C:\Windows Kits\10\Include\10.0.22000.0\shared\WlanTypes.h : 340
# C:\Windows Kits\10\Include\10.0.22000.0\shared\windot11.h : 9113
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/offloadtypes.h : 1
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/ndisport.h : 25
# C:\Windows Kits\10\Include\10.0.22000.0\shared\ndis/hashtypes.h : 3
# C:\Windows Kits\10\Include\10.0.22000.0\um\uxtheme.h : 1687
# C:\Windows Kits\10\Include\10.0.22000.0\um\dwmapi.h : 1086
# C:\Windows Kits\10\Include\10.0.22000.0\um\HtmlHelp.h : 518
# C:\Windows Kits\10\Include\10.0.22000.0\um\UIAnimation.h : 2075
# C:\Windows Kits\10\Include\10.0.22000.0\um/dcompanimation.h : 49
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/afxanimationhelper.h : 404
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxplex_.h : 20
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/afxtempl.h : 1807
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/afxanimationcontroller.h : 3915
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxmsg_.h : 233
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdd_.h : 341
# C:\Windows Kits\10\Include\10.0.22000.0\shared\d3d9types.h : 5050
# C:\Windows Kits\10\Include\10.0.22000.0\shared/dxgicommon.h : 131
# C:\Windows Kits\10\Include\10.0.22000.0\shared/dxgiformat.h : 493
# C:\Windows Kits\10\Include\10.0.22000.0\shared\dxgitype.h : 170
# C:\Windows Kits\10\Include\10.0.22000.0\um\dcommon.h : 694
# C:\Windows Kits\10\Include\10.0.22000.0\um\D2DBaseTypes.h : 2
# C:\Windows Kits\10\Include\10.0.22000.0\um\d3d10_1.h : 320
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3d10.h : 3593
# C:\Windows Kits\10\Include\10.0.22000.0\shared\dxgi.h : 881
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3dcommon.h : 2629
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3d10sdklayers.h : 5483
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3d10misc.h : 65
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3d10shader.h : 527
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3d10effect.h : 2450
# C:\Windows Kits\10\Include\10.0.22000.0\um/d3d10_1shader.h : 530
# C:\Windows Kits\10\Include\10.0.22000.0\um\d2d1.h : 5103
# C:\Windows Kits\10\Include\10.0.22000.0\um\d2d1helper.h : 2270
# C:\Windows Kits\10\Include\10.0.22000.0\um\dwrite.h : 5869
# C:\Windows Kits\10\Include\10.0.22000.0\um\wincodec.h : 4220
# C:\Windows Kits\10\Include\10.0.22000.0\shared\intsafe.h : 7343
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/afxrendertarget.h : 2368
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxwin1.inl : 8019
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxwin2.inl : 8125
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxwin3.inl : 129
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxwin4.inl : 1129
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxlayout.h : 258
# C:\Windows Kits\10\Include\10.0.22000.0\um\Richedit.h : 776
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdlgs.h : 1531
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdlgs.inl : 769
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxext.h : 2299
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxext.inl : 847
# C:\Windows Kits\10\Include\10.0.22000.0\um\shlguid.h : 756
# C:\Windows Kits\10\Include\10.0.22000.0\um\isguids.h : 9
# C:\Windows Kits\10\Include\10.0.22000.0\um\exdisp.h : 1498
# C:\Windows Kits\10\Include\10.0.22000.0\um\shldisp.h : 1454
# C:\Windows Kits\10\Include\10.0.22000.0\um\knownfolders.h : 426
# C:\Windows Kits\10\Include\10.0.22000.0\um\shlobj_core.h : 5593
# C:\Windows Kits\10\Include\10.0.22000.0\um\ShlObj.h : 840
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\ATLComTime.h : 3327
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdisp.h : 1523
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/olebind.h : 77
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/ocdbid.h : 207
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include/ocdb.h : 892
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxocc.h : 2111
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxole.inl : 1609
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcom_.h : 488
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxole.h : 4635
# C:\Windows Kits\10\Include\10.0.22000.0\um\dlgs.h : 19
# C:\Windows Kits\10\Include\10.0.22000.0\um\OleDlg.h : 3311
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxodlgs.h : 684
# C:\Windows Kits\10\Include\10.0.22000.0\um\sqltypes.h : 283
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdb_.h : 16
# C:\Windows Kits\10\Include\10.0.22000.0\um\sql.h : 639
# C:\Windows Kits\10\Include\10.0.22000.0\um\sqlext.h : 385
# C:\Windows Kits\10\Include\10.0.22000.0\um/sqlucode.h : 1133
# C:\Windows Kits\10\Include\10.0.22000.0\um\wincrypt.h : 12249
# C:\Windows Kits\10\Include\10.0.22000.0\shared\bcrypt.h : 1598
# C:\Windows Kits\10\Include\10.0.22000.0\um\ncrypt.h : 944
# C:\Windows Kits\10\Include\10.0.22000.0\um\dpapi.h : 130
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdb.h : 1503
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdb.inl : 428
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdtctl.h : 311
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxdtctl.inl : 638
# C:\Windows Kits\10\Include\10.0.22000.0\um\RichOle.h : 235
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcmn.h : 3531
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcmn.inl : 9796
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcmn2.inl : 4344
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxcmn3.inl : 2294
# C:\Windows Kits\10\Include\10.0.22000.0\um\MSWSock.h : 1610
# C:\Windows Kits\10\Include\10.0.22000.0\shared\mswsockdef.h : 154
# C:\Windows Kits\10\Include\10.0.22000.0\um\WS2tcpip.h : 2154
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlsocket.h : 385
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxsock.h : 1309
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\afxsock.inl : 365
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../inlines/ImageInfo.h : 377
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../inlines/usefulinlines.h : 2953
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/Base_Data.h : 16
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/ToothBase_Data.h : 22
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cmath : 2023
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\iosfwd : 296
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\iterator : 1588
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\__msvc_system_error_abi.hpp : 14
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xstring : 3617
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\stdexcept : 221
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xcall_once.h : 41
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xerrc.h : 158
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\ctime : 27
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xtimec.h : 20
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xthreads.h : 173
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\atomic : 1843
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\system_error : 1225
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vcruntime_typeinfo.h : 231
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\typeinfo : 20
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\memory : 2132
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xfacet : 11
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\cctype : 29
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\locale.h : 81
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\clocale : 7
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xlocinfo.h : 134
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xlocinfo : 571
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xlocale : 7610
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xiosbase : 1466
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\streambuf : 258
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xlocnum : 995
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\ios : 292
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\ostream : 334
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\istream : 419
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\iostream : 39
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\vector : 1675
# C:\Windows Kits\10\Include\10.0.22000.0\ucrt\assert.h : 5
# C:\Windows Kits\10\Include\10.0.22000.0\um\DirectXMath.h : 6954
# C:\Windows Kits\10\Include\10.0.22000.0\um/DirectXMathConvert.inl : 8373
# C:\Windows Kits\10\Include\10.0.22000.0\um/DirectXMathVector.inl : 65523
# C:\Windows Kits\10\Include\10.0.22000.0\um/DirectXMathMatrix.inl : 18461
# C:\Windows Kits\10\Include\10.0.22000.0\um/DirectXMathMisc.inl : 11487
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../BaseTools/Vector.h : 229
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../BaseTools/Matrix.h : 315
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/AbutmentData.h : 63
# C:\Windows Kits\10\Include\10.0.22000.0\um\gdiplus.h : 9
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusMem.h : 6
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusBase.h : 42
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusEnums.h : 1624
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusTypes.h : 2091
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusInit.h : 70
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusPixelFormats.h : 92
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusColor.h : 780
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusMetaHeader.h : 350
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusImaging.h : 265
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusColorMatrix.h : 25
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusGpStubs.h : 110
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusHeaders.h : 1654
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusFlat.h : 5262
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusImageAttributes.h : 650
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusMatrix.h : 775
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusBrush.h : 2004
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusPen.h : 1137
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusStringFormat.h : 635
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusPath.h : 4055
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusLineCaps.h : 585
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusGraphics.h : 6594
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusMetafile.h : 761
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusCachedBitmap.h : 55
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusRegion.h : 1209
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusFontCollection.h : 249
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusFontFamily.h : 404
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusFont.h : 687
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusBitmap.h : 1833
# C:\Windows Kits\10\Include\10.0.22000.0\um/GdiplusImageCodec.h : 72
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\atlmfc\include\atlImage.h : 6703
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../BaseTools/tinyxml2.h : 2931
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\string : 1637
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../BaseTools/TinyXMLWrapper.h : 185
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/AbutmentDoc.h : 218
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\List : 1074
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\tuple : 1377
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\xtree : 867
# C:\dev\VS2019 Professional\IDE\VC\Tools\MSVC\14.29.30133\include\map : 842
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/FixtureDoc.h : 117
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/SleeveDoc.h : 262
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/XMLDocFixture.h : 55
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/SurfaceLoader.h : 111
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../BaseTools/EnvSession.h : 70
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../BaseTools/MiscUtils.h : 108
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../DoitPrimitive/ModelIndex.h : 475
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame/../DoitPrimitive/SurfaceModelItem.h : 598
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp : 998
# =================
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp : 998
# ====
# CAbutmentData::->CAbutmentData(E_SCAN_MODEL_TY eType)
# [14:16]CAbutmentData CursorKind.CONSTRUCTOR
# ====
# ====
# ->CAbutmentData::CAbutmentData(E_SCAN_MODEL_TY eType)
# [14:1]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# CAbutmentData::CAbutmentData(E_SCAN_MODEL_TY ->eType)
# [14:46]eType CursorKind.PARM_DECL
# ====
# ====
# CAbutmentData::CAbutmentData(->E_SCAN_MODEL_TY eType)
# [14:30]enum E_SCAN_MODEL_TY CursorKind.TYPE_REF
# ====
# ====
# 	: ->CToothBase_Data(eType)
# [15:4]class CToothBase_Data CursorKind.TYPE_REF
# ====
# ====
# 	: ->CToothBase_Data(eType)
# [15:4]CToothBase_Data CursorKind.CALL_EXPR
# ====
# ====
# 	: CToothBase_Data(->eType)
# [15:20]eType CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	: CToothBase_Data(->eType)
# [15:20]eType CursorKind.DECL_REF_EXPR
# ====
# ====
# 	, ->_pAbutmentInfo(NULL)
# [16:4]_pAbutmentInfo CursorKind.MEMBER_REF
# ====
# ====
# 	, _pAbutmentInfo(->NULL)
# [16:19] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	, _pAbutmentInfo(->NULL)
# [16:19] CursorKind.INTEGER_LITERAL
# ====
# ====
# 	, ->_mTrans(4,4)
# [17:4]_mTrans CursorKind.MEMBER_REF
# ====
# ====
# 	, ->_mTrans(4,4)
# [17:4]CMatrixMxN CursorKind.CALL_EXPR
# ====
# ====
# 	, _mTrans(->4,4)
# [17:12] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	, _mTrans(->4,4)
# [17:12] CursorKind.INTEGER_LITERAL
# ====
# ====
# 	, _mTrans(4,->4)
# [17:14] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	, _mTrans(4,->4)
# [17:14] CursorKind.INTEGER_LITERAL
# ====
# ====
# ->{
# [18:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->_mTrans.eye();
# [19:2]eye CursorKind.CALL_EXPR
# ====
# ====
# 	_mTrans.->eye();
# [19:10]eye CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->_mTrans.eye();
# [19:2]_mTrans CursorKind.MEMBER_REF_EXPR
# ====
# ====
# CAbutmentData::->~CAbutmentData()
# [22:16]~CAbutmentData CursorKind.DESTRUCTOR
# ====
# ====
# ->CAbutmentData::~CAbutmentData()
# [22:1]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# ->{
# [23:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2] CursorKind.IF_STMT
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2] CursorKind.CXX_DELETE_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2] CursorKind.BINARY_OPERATOR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	->SAFE_DELETE(_pAbutmentInfo);
# [24:2] CursorKind.CXX_NULL_PTR_LITERAL_EXPR
# ====
# ====
# 	SAFE_DELETE(_pAbutmentInfo)->;
# [24:29] CursorKind.NULL_STMT
# ====
# ====
# void CAbutmentData::->SetAbutmentInfo(ST_ABUTMENT_INFO* pInfo)
# [28:21]SetAbutmentInfo CursorKind.CXX_METHOD
# ====
# ====
# void ->CAbutmentData::SetAbutmentInfo(ST_ABUTMENT_INFO* pInfo)
# [28:6]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# void CAbutmentData::SetAbutmentInfo(ST_ABUTMENT_INFO* ->pInfo)
# [28:55]pInfo CursorKind.PARM_DECL
# ====
# ====
# void CAbutmentData::SetAbutmentInfo(->ST_ABUTMENT_INFO* pInfo)
# [28:37]struct ST_ABUTMENT_INFO CursorKind.TYPE_REF
# ====
# ====
# ->{
# [29:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->if (NULL != pInfo)
# [30:2] CursorKind.IF_STMT
# ====
# ====
# 	if (->NULL != pInfo)
# [30:6] CursorKind.BINARY_OPERATOR
# ====
# ====
# 	if (->NULL != pInfo)
# [30:6] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	if (->NULL != pInfo)
# [30:6] CursorKind.INTEGER_LITERAL
# ====
# ====
# 	if (NULL != ->pInfo)
# [30:14]pInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	if (NULL != ->pInfo)
# [30:14]pInfo CursorKind.DECL_REF_EXPR
# ====
# ====
# 	->{
# [31:2] CursorKind.COMPOUND_STMT
# ====
# ====
# 		->if (NULL == _pAbutmentInfo)
# [32:3] CursorKind.IF_STMT
# ====
# ====
# 		if (->NULL == _pAbutmentInfo)
# [32:7] CursorKind.BINARY_OPERATOR
# ====
# ====
# 		if (->NULL == _pAbutmentInfo)
# [32:7] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		if (->NULL == _pAbutmentInfo)
# [32:7] CursorKind.INTEGER_LITERAL
# ====
# ====
# 		if (NULL == ->_pAbutmentInfo)
# [32:15]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		if (NULL == ->_pAbutmentInfo)
# [32:15]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 			->_pAbutmentInfo = new ST_ABUTMENT_INFO;
# [33:4] CursorKind.BINARY_OPERATOR
# ====
# ====
# 			->_pAbutmentInfo = new ST_ABUTMENT_INFO;
# [33:4]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 			_pAbutmentInfo = ->new ST_ABUTMENT_INFO;
# [33:21] CursorKind.CXX_NEW_EXPR
# ====
# ====
# 			_pAbutmentInfo = new ->ST_ABUTMENT_INFO;
# [33:25]struct ST_ABUTMENT_INFO CursorKind.TYPE_REF
# ====
# ====
# 			_pAbutmentInfo = new ->ST_ABUTMENT_INFO;
# [33:25]ST_ABUTMENT_INFO CursorKind.CALL_EXPR
# ====
# ====
# 		->*_pAbutmentInfo = *pInfo;
# [35:3]operator= CursorKind.CALL_EXPR
# ====
# ====
# 		->*_pAbutmentInfo = *pInfo;
# [35:3] CursorKind.UNARY_OPERATOR
# ====
# ====
# 		*->_pAbutmentInfo = *pInfo;
# [35:4]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		*->_pAbutmentInfo = *pInfo;
# [35:4]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 		*_pAbutmentInfo ->= *pInfo;
# [35:19]operator= CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		*_pAbutmentInfo ->= *pInfo;
# [35:19]operator= CursorKind.DECL_REF_EXPR
# ====
# ====
# 		*_pAbutmentInfo = ->*pInfo;
# [35:21] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		*_pAbutmentInfo = ->*pInfo;
# [35:21] CursorKind.UNARY_OPERATOR
# ====
# ====
# 		*_pAbutmentInfo = *->pInfo;
# [35:22]pInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		*_pAbutmentInfo = *->pInfo;
# [35:22]pInfo CursorKind.DECL_REF_EXPR
# ====
# ====
# 	->{
# [38:2] CursorKind.COMPOUND_STMT
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3] CursorKind.IF_STMT
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3] CursorKind.COMPOUND_STMT
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3] CursorKind.CXX_DELETE_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3] CursorKind.BINARY_OPERATOR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 		->SAFE_DELETE(_pAbutmentInfo);
# [39:3] CursorKind.CXX_NULL_PTR_LITERAL_EXPR
# ====
# ====
# 		SAFE_DELETE(_pAbutmentInfo)->;
# [39:30] CursorKind.NULL_STMT
# ====
# ====
# ST_ABUTMENT_INFO* CAbutmentData::->GetAbutmentInfo()
# [44:34]GetAbutmentInfo CursorKind.CXX_METHOD
# ====
# ====
# ->ST_ABUTMENT_INFO* CAbutmentData::GetAbutmentInfo()
# [44:1]struct ST_ABUTMENT_INFO CursorKind.TYPE_REF
# ====
# ====
# ST_ABUTMENT_INFO* ->CAbutmentData::GetAbutmentInfo()
# [44:19]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# ->{
# [45:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->return _pAbutmentInfo;
# [46:2] CursorKind.RETURN_STMT
# ====
# ====
# 	return ->_pAbutmentInfo;
# [46:9]_pAbutmentInfo CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	return ->_pAbutmentInfo;
# [46:9]_pAbutmentInfo CursorKind.MEMBER_REF_EXPR
# ====
# ====
# CString CAbutmentData::->GetName()
# [50:24]GetName CursorKind.CXX_METHOD
# ====
# ====
# ->CString CAbutmentData::GetName()
# [50:1]CString CursorKind.TYPE_REF
# ====
# ====
# CString ->CAbutmentData::GetName()
# [50:9]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# ->{
# [51:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->CString strName;
# [52:2] CursorKind.DECL_STMT
# ====
# ====
# 	CString ->strName;
# [52:10]strName CursorKind.VAR_DECL
# ====
# ====
# 	->CString strName;
# [52:2]CString CursorKind.TYPE_REF
# ====
# ====
# 	CString ->strName;
# [52:10]CStringT CursorKind.CALL_EXPR
# ====
# ====
# 	->strName.Format(L"%s_%d", SURFACEMODEL_ABUTMENT, GetToothNumber());
# [53:2] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	->strName.Format(L"%s_%d", SURFACEMODEL_ABUTMENT, GetToothNumber());
# [53:2] CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->strName.Format(L"%s_%d", SURFACEMODEL_ABUTMENT, GetToothNumber());
# [53:2]strName CursorKind.DECL_REF_EXPR
# ====
# ====
# 	strName.->Format(L"%s_%d", SURFACEMODEL_ABUTMENT, GetToothNumber());
# [53:10]Format CursorKind.OVERLOADED_DECL_REF
# ====
# ====
# 	strName.Format(->L"%s_%d", SURFACEMODEL_ABUTMENT, GetToothNumber());
# [53:17]L"%s_%d" CursorKind.STRING_LITERAL
# ====
# ====
# 	strName.Format(L"%s_%d", ->SURFACEMODEL_ABUTMENT, GetToothNumber());
# [53:27]L"surface_abutment" CursorKind.STRING_LITERAL
# ====
# ====
# 	strName.Format(L"%s_%d", SURFACEMODEL_ABUTMENT, ->GetToothNumber());
# [53:50]GetToothNumber CursorKind.CALL_EXPR
# ====
# ====
# 	strName.Format(L"%s_%d", SURFACEMODEL_ABUTMENT, ->GetToothNumber());
# [53:50]GetToothNumber CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->return strName;
# [54:2] CursorKind.RETURN_STMT
# ====
# ====
# 	return ->strName;
# [54:9]CStringT CursorKind.CALL_EXPR
# ====
# ====
# 	return ->strName;
# [54:9]strName CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	return ->strName;
# [54:9]strName CursorKind.DECL_REF_EXPR
# ====
# ====
# int CAbutmentData::->GetIndex()
# [57:20]GetIndex CursorKind.CXX_METHOD
# ====
# ====
# int ->CAbutmentData::GetIndex()
# [57:5]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# ->{
# [58:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->int nIndex = ABUTMENT_MODEL_INDEX + GetToothNumber();
# [59:2] CursorKind.DECL_STMT
# ====
# ====
# 	int ->nIndex = ABUTMENT_MODEL_INDEX + GetToothNumber();
# [59:6]nIndex CursorKind.VAR_DECL
# ====
# ====
# 	int nIndex = ->ABUTMENT_MODEL_INDEX + GetToothNumber();
# [59:15] CursorKind.BINARY_OPERATOR
# ====
# ====
# 	int nIndex = ->ABUTMENT_MODEL_INDEX + GetToothNumber();
# [59:15]ABUTMENT_MODEL_INDEX CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	int nIndex = ->ABUTMENT_MODEL_INDEX + GetToothNumber();
# [59:15]ABUTMENT_MODEL_INDEX CursorKind.DECL_REF_EXPR
# ====
# ====
# 	int nIndex = ABUTMENT_MODEL_INDEX + ->GetToothNumber();
# [59:38]GetToothNumber CursorKind.CALL_EXPR
# ====
# ====
# 	int nIndex = ABUTMENT_MODEL_INDEX + ->GetToothNumber();
# [59:38]GetToothNumber CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->return nIndex;
# [60:2] CursorKind.RETURN_STMT
# ====
# ====
# 	return ->nIndex;
# [60:9]nIndex CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	return ->nIndex;
# [60:9]nIndex CursorKind.DECL_REF_EXPR
# ====
# ====
# void CAbutmentData::->SetMatrix(CMatrixMxN m)
# [63:21]SetMatrix CursorKind.CXX_METHOD
# ====
# ====
# void ->CAbutmentData::SetMatrix(CMatrixMxN m)
# [63:6]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# void CAbutmentData::SetMatrix(CMatrixMxN ->m)
# [63:42]m CursorKind.PARM_DECL
# ====
# ====
# void CAbutmentData::SetMatrix(->CMatrixMxN m)
# [63:31]class CMatrixMxN CursorKind.TYPE_REF
# ====
# ====
# ->{
# [64:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->_mTrans = m;
# [65:2]operator= CursorKind.CALL_EXPR
# ====
# ====
# 	->_mTrans = m;
# [65:2]_mTrans CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	_mTrans ->= m;
# [65:10]operator= CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	_mTrans ->= m;
# [65:10]operator= CursorKind.DECL_REF_EXPR
# ====
# ====
# 	_mTrans = ->m;
# [65:12]m CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	_mTrans = ->m;
# [65:12]m CursorKind.DECL_REF_EXPR
# ====
# ====
# CMatrixMxN CAbutmentData::->GetMatrix()
# [68:27]GetMatrix CursorKind.CXX_METHOD
# ====
# ====
# ->CMatrixMxN CAbutmentData::GetMatrix()
# [68:1]class CMatrixMxN CursorKind.TYPE_REF
# ====
# ====
# CMatrixMxN ->CAbutmentData::GetMatrix()
# [68:12]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# ->{
# [69:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->return _mTrans;
# [70:2] CursorKind.RETURN_STMT
# ====
# ====
# 	return ->_mTrans;
# [70:9]CMatrixMxN CursorKind.CALL_EXPR
# ====
# ====
# 	return ->_mTrans;
# [70:9]_mTrans CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	return ->_mTrans;
# [70:9]_mTrans CursorKind.MEMBER_REF_EXPR
# ====
# ====
# CString CAbutmentData::->_getInfoPath()
# [76:24]_getInfoPath CursorKind.CXX_METHOD
# ====
# ====
# ->CString CAbutmentData::_getInfoPath()
# [76:1]CString CursorKind.TYPE_REF
# ====
# ====
# CString ->CAbutmentData::_getInfoPath()
# [76:9]class CAbutmentData CursorKind.TYPE_REF
# ====
# ====
# ->{
# [77:1] CursorKind.COMPOUND_STMT
# ====
# ====
# 	->CEnvSession* pEnv = CEnvSession::GetInstance();
# [79:2] CursorKind.DECL_STMT
# ====
# ====
# 	CEnvSession* ->pEnv = CEnvSession::GetInstance();
# [79:15]pEnv CursorKind.VAR_DECL
# ====
# ====
# 	->CEnvSession* pEnv = CEnvSession::GetInstance();
# [79:2]class CEnvSession CursorKind.TYPE_REF
# ====
# ====
# 	CEnvSession* pEnv = ->CEnvSession::GetInstance();
# [79:22]GetInstance CursorKind.CALL_EXPR
# ====
# ====
# 	CEnvSession* pEnv = CEnvSession::->GetInstance();
# [79:35]GetInstance CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	CEnvSession* pEnv = CEnvSession::->GetInstance();
# [79:35]GetInstance CursorKind.DECL_REF_EXPR
# ====
# ====
# 	CEnvSession* pEnv = ->CEnvSession::GetInstance();
# [79:22]class CEnvSession CursorKind.TYPE_REF
# ====
# ====
# 	->CString strAbutmentFolder;
# [82:2] CursorKind.DECL_STMT
# ====
# ====
# 	CString ->strAbutmentFolder;
# [82:10]strAbutmentFolder CursorKind.VAR_DECL
# ====
# ====
# 	->CString strAbutmentFolder;
# [82:2]CString CursorKind.TYPE_REF
# ====
# ====
# 	CString ->strAbutmentFolder;
# [82:10]CStringT CursorKind.CALL_EXPR
# ====
# ====
# 	->strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:2] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	->strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:2]Format CursorKind.CALL_EXPR
# ====
# ====
# 	strAbutmentFolder.->Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:20]Format CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	->strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:2]strAbutmentFolder CursorKind.DECL_REF_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(->_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:27] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(->_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:27]"%s%s%s" CursorKind.STRING_LITERAL
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:41] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:41]GetPath_UserData CursorKind.CALL_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:47]GetPath_UserData CursorKind.MEMBER_REF_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:41]pEnv CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:41]pEnv CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:41]pEnv CursorKind.DECL_REF_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), ->MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:67] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), ->MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:67]GetCaseID CursorKind.CALL_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::->GetCaseID(), ABUTMENT_FILE_PATH);
# [83:78]GetCaseID CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::->GetCaseID(), ABUTMENT_FILE_PATH);
# [83:78]GetCaseID CursorKind.DECL_REF_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), ->MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [83:67]class MiscUtils CursorKind.TYPE_REF
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ->ABUTMENT_FILE_PATH);
# [83:91] CursorKind.UNEXPOSED_EXPR
# ====
# ====
# 	strAbutmentFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ->ABUTMENT_FILE_PATH);
# [83:91]"\\ModeXML\\ImplantSimulation\\Implant Design\\Implant\\" CursorKind.STRING_LITERAL
# ====
# ====
# 	->MiscUtils::MakeDirectory(strAbutmentFolder);
# [84:2]MakeDirectory CursorKind.CALL_EXPR
# ====
# ====
# 	MiscUtils::->MakeDirectory(strAbutmentFolder);
# [84:13]MakeDirectory CursorKind.UNEXPOSED_EXPR
# ====
# ====
# ...
# [178:23]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		CSurfaceLoader ->surfaceLoader;
# [182:18]CSurfaceLoader CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->strMatPath.Format(_T("%s%s%s"), strLoadFolder, GetName(), DATA_MATRIX);
# [186:2]Format CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strMatPath.Format(_T("%s%s%s"), ->strLoadFolder, GetName(), DATA_MATRIX);
# [186:34]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strMatPath.Format(_T("%s%s%s"), strLoadFolder, ->GetName(), DATA_MATRIX);
# [186:49]GetName CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->SetMatrix(_loadMatrix(strMatPath));
# [188:2]SetMatrix CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	SetMatrix(->_loadMatrix(strMatPath));
# [188:12] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	SetMatrix(->_loadMatrix(strMatPath));
# [188:12]_loadMatrix CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	SetMatrix(_loadMatrix(->strMatPath));
# [188:24]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CEnvSession* pEnv = ->CEnvSession::GetInstance();
# [197:22]GetInstance CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CString strFilePath = ->strPath;
# [201:24]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		CString strLeft = ->strPath.Left(nFind);
# [206:21] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		CString strLeft = ->strPath.Left(nFind);
# [206:21]Left CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		CString ->strFixtureFolder;
# [208:11]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		->strFixtureFolder.Format(_T("%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID());
# [209:3]Format CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		strFixtureFolder.Format(_T("%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID());
# [209:39]GetPath_UserData CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		strFixtureFolder.Format(_T("%s%s"), pEnv->GetPath_UserData(), ->MiscUtils::GetCaseID());
# [209:65]GetCaseID CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		->strFilePath.Replace(strLeft, strFixtureFolder);
# [211:3]Replace CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		strFilePath.Replace(->strLeft, strFixtureFolder);
# [211:23]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		strFilePath.Replace(strLeft, ->strFixtureFolder);
# [211:32]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CFileStatus ->fs;
# [214:14]CFileStatus CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	if (->CFile::GetStatus(strFilePath, fs))
# [215:6]GetStatus CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	if (CFile::GetStatus(->strFilePath, fs))
# [215:23]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		CSurfaceLoader ->surfaceLoader;
# [219:18]CSurfaceLoader CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CString ->strSaveFolder;
# [223:10]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->strSaveFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [224:2]Format CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strSaveFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [224:37]GetPath_UserData CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strSaveFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), ->MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [224:63]GetCaseID CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CString strMat = ->strSaveFolder;
# [226:19]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->strMat.Format(_T("%s%s%s"), strMat, GetName(), DATA_MATRIX);
# [227:2]Format CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strMat.Format(_T("%s%s%s"), ->strMat, GetName(), DATA_MATRIX);
# [227:30]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strMat.Format(_T("%s%s%s"), strMat, ->GetName(), DATA_MATRIX);
# [227:38]GetName CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->SetMatrix(_loadMatrix(strMat));
# [229:2]SetMatrix CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	SetMatrix(->_loadMatrix(strMat));
# [229:12] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	SetMatrix(->_loadMatrix(strMat));
# [229:12]_loadMatrix CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	SetMatrix(_loadMatrix(->strMat));
# [229:24]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CString ->strLoadFolder, strSTLPath, strMatPath;
# [237:10]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CString strLoadFolder, ->strSTLPath, strMatPath;
# [237:25]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CString strLoadFolder, strSTLPath, ->strMatPath;
# [237:37]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CEnvSession* pEnv = ->CEnvSession::GetInstance();
# [239:22]GetInstance CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->strLoadFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [240:2]Format CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strLoadFolder.Format(_T("%s%s%s"), ->pEnv->GetPath_UserData(), MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [240:37]GetPath_UserData CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strLoadFolder.Format(_T("%s%s%s"), pEnv->GetPath_UserData(), ->MiscUtils::GetCaseID(), ABUTMENT_FILE_PATH);
# [240:63]GetCaseID CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	strSTLPath.Format(L"%s%s%s", strLoadFolder, ->GetName(), PLY_FORMAT);
# [242:46]GetName CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	BOOL bRet = ->DeleteFile(strSTLPath);
# [244:14]DeleteFileA CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	BOOL bRet = DeleteFile(->strSTLPath);
# [244:25]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		->strMatPath.Format(_T("%s%s%s"), strLoadFolder, GetName(), DATA_MATRIX);
# [248:3]Format CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		strMatPath.Format(_T("%s%s%s"), ->strLoadFolder, GetName(), DATA_MATRIX);
# [248:35]CStringT CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		strMatPath.Format(_T("%s%s%s"), strLoadFolder, ->GetName(), DATA_MATRIX);
# [248:50]GetName CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		->DeleteFile(strMatPath);
# [249:3]DeleteFileA CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 		DeleteFile(->strMatPath);
# [249:14]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->MiscUtils::MakeDirectory(strFolder);
# [263:2]MakeDirectory CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	MiscUtils::MakeDirectory(->strFolder);
# [263:27]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CMatrixMxN mat = ->mTrans;
# [265:19]CMatrixMxN CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->::DeleteFile(strPath);
# [267:2]DeleteFileA CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	::DeleteFile(->strPath);
# [267:15]operator const char * CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	if (->os.is_open())
# [276:6] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 				->os.write((char*)&mat.val[i][j], sizeof(float));
# [286:5] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->os.close();
# [298:2] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	CMatrixMxN ->mat{ 4,4 };
# [334:13]CMatrixMxN CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->mat.eye();
# [335:2]eye CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	if (->is.is_open())
# [337:6] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 				->is.read((char*)&mat.val[i][j], sizeof(float));
# [343:5] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	->is.close();
# [351:2] CursorKind.CALL_EXPR
# D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp contains D:\dev\AutoPlanning\trunk\AP_trunk_pure\AppFrame\AbutmentData.cpp
# =================
# 	return ->mat;
# [353:9]CMatrixMxN CursorKind.CALL_EXPR
